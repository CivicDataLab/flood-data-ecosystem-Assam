# %%
import pandas as pd
import os
import glob

# %%
hp_tenders_root = r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Himachal-Pradesh\Sources\TENDERS\data\monthly_tenders'

if not os.path.isdir(hp_tenders_root):
    raise FileNotFoundError(f"Directory not found: {hp_tenders_root}")

csv_files = glob.glob(os.path.join(hp_tenders_root, "*.csv"))
frames = []
for file in csv_files:
    try:
        df = pd.read_csv(file)
        frames.append(df)
    except Exception as e:
        print(f"Failed to read {file}: {e}")

if frames:
    hp_tenders = pd.concat(frames, ignore_index=True)
else:
    hp_tenders = pd.DataFrame()

as_tenders = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Assam\Sources\TENDERS\data\flood_tenders_all.csv')

# %%
as_tenders.shape
# Out:
# (1209, 39)

# %%
as_tenders = as_tenders.loc[as_tenders['Status'] == 'Accepted-AOC']
print(f"Number of accepted tenders: {len(as_tenders)}")
as_tenders
# Out:
# Number of accepted tenders: 1201
#                Tender ID                     tender_externalreference  \
# 0     2020_AEGCL_18168_1                          MD/CGM/NAMRUPBAY/01
# 1      2020_DoWR_17961_1                    TEZPUR/2019-20/SDRF-II/II
# 2      2020_DoWR_17997_1                   SILCHAR/2020-21/CMSPLPKG/1
# 3      2020_DoWR_18530_2                         DIPHU/2019-20/RIDF/I
# 4      2020_DoWR_19044_1                       DHUBRI/2018-19/RIDF/II
# ...                  ...                                          ...
# 1204  2020_BTCWR_15799_1  Addl.CE/KZ/WR/E-T/100/05-A, dtd.06.01.2020.
# 1205   2020_DoWR_16157_1                  MORIGAON/2019-20/SOPD-FDR/I
# 1206   2020_DoWR_16420_1                        TEZPUR/2018-19/SDRF/I
# 1207   2020_DoWR_16504_1                            CID/2019-20/MnR/I
# 1208   2020_DoWR_16508_1                      KARIMGANJ/2019-20/MnR/I
#
#                                            tender_title  \
# ...

# %%
as_tenders['Awarded Value'].str.replace(',','').astype(float).sum()
# Out:
# 30641996994.9
