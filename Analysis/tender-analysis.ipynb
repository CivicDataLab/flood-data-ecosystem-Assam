# %%
import pandas as pd
import os
import glob

# %%
# Concatenate monthly tenders files
as_tenders_root = r"/Users/saurabhlevin/Deployment/flood-data-ecosystem-Assam/Sources/TENDERS/data/monthly_tenders"
if not os.path.isdir(as_tenders_root):
    raise FileNotFoundError(f"Directory not found: {as_tenders_root}")

csv_files = glob.glob(os.path.join(as_tenders_root, "*.csv"))
frames = []
for file in csv_files:
    try:
        df = pd.read_csv(file)
        frames.append(df)
    except Exception as e:
        print(f"Failed to read {file}: {e}")

if frames:
    as_tenders = pd.concat(frames, ignore_index=True)
else:
    as_tenders = pd.DataFrame()

as_tenders.shape
# Out:
# (29992, 29)

# %%
as_flood_tenders = pd.read_csv(r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-Assam/Sources/TENDERS/data/flood_tenders_all.csv')
as_flood_tenders = as_flood_tenders.loc[as_flood_tenders['Status'] == 'Accepted-AOC']
print(f"Number of accepted tenders: {len(as_flood_tenders)}")
as_flood_tenders
# Out:
# Number of accepted tenders: 1457
#                Tender ID                     tender_externalreference  \
# 0     2020_AEGCL_18168_1                          MD/CGM/NAMRUPBAY/01
# 1      2020_DoWR_17961_1                    TEZPUR/2019-20/SDRF-II/II
# 2      2020_DoWR_17997_1                   SILCHAR/2020-21/CMSPLPKG/1
# 3      2020_DoWR_18530_2                         DIPHU/2019-20/RIDF/I
# 4      2020_DoWR_19044_1                       DHUBRI/2018-19/RIDF/II
# ...                  ...                                          ...
# 1460  2020_BTCWR_15799_1  Addl.CE/KZ/WR/E-T/100/05-A, dtd.06.01.2020.
# 1461   2020_DoWR_16157_1                  MORIGAON/2019-20/SOPD-FDR/I
# 1462   2020_DoWR_16420_1                        TEZPUR/2018-19/SDRF/I
# 1463   2020_DoWR_16504_1                            CID/2019-20/MnR/I
# 1464   2020_DoWR_16508_1                      KARIMGANJ/2019-20/MnR/I
#
#                                            tender_title  \
# 0     Turnkey Construction of 132KV and 33kV Transfo...
# 1     Immediate measures for closing of breaches on ...
# 2     A/E measures to protect Annapurna Ferry Ghat (...
# 3     Protection of Daudpur gaon from the erosion of...
# 4     Re-sectioning of river Tekonjhora at Kharija-D...
# ...                                                 ...
# 1460  A/E measures to protect villages Aie Poali No....
# 1461  Reconstruction of breach like damaged embankme...
# 1462  Immediate Measures for restoration of damages ...
# 1463  MnR to Dyke along R/B of river Barak from Goni...
# 1464  M n R to embankment along both bank of River L...
#
#                                        Work Description Tender Category  \
# 0     Turnkey Construction of 132KV and 33kV Transfo...           Works
# 1     Immediate measures for closing of breaches on ...           Works
# 2     A/E measures to protect Annapurna Ferry Ghat (...           Works
# 3     Protection of Daudpur gaon from the erosion of...           Works
# 4     Re-sectioning of river Tekonjhora at Kharija-D...           Works
# ...                                                 ...             ...
# 1460  A/E measures to protect villages Aie Poali No....           Works
# 1461  Reconstruction of breach like damaged embankme...           Works
# 1462  Immediate Measures for restoration of damages ...           Works
# 1463  MnR to Dyke along R/B of river Barak from Goni...           Works
# 1464  M n R to embankment along both bank of River L...           Works
#
#       Tender Type Form of contract Product Category  \
# 0     Open Tender         Turn-key  Composite Works
# 1     Open Tender            Works      Civil Works
# 2     Open Tender            Works      Civil Works
# 3     Open Tender            Works      Civil Works
# 4     Open Tender            Works      Civil Works
# ...           ...              ...              ...
# 1460  Open Tender        Item Rate      Civil Works
# 1461  Open Tender            Works      Civil Works
# 1462  Open Tender            Works      Civil Works
# 1463  Open Tender            Works      Civil Works
# 1464  Open Tender            Works      Civil Works
#
#      Is Multi Currency Allowed For BOQ Allow Two Stage Bidding  ...  \
# 0                                   No                      No  ...
# 1                                   No                      No  ...
# 2                                   No                      No  ...
# 3                                   No                      No  ...
# 4                                   No                      No  ...
# ...                                ...                     ...  ...
# 1460                                No                      No  ...
# 1461                                No                      No  ...
# 1462                                No                      No  ...
# 1463                                No                      No  ...
# 1464                                No                      No  ...
#
#      is_flood_tender                             positive_keywords_dict  \
# 0               True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 1               True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 2               True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 3               True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 4               True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# ...              ...                                                ...
# 1460            True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 1461            True  {'Flood': 0, 'Embankment': 2, 'embkt': 0, 'Rel...
# 1462            True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 1463            True  {'Flood': 0, 'Embankment': 0, 'embkt': 0, 'Rel...
# 1464            True  {'Flood': 0, 'Embankment': 2, 'embkt': 0, 'Rel...
#
#                                  negative_keywords_dict        Season Scheme  \
# 0     {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...       Monsoon    NaN
# 1     {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...       Monsoon   SDRF
# 2     {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...       Monsoon    NaN
# 3     {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...       Monsoon   RIDF
# 4     {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...  Post-Monsoon   RIDF
# ...                                                 ...           ...    ...
# 1460  {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...   Pre-Monsoon    NaN
# 1461  {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...   Pre-Monsoon   SOPD
# 1462  {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...   Pre-Monsoon   SDRF
# 1463  {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...   Pre-Monsoon    NaN
# 1464  {'Floodlight': 0, 'Flood Light': 0, 'GAS': 0, ...   Pre-Monsoon    NaN
#
#      Erosion Roads_Bridges_Embkt           Response Type  \
# 0      False               False                  Others
# 1      False                True  Repair and Restoration
# 2       True               False                  Others
# 3       True               False                  Others
# 4      False                True                  Others
# ...      ...                 ...                     ...
# 1460    True               False                  Others
# 1461   False                True  Repair and Restoration
# 1462   False                True  Repair and Restoration
# 1463   False                True                  Others
# 1464   False                True      Immediate Measures
#
#      Flood Response - Subhead    month
# 0                         NaN  2021_01
# 1          {'restoration': 2}  2021_01
# 2                         NaN  2021_01
# 3                         NaN  2021_01
# 4                         NaN  2021_01
# ...                       ...      ...
# 1460                      NaN  2020_03
# 1461    {'reconstruction': 2}  2020_03
# 1462       {'restoration': 2}  2020_03
# 1463                      NaN  2020_03
# 1464              {'i.m.': 1}  2020_03
#
# [1457 rows x 39 columns]

# %%
as_flood_tenders['Awarded Value'].str.replace(',','').astype(float).sum()
# Out:
# np.float64(39645119826.07)

# %%
as_tenders = pd.read_csv(r'/Users/saurabhlevin/Deployment/flood-data-ecosystem-Assam/Sources/TENDERS/data/all_tenders.csv')
as_tenders = as_tenders.loc[as_tenders['Status'] == 'Accepted-AOC']
print(f"Number of accepted tenders: {len(as_tenders)}")
as_tenders
# Out:
# Number of accepted tenders: 13790
#                 Tender ID               tender_externalreference  \
# 1         2017_BTC_3541_1         ACE02/PWD/BTC/IFB/SA/17-18/118
# 3       2017_PWBNH_3174_1               SE(B)JHT/(C/S)/S-5/17-18
# 6       2017_PWBNH_4642_1              SE(B)JHT/(C/S)/S-23/17-18
# 9        2018_HFWD_5898_1     DME/324/2016/2780, Dated 19-2-2018
# 10     2018_PWBNH_10537_1              SE(B)JHT/(C/S)/S-52/18-19
# ...                   ...                                    ...
# 34733   2020_DoWR_16420_1                  TEZPUR/2018-19/SDRF/I
# 34734   2020_DoWR_16504_1                      CID/2019-20/MnR/I
# 34737   2020_DoWR_16508_1                KARIMGANJ/2019-20/MnR/I
# 34739    2020_GMC_16232_1  GER/Div-V/2019/62/04 Dated 30/01/2020
# 34743    2020_PWD_16027_1                    NLRC/T/2019-20/3832
#
#                                             tender_title  \
# 1                                    BTC/OTSG/2017-18/22
# 3      Proposed Construction of Class Room Building w...
# 6      Balance Work of Incomplete portion of Construc...
# 9                     Cardiac Catheterization Laboratory
# 10     Construction of Auditorium, Majuli (at Kamalab...
# ...                                                  ...
# 34733  Immediate Measures for restoration of damages ...
# 34734  MnR to Dyke along R/B of river Barak from Goni...
# 34737  M n R to embankment along both bank of River L...
# 34739     Construction of Beltola Market Balance Portion
# 34743                            ASSAM DARSHAN/JOANAI/06
#
#                                         Work Description Tender Category  \
# 1      BTC/OTSG/2017-18/22 Construction of Road from ...           Works
# 3      Proposed Construction of Class Room Building w...           Works
# 6      Balance Work of Incomplete portion of Construc...           Works
# 9      Top of the line Flat Panel Cardiac Catheteriza...           Goods
# 10     Construction of Auditorium, Majuli (at Kamalab...           Works
# ...                                                  ...             ...
# 34733  Immediate Measures for restoration of damages ...           Works
# 34734  MnR to Dyke along R/B of river Barak from Goni...           Works
# 34737  M n R to embankment along both bank of River L...           Works
# 34739     Construction of Beltola Market Balance Portion           Works
# 34743  Repair and renovation work for Kundimama under...           Works
#
#        Tender Type Form of contract          Product Category  \
# 1      Open Tender        Item Rate               Civil Works
# 3      Open Tender        Item Rate    Civil Works - Building
# 6      Open Tender        Item Rate    Civil Works - Building
# 9      Open Tender           Supply  Medical Equipments/Waste
# 10     Open Tender        Item Rate    Civil Works - Building
# ...            ...              ...                       ...
# 34733  Open Tender            Works               Civil Works
# 34734  Open Tender            Works               Civil Works
# 34737  Open Tender            Works               Civil Works
# 34739  Open Tender         Lump-sum    Civil Works - Building
# 34743  Open Tender            Works               Civil Works
#
#       Is Multi Currency Allowed For BOQ Allow Two Stage Bidding  ...  \
# 1                                    No                      No  ...
# 3                                    No                      No  ...
# 6                                    No                      No  ...
# 9                                   Yes                      No  ...
# 10                                   No                      No  ...
# ...                                 ...                     ...  ...
# 34733                                No                      No  ...
# 34734                                No                      No  ...
# 34737                                No                      No  ...
# 34739                                No                      No  ...
# 34743                                No                      No  ...
#
#                                    location   Pincode No of Bids Received  \
# 1                                 Kokrajhar  788730.0                 2.0
# 3                                  Bokakhat  785612.0                 2.0
# 6                                  Dholajan  785616.0                 2.0
# 9      GMCH, Guwahati, Kamrup, Assam, India  781032.0                 2.0
# 10                        Kamalabari Majuli  785106.0                 2.0
# ...                                     ...       ...                 ...
# 34733                                TEZPUR  784001.0                 3.0
# 34734                              BADARPUR  788806.0                 3.0
# 34737                             KARIMGANJ  788710.0                 3.0
# 34739                       Division-V, GMC  781006.0                 2.0
# 34743                                 Jonai  787060.0                 2.0
#
#        Tender Value in ₹                    Bidder Name Awarded Value  \
# 1            4,99,02,750        RAJU CHANDRA BASUMATARY   49902742.32
# 3              69,30,900                 ABHIJIT PHUKAN     6235027.0
# 6              33,43,700                    DEEPAK BORA     3343683.0
# 9            6,00,00,000  WIPRO GE HEALTHCARE PVT. LTD.    58936205.0
# 10             78,74,000                Bhabananda Nath     9958670.0
# ...                  ...                            ...           ...
# 34733          99,89,946                   KAMAL KAKATI    8772790.29
# 34734          64,99,990                  ROYAL TRADING    6492726.24
# 34737          64,99,823                  ROYAL TRADING     6488145.0
# 34739       11,50,00,000                       ANIL DAS   115000000.0
# 34743          68,48,708                 Bhairab Bhuyan     6848708.0
#
#              Status Contract Date : Tender Stage  \
# 1      Accepted-AOC     22-Jan-2021          AOC
# 3      Accepted-AOC     10-Apr-2018          AOC
# 6      Accepted-AOC     20-Nov-2018          AOC
# 9      Accepted-AOC     06-Jan-2021          AOC
# 10     Accepted-AOC     15-Jan-2019          AOC
# ...             ...             ...          ...
# 34733  Accepted-AOC     07-Mar-2020          AOC
# 34734  Accepted-AOC     07-Mar-2020          AOC
# 34737  Accepted-AOC     07-Mar-2020          AOC
# 34739  Accepted-AOC     12-Mar-2020          AOC
# 34743  Accepted-AOC     14-Feb-2020          AOC
#
#                                               Department
# 1      Bodoland Territorial Council-PWD||Director Cum...
# 3      Public Works Building and NH Department||Chief...
# 6      Public Works Building and NH Department||Chief...
# 9      Health and Family Welfare Department||Director...
# 10     Public Works Building and NH Department||Chief...
# ...                                                  ...
# 34733  Department of Water Resources||Chief Engineer ...
# 34734  Department of Water Resources||Chief Engineer ...
# 34737  Department of Water Resources||Chief Engineer ...
# 34739                     Guwahati Municipal Corporation
# 34743                      Public Works Roads Department
#
# [13790 rows x 29 columns]

# %%
as_tenders['Awarded Value'].str.replace(',','').astype(float).sum()
# Out:
# np.float64(512357264148.3707)

# %%
import pandas as pd

def tender_count_by_fy(csv_path: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)
    df["Published Date"] = pd.to_datetime(
        df["Published Date"], format="%d-%b-%Y %I:%M %p", errors="coerce"
    )
    def to_fy(dt):
        if pd.isna(dt): return None
        year = dt.year if dt.month >= 4 else dt.year - 1
        return f"{year}-{str(year + 1)[2:]}"
    df["FY"] = df["Published Date"].apply(to_fy)
    return df.groupby("FY").size().reset_index(name="Count")

result = tender_count_by_fy("data/flood_tenders_all.csv")
print(result.to_string(index=False))
print(f"\nTotal: {result['Count'].sum()}")

# %% [markdown]
# generate a function that will give the annual value of tenders in the financial year 2025-2026 from /Users/saurabhlevin/Deployment/flood-data-ecosystem-Assam/Sources/TENDERS/data/assam_all_tenders.csv

# %%
import pandas as pd

def annual_tender_value_fy2025_26(csv_path: str) -> tuple[float, int]:
    df = pd.read_csv(csv_path)
    df["Published Date"] = pd.to_datetime(
        df["Published Date"], format="%d-%b-%Y %I:%M %p", errors="coerce"
    )
    mask = (df["Published Date"] >= "2025-04-01") & \
           (df["Published Date"] <= "2026-03-31 23:59:59")
    fy_df = df[mask].copy()
    fy_df["_value"] = (
        fy_df["Tender Value in ₹"]
        .astype(str)
        .str.replace(",", "", regex=False)
        .pipe(pd.to_numeric, errors="coerce")
    )
    return fy_df["_value"].sum(), int(mask.sum())

total, count = annual_tender_value_fy2025_26("data/assam_all_tenders.csv")
print(f"FY 2025-26 — {count} tenders, Total Value: ₹{total:,.0f}")
