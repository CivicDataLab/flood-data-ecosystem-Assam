# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import re
from bs4 import BeautifulSoup
import fuzzywuzzy

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Utility to clean whitespace

def clean_text(text):
    return re.sub(r"\s+", " ", text).strip()

# Extraction mapping for scheme-level fields
extraction_dict = {
    'Name of the Scheme': 'div class="col-sm-18"', #/Project
    'Whether scheme': 'div class="col-sm-6"', # /project is new/ongoing
    'Whether the scheme is funded by NABARD': 'div class="col-sm-6"', 
    'Proposal Number': 'div class="form-group"', 
    'Proposal Date': 'div class="col-sm-6"', 
    'Issued Number': 'div class="form-group"', 
    'Valid Upto': 'div class="col-sm-6"', 
    'Admin Department File Number': 'div class="col-sm-6"', 
    'Brief nature of the scheme': 'div class="col-sm-6"', #/project and the time period required for implementation/execution
    'Aim, objectives and benefit expected from the scheme/project': 'div class="col-sm-6"', 
    'Whether included in the priority list approved by the Departmental Minister': 'div class="col-sm-6"', 
    'Ddo Details': 'div class="col-sm-6"', 
    'Common Proposal': 'div class="col-sm-6"', 
    'Project Profile Id:': 'div class="col-sm-6"', 
    'Project Classification': 'span class="text-success h6"', 
    'Type of the project:': '<div class="col-lg-12">', 
    'Opening and Closing dates:': 'div class="col-sm-6"', 
    'Project Beneficiary :': 'div class="col-sm-6" style="margin-top: 10px;"', 
    'Procurement Activity Type:': 'div class="col-sm-8" style="margin-top: 10px;"', 
    'Beneficiary Share Amount': 'div class="col-sm-12"', 
    'Whether the scheme is centrally sponsored scheme': 'div class="col-sm-12"', 
    'Total Administrative Approval Amount (Project Cost)(In Lakhs)': 'div class="col-sm-12"', 
    'DDO Code': 'div class="col-sm-6"', 
    'Treasury Name': 'div class="col-sm-6"', 
    'DDO Office Name': 'div class="col-sm-18"', 
    'Permission from local bodies for construction/establishment wherever necessary': 'div class="col-sm-18"', 
    'Non-Objection certificate': 'div class="col-sm-18"', 
    'Non-Duplicity certificate': 'div class="col-sm-18"', 
    'Views of Department': 'div class="col-sm-18"', 
    'Details information in case of observation made': 'div class="form-group"', # by T&D in last year\'s endorsement
    'Sanction letter copy of GOI in case of Central Sector Schemes': 'div class="col-sm-6"', 
    'Views of Sr': 'div class="col-sm-18"', #.F.A/F.A for non-admissibility of the instant project under DFPR
    'Funding pattern of the scheme': 'div class="col-sm-6"', 
    'The year from which the scheme is being implemented': 'div class="col-sm-6"', 
    'The quantum of central share allocated': 'div class="col-sm-6"', #/released for the year along with the supporting document
    'The criteria of proposing the amount of state share': 'div class="col-sm-6"'
}

# Convert pattern strings to CSS-like selector

def pattern_to_selector(pattern):
    pattern = pattern.strip()
    if pattern.startswith("<") and pattern.endswith(">"):
        pattern = pattern[1:-1].strip()
    tag_match = re.match(r'^(\w+)', pattern)
    tag = tag_match.group(1) if tag_match else ""
    class_match = re.search(r'class="([^"]+)"', pattern)
    if class_match:
        classes = class_match.group(1).split()
        return tag + ''.join(f'.{c}' for c in classes)
    return tag

# Extract a field based on label text and selector fingerprint

def extract_value_for_key(soup, key, pattern):
    cleaned_key = re.sub(r"\s*\([^)]*\)", "", key).strip()
    label = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))
    if not label:
        return None
    selector = pattern_to_selector(pattern)
    def matches(tag):
        if not tag.name:
            return False
        parts = selector.split('.')
        if tag.name != parts[0]:
            return False
        return all(c in tag.get('class', []) for c in parts[1:])
    found = label.find_next(matches)
    return clean_text(found.get_text()) if found else None

# Identify HOA tables by header keywords

def find_hoa_tables(soup):
    tables = []
    for tbl in soup.find_all('table'):
        first = tbl.find('tr')
        if not first:
            continue
        # only consider direct <th> children for header detection
        headers = [clean_text(th.get_text()) for th in first.find_all('th', recursive=False)]
        low = [h.lower() for h in headers]
        # require both 'head of account' and 'si no.' in direct headers
        if 'head of account' in low and any('si no' in h for h in low):
            tables.append(tbl)
    return tables

# Parse a single HOA table into flat records

def parse_hoa_table(tbl, scheme_data):
    records = []
    body = tbl.find('tbody') or tbl
    for tr in body.find_all('tr'):
        # skip header or total rows
        if tr.find('th'):
            continue
        # detect total row
        total_in = tr.find('input', id='totalHoaAmount')
        if total_in:
            scheme_data['Total HOA Amount'] = total_in['value']
            continue
        cells = tr.find_all('td')
        # need at least 7 cells: sl no, HOA cell, grant, current, total, est, green tag
        if len(cells) < 7:
            continue
        # Extract HOA number and name
        hoacell = cells[1]
        label = hoacell.find('label')
        name = clean_text(label.get_text()) if label else None
        # remove label(s) to isolate number
        for lab in hoacell.find_all('label'):
            lab.extract()
        number = clean_text(hoacell.get_text())
        # Extract financials
        current = clean_text(cells[3].get_text())
        total_est = clean_text(cells[4].get_text())
        estimated = clean_text(cells[5].get_text())
        # Green Budget Tag (first of two cells)
        green = clean_text(cells[6].get_text())
        # Build record
        rec = scheme_data.copy()
        rec['HOA_Number'] = number
        rec['HOA_Name'] = name
        rec["Current Year's Budget Provision (In Lakhs)"] = current
        rec["Total Estimated Cost of the Project (In Lakhs)"] = total_est
        rec["Estimated Expenditure in (Ct FY) (In Lakhs)"] = estimated
        rec['Green Budget Tag'] = green
        records.append(rec)
    return records

# Process a single HTML file

def process_file(path):
    with open(path, 'r', encoding='utf-8') as f:
        html = f.read()
    soup = BeautifulSoup(html, 'html.parser')
    # Normalize whitespace
    for t in soup.find_all(text=True):
        t.replace_with(clean_text(t))
    # Extract scheme-level fields
    scheme_data = {k: extract_value_for_key(soup, k, p) for k, p in extraction_dict.items()}
    # Parse any HOA tables
    recs = []
    for tbl in find_hoa_tables(soup):
        recs.extend(parse_hoa_table(tbl, scheme_data))
    # Fallback to single record if no table
    return recs or [scheme_data]

# Batch-run and export

def main():
    root = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages"
    files = []
    for yr in os.listdir(root):
        path = os.path.join(root, yr)
        if os.path.isdir(path) and re.match(r'\d{4}-\d{2}', yr):
            for fn in os.listdir(path):
                if fn.lower().endswith(('.html', '.htm')):
                    files.append((yr, os.path.join(path, fn)))
    total = len(files)
    print(f"Total files to process: {total}")

    # Export a sample for 2023-24
    sample = next(((y, f) for y, f in files if y == '2023-24'), None)
    if sample:
        y, fpath = sample
        print(f"\nSample [{y}]: {fpath}")
        sample_recs = process_file(fpath)
        print(sample_recs, "\n")
        pd.DataFrame(sample_recs).to_csv(
            os.path.join(os.path.dirname(fpath), 'all_extracted_data_sample_2023-24.csv'),
            index=False)
        print("Sample exported.\n")

    all_recs = []
    proc = fail = 0
    for y, fpath in files:
        try:
            recs = process_file(fpath)
            for r in recs:
                r['Financial Year'] = y
                r['Source File'] = fpath
                all_recs.append(r)
            proc += 1
        except Exception as e:
            fail += 1
            print(f"Error parsing {fpath}: {e}")
        print(f"Finished {proc}/{total} files")

    print(f"Done: {proc} succeeded, {fail} failed.")
    df = pd.DataFrame(all_recs)
    out = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Assam\Sources\SDRF\data\all_extracted_data_v2.csv"
    df.to_csv(out, index=False)
    print(f"Data saved to {out}")

if __name__ == '__main__':
    main()
# Out:
# Total files to process: 6916
#
# Sample [2023-24]: D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2023-24\AA-05-2023-24-6740.html
# C:\Users\saura\AppData\Local\Temp\ipykernel_30516\3796020064.py:149: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for t in soup.find_all(text=True):
# C:\Users\saura\AppData\Local\Temp\ipykernel_30516\3796020064.py:69: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   label = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))
# [{'Name of the Scheme': 'Repairing & Renovation Santipur PWSS damaged during Flood 2022 at Hajo LAC & Jalukbari LAC Under Hajo PHE Sub Division', 'Whether scheme': 'New project', 'Whether the scheme is funded by NABARD': 'No', 'Proposal Number': 'AA-05-2023-24-6740', 'Proposal Date': '26-06-2023', 'Issued Number': 'AA/05_2023-24(I)_5243', 'Valid Upto': '26-06-2026', 'Admin Department File Number': '289051', 'Brief nature of the scheme': 'FDR SCHEME', 'Aim, objectives and benefit expected from the scheme/project': 'Repairing & Renovation Santipur PWSS', 'Whether included in the priority list approved by the Departmental Minister': 'No', 'Ddo Details': 'AKM/DA/001', 'Common Proposal': 'No', 'Project Profile Id:': '', 'Project Classification': 'State Own Priority Scheme-GOI Special Scheme', 'Type of the project:': '3 Year Project', 'Opening and Closing dates:': '26-06-202326-06-2026', 'Project Beneficiary :': 'PUBLIC', 'Procurement Activity Type:': '--Not Available--', 'Beneficiary Share Amount': '-N/A-', 'Whether the scheme is centrally sponsored scheme': 'Yes', 'Total Administrative Approval Amount (Project Cost)(In Lakhs)': '1.49801', 'DDO Code': 'AKM/DA/001', 'Treasury Name': '', 'DDO Office Name': '', 'Permission from local bodies for construction/establishment w
# Finished 6843/6916 files
# Finished 6844/6916 files
# Finished 6845/6916 files
# Finished 6846/6916 files
# Finished 6847/6916 files
# Finished 6848/6916 files
# Finished 6849/6916 files
# Finished 6850/6916 files
# Finished 6851/6916 files
# Finished 6852/6916 files
# Finished 6853/6916 files
# Finished 6854/6916 files
# Finished 6855/6916 files
# Finished 6856/6916 files
# Finished 6857/6916 files
# Finished 6858/6916 files
# Finished 6859/6916 files
# Finished 6860/6916 files
# Finished 6861/6916 files
# Finished 6862/6916 files
# Finished 6863/6916 files
# Finished 6864/6916 files
# Finished 6865/6916 files
# Finished 6866/6916 files
# Finished 6867/6916 files
# Finished 6868/6916 files
# Finished 6869/6916 files
# Finished 6870/6916 files
# Finished 6871/6916 files
# Finished 6872/6916 files
# Finished 6873/6916 files
# Finished 6874/6916 files
# Finished 6875/6916 files
# Finished 6876/6916 files
# Finished 6877/6916 files
# Finished 6878/6916 files
# Finished 6879/6916 files
# Finished 6880/6916 files
# Finished 6881/6916 files
# Finished 6882/6916 files
# Finished 6883/6916 files
# Finished 6884/6916 files
# Finished 6885/6916 files
# Finished 6886/6916 files
# Finished 6887/6916 files
# Finished 6888/6916 files
# Finished 6889/6916 files
# Finished 6890/6916 files
# Finished 6891/6916 files
# Finished 6892/6916 files
# Finished 6893/6916 files
# Finished 6894/6916 files
# Finished 6895/6916 files
# Finished 6896/6916 files
# Finished 6897/6916 files
# Finished 6898/6916 files
# Finished 6899/6916 files
# Finished 6900/6916 files
# Finished 6901/6916 files
# Finished 6902/6916 files
# Finished 6903/6916 files
# Finished 6904/6916 files
# Finished 6905/6916 files
# Finished 6906/6916 files
# Finished 6907/6916 files
# Finished 6908/6916 files
# Finished 6909/6916 files
# Finished 6910/6916 files
# Finished 6911/6916 files
# Finished 6912/6916 files
# Finished 6913/6916 files
# Finished 6914/6916 files
# Finished 6915/6916 files
# Finished 6916/6916 files
# Done: 6916 succeeded, 0 failed.
# Data saved to D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\Deployment\flood-data-ecosystem-Assam\Sources\SDRF\data\all_extracted_data_v2.csv

# %% [markdown]
# ### All pages script

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Extraction dictionary mapping column names to a string fingerprint for the element.
extraction_dict = {
    'Name of the Scheme': 'div class="col-sm-18"', #/Project
    'Whether scheme': 'div class="col-sm-6"', # /project is new/ongoing
    'Whether the scheme is funded by NABARD': 'div class="col-sm-6"', 
    'Proposal Number': 'div class="form-group"', 
    'Proposal Date': 'div class="col-sm-6"', 
    'Issued Number': 'div class="form-group"', 
    'Valid Upto': 'div class="col-sm-6"', 
    'Admin Department File Number': 'div class="col-sm-6"', 
    'Brief nature of the scheme': 'div class="col-sm-6"', #/project and the time period required for implementation/execution
    'Aim, objectives and benefit expected from the scheme/project': 'div class="col-sm-6"', 
    'Whether included in the priority list approved by the Departmental Minister': 'div class="col-sm-6"', 
    'Ddo Details': 'div class="col-sm-6"', 
    'Common Proposal': 'div class="col-sm-6"', 
    'Project Profile Id:': 'div class="col-sm-6"', 
    'Project Classification': 'span class="text-success h6"', 
    'Type of the project:': '<div class="col-lg-12">', 
    'Opening and Closing dates:': 'div class="col-sm-6"', 
    'Project Beneficiary :': 'div class="col-sm-6" style="margin-top: 10px;"', 
    'Procurement Activity Type:': 'div class="col-sm-8" style="margin-top: 10px;"', 
    'Beneficiary Share Amount': 'div class="col-sm-12"', 
    'Whether the scheme is centrally sponsored scheme': 'div class="col-sm-12"', 
    'Total Administrative Approval Amount (Project Cost)(In Lakhs)': 'div class="col-sm-12"', 
    'DDO Code': 'div class="col-sm-6"', 
    'Treasury Name': 'div class="col-sm-6"', 
    'DDO Office Name': 'div class="col-sm-18"', 
    'Permission from local bodies for construction/establishment wherever necessary': 'div class="col-sm-18"', 
    'Non-Objection certificate': 'div class="col-sm-18"', 
    'Non-Duplicity certificate': 'div class="col-sm-18"', 
    'Views of Department': 'div class="col-sm-18"', 
    'Details information in case of observation made': 'div class="form-group"', # by T&D in last year\'s endorsement
    'Sanction letter copy of GOI in case of Central Sector Schemes': 'div class="col-sm-6"', 
    'Views of Sr': 'div class="col-sm-18"', #.F.A/F.A for non-admissibility of the instant project under DFPR
    'Funding pattern of the scheme': 'div class="col-sm-6"', 
    'The year from which the scheme is being implemented': 'div class="col-sm-6"', 
    'The quantum of central share allocated': 'div class="col-sm-6"', #/released for the year along with the supporting document
    'The criteria of proposing the amount of state share': 'div class="col-sm-6"'
}

def pattern_to_selector(pattern):
    """
    Converts a string like 'div class="col-sm-18"' or '<div class="col-lg-12">' 
    into a CSS selector, e.g. 'div.col-sm-18' or 'div.col-lg-12'.
    """
    pattern = pattern.strip()
    if pattern.startswith("<") and pattern.endswith(">"):
        pattern = pattern[1:-1].strip()
    tag_match = re.match(r'^(\w+)', pattern)
    tag = tag_match.group(1) if tag_match else ""
    class_match = re.search(r'class="([^"]+)"', pattern)
    if class_match:
        classes = class_match.group(1).split()
        selector = tag + ''.join(['.' + cls for cls in classes])
    else:
        selector = tag
    return selector

def extract_value_for_key(soup, key, pattern):
    """
    Matches the text node that contains the cleaned key (with parentheses removed)
    and returns the text from the first subsequent element that matches the CSS fingerprint derived from pattern.
    The matching is done in a case-insensitive manner.
    """
    # Remove parentheses and the text contained within them from the key
    cleaned_key = re.sub(r'\s*\([^)]*\)', '', key).strip()
    label_element = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))
    if label_element:
        selector = pattern_to_selector(pattern)
        def matches(tag):
            if not tag.name:
                return False
            sel_parts = selector.split('.')
            sel_tag = sel_parts[0]
            sel_classes = sel_parts[1:] if len(sel_parts) > 1 else []
            if tag.name != sel_tag:
                return False
            tag_classes = tag.get("class", [])
            return all(cls in tag_classes for cls in sel_classes)
        candidate = label_element.find_next(matches)
        if candidate:
            return re.sub(r'\s+', ' ', candidate.get_text(strip=True))
    return None

def process_file(file_path):
    """
    Processes one HTML file: cleans text nodes, extracts data based on extraction_dict,
    and then splits the combined 'Opening and Closing dates:' field into 'Starting Date' and 'Closing Date'.
    Returns a dictionary of extracted values.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        file_contents = file.read()

    soup = BeautifulSoup(file_contents, 'html.parser')
    
    # Pre-clean all text nodes to remove extra whitespace/newlines
    for text_node in soup.find_all(text=True):
        cleaned = re.sub(r'\s+', ' ', text_node)
        text_node.replace_with(cleaned)
    
    extracted_data = {}
    for key, pattern in extraction_dict.items():
        value = extract_value_for_key(soup, key, pattern)
        extracted_data[key] = value

    # Split the "Opening and Closing dates:" entry into two separate columns
    if "Opening and Closing dates:" in extracted_data and extracted_data["Opening and Closing dates:"] is not None:
        dates_value = extracted_data["Opening and Closing dates:"]
        # Use regex to extract date patterns of the form dd-mm-yyyy
        dates = re.findall(r'\d{2}-\d{2}-\d{4}', dates_value)
        if len(dates) >= 2:
            extracted_data["Starting Date"] = dates[0]
            extracted_data["Closing Date"] = dates[1]
        else:
            extracted_data["Starting Date"] = dates_value
            extracted_data["Closing Date"] = None
        # Remove the original combined field
        extracted_data.pop("Opening and Closing dates:", None)
    else:
        extracted_data["Starting Date"] = None
        extracted_data["Closing Date"] = None
    
    return extracted_data

def main():
    # Set the root folder containing subfolders named as financial years (e.g. "2021-22")
    root_folder = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages"
    all_data = []
    
    # Iterate over each subfolder matching the financial year pattern
    for subfolder in os.listdir(root_folder):
        subfolder_path = os.path.join(root_folder, subfolder)
        if os.path.isdir(subfolder_path) and re.match(r'\d{4}-\d{2}', subfolder):
            financial_year = subfolder  # e.g. "2021-22"
            # Process both .html and .htm files in this subfolder
            for file in os.listdir(subfolder_path):
                if file.lower().endswith((".html", ".htm")):
                    file_path = os.path.join(subfolder_path, file)
                    data = process_file(file_path)
                    data["Financial Year"] = financial_year
                    data["Source File"] = file_path
                    all_data.append(data)
    
    # Create a single DataFrame from all the records
    df = pd.DataFrame(all_data)
    print("Extracted DataFrame (first few rows):")
    print(df.head())
    
    # Save the DataFrame to a CSV file
    output_csv = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\data\all_extracted_data.csv"
    df.to_csv(output_csv, index=False)
    print(f"Data saved to {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_66328\2057794036.py:102: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for text_node in soup.find_all(text=True):
# C:\Users\saura\AppData\Local\Temp\ipykernel_66328\2057794036.py:72: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   label_element = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))
# Extracted DataFrame (first few rows):
#   Name of the Scheme Whether scheme Whether the scheme is funded by NABARD  \
# 0                              None                                   None
# 1                              None                                   None
# 2                              None                                   None
# 3                              None                                   None
# 4                              None                                   None
#
#   Proposal Number Proposal Date Issued Number Valid Upto  \
# 0            None          None          None       None
# 1            None          None          None       None
# 2            None          None          None       None
# 3            None          None          None       None
# 4            None          None          None       None
#
#   Admin Department File Number Brief nature of the scheme  \
# 0                         None                       None
# 1                         None                       None
# 2                         None                       None
# 3                         None                       None
# 4                         None                       None
#
#   Aim, objectives and benefit expected from the scheme/project  ...  \
# 0                                               None            ...
# 1                                               None            ...
# 2                                               None            ...
# 3                                               None            ...
# 4                                               None            ...
#
#   Sanction letter copy of GOI in case of Central Sector Schemes Views of Sr  \
# 0                                               None                   None
# 1                                               None                   None
# 2                                               None                   None
# 3                                               None                   None
# 4                                               None                   None
#
#   Funding pattern of the scheme  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
#
#   The year from which the scheme is being implemented  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   The quantum of central share allocated  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
#
#   The criteria of proposing the amount of state share  Starting Date  \
# 0                                               None            None
# 1                                               None            None
# 2                                               None            None
# 3                                               None            None
# 4                                               None            None
#
#   Closing Date Financial Year  \
# 0         None        2017-18
# 1         None        2017-18
# 2         None        2017-18
# 3         None        2017-18
# 4         None        2017-18
#
#                                          Source File
# 0  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 1  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 2  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 3  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 4  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
#
# [5 rows x 40 columns]
# Data saved to D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\data\all_extracted_data.csv

# %% [markdown]
# extraction_dict mapping:
# | Key                                                                                                                     | Element                                  |
# | ----------------------------------------------------------------------------------------------------------------------- | ---------------------------------------- |
# | Name of the Scheme/Project proposed                                                                                     | div class="col-sm-18"                     |
# | Whether scheme/project is new/ongoing                                                                                   | div class="col-sm-6"                      |
# | Whether the scheme is funded by NABARD                                                                                  | div class="col-sm-6"                      |
# | Proposal Number                                                                                                         | div class="form-group"                    |
# | Proposal Date                                                                                                           | div class="col-sm-6"                      |
# | Issued Number                                                                                                           | div class="form-group"                    |
# | Valid Upto(Auto generated after Issue)                                                                                  | div class="col-sm-6"                      |
# | Admin Department File Number                                                                                            | div class="col-sm-6"                      |
# | Brief nature of the scheme/project and the time period required for implementation/execution                          | div class="col-sm-6"                      |
# | Aim, objectives and benefit expected from the scheme/project                                                            | div class="col-sm-6"                      |
# | Whether included in the priority list approved by the Departmental Minister                                            | div class="col-sm-6"                      |
# | Ddo Details                                                                                                             | div class="col-sm-6"                      |
# | Common Proposal(If the documents in the Proposal Needs a Referance in other Proposals)                                   | div class="col-sm-6"                      |
# | Project Profile Id:                                                                                                     | div class="col-sm-6"                      |
# | Project Classification :                                                                                                | span class="text-success h6"              |
# | Type of the project:                                                                                                    | <div class="col-lg-12">                    |
# | Opening and Closing dates:                                                                                              | div class="col-sm-6"                      |
# | Project Beneficiary :                                                                                                   | div class="col-sm-6" style="margin-top: 10px;" |
# | Procurement Activity Type:                                                                                              | div class="col-sm-8" style="margin-top: 10px;" |
# | Beneficiary Share Amount(In Lakhs)                                                                                      | div class="col-sm-12"                     |
# | Whether the scheme is centrally sponsored scheme                                                                      | div class="col-sm-12"                     |
# | Total Administrative Approval Amount (Project Cost)(In Lakhs)                                                          | div class="col-sm-12"                     |
# | DDO Code                                                                                                                | div class="col-sm-6"                      |
# | Treasury Name(Auto generated)                                                                                           | div class="col-sm-6"                      |
# | DDO Office Name(Auto generated)                                                                                         | div class="col-sm-18"                     |
# | Permission from local bodies for construction/establishment wherever necessary                                          | div class="col-sm-18"                     |
# | Non-Objection certificate                                                                                                | div class="col-sm-18"                     |
# | Non-Duplicity certificate                                                                                                | div class="col-sm-18"                     |
# | Views of Department                                                                                                     | div class="col-sm-18"                     |
# | Details information in case of observation made by T&D in last year's endorsement                                       | div class="form-group"                    |
# | Sanction letter copy of GOI in case of Central Sector Schemes                                                          | div class="col-sm-6"                      |
# | Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR                                              | div class="col-sm-18"                     |
# | Funding pattern of the scheme                                                                                           | div class="col-sm-6"                      |
# | The year from which the scheme is being implemented                                                                     | div class="col-sm-6"                      |
# | The quantum of central share allocated/released for the year along with the supporting document                         | div class="col-sm-6"                      |
# | The criteria of proposing the amount of state share                                                                     | div class="col-sm-6"                      |
# | attachments required 'Other Documents( if required )'                                                                   |                                          |
# | attachments required 'SOPD Justification Document*'                                                                     |                                          |
# | Detailed Project Report (DPR) / Project Estimate approved by the Competent Authority                                    |                                          |
# | attachmenbts required 'Views of Senior Most Secretary in the Department'                                                | div class="col-sm-18"                     |
# | (attachments required) 'Departments view on the feasibility of the proposal by the Departmental Authority'                | div class="col-sm-18"                     |
# | (attachments required) 'Specific View of F.A/Sr.F.A and Checklist of F.A'                                                | div class="col-sm-18"                     |
# | Beneficiary Name                                                                                                        | div class="col-sm-12"                     |
# | Procurement activity                                                                                                    |                                          |
# | Unique Number                                                                                                           |                                          |

# %%
folder = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages"

# %%
def extract_field_by_label(soup, label_text):
    """
    Searches for an element (e.g., <td>, <th>, <div>, or <span>) that contains the given label text,
    and returns the text from its next sibling element.
    
    You might need to update the logic based on your file's actual structure.
    """
    # Find an element containing the label text
    label_element = soup.find(lambda tag: tag.name in ['td', 'th', 'div', 'span'] and label_text in tag.get_text())
    if label_element:
        # Get the next element which should contain the corresponding value
        value_element = label_element.find_next()
        if value_element:
            return value_element.get_text(strip=True)
    return None

def extract_fields(soup):
    """
    Extracts the required fields from the BeautifulSoup-parsed HTML.
    Adjust the label texts below to match your HTML document.
    """
    record = {}
    record["Name of the Scheme/Project Proposed"] = extract_field_by_label(soup, "Name of the Scheme/Project Proposed")
    record["Whether the scheme is funded by NABARD"] = extract_field_by_label(soup, "NABARD")
    record["Brief nature of the scheme/project and the time period required for implementation/execution"] = extract_field_by_label(soup, "Brief nature")
    record["Type of the project"] = extract_field_by_label(soup, "Type of the project")
    record["Procurement Activity Type"] = extract_field_by_label(soup, "Procurement Activity Type")
    record["Aim, objectives and benefit expected from the scheme/project"] = extract_field_by_label(soup, "Aim, objectives")
    record["Project Classification"] = extract_field_by_label(soup, "Project Classification")
    record["Total Administrative Approval Amount (Project Cost) (In Lakhs)"] = extract_field_by_label(soup, "Total Administrative Approval Amount")
    return record

def main():
    # Specify the test HTML file (ensure it's in the current directory or provide the full path)
    test_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2023-24\AA-05-2023-24-6741.html"
    
    if not os.path.exists(test_file):
        print(f"File {test_file} not found. Please ensure the file exists in the directory.")
        return

    with open(test_file, "r", encoding="utf-8") as f:
        html_content = f.read()

    soup = BeautifulSoup(html_content, "html.parser")
    data_record = extract_fields(soup)
    
    # Create a DataFrame with one row using the extracted data
    df = pd.DataFrame([data_record])
    
    print("Extracted DataFrame:")
    df
    
    # Optionally, save the DataFrame to a CSV file
    df.to_csv("test_extracted_data.csv", index=False)
    print("DataFrame saved to test_extracted_data.csv")

if __name__ == "__main__":
    main()

test_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2023-24\AA-05-2023-24-6741.html"
with open(test_file, 'r', encoding='utf-8') as file:
    file_contents = file.read()

soup = BeautifulSoup(file_contents, 'html.parser')

print(soup.prettify())
cleaned_text = [div.get_text(strip=True) for div in soup.find_all("div", class_="col-sm-6 active")]
print([re.sub(r'\s+', ' ', text) for text in cleaned_text])
# Out:
# Extracted DataFrame:
# DataFrame saved to test_extracted_data.csv

# %%
test_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2018-19\AA-05-2018-19-0036.html"
with open(test_file, 'r', encoding='utf-8') as file:
    file_contents = file.read()

soup = BeautifulSoup(file_contents, 'html.parser')

print(soup.prettify())
cleaned_text = [div.get_text(strip=True) for div in soup.find_all("div", class_="col-sm-6 active")]
print([re.sub(r'\s+', ' ', text) for text in cleaned_text])
# Out:
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Public Finance Management System - Government of Assam" name="description"/>
#   <link href="/assamfinance/resources/icons/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/assamfinance/resources/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/assamfinance/resources/style/kranstyle.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/style/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <!-- BOOTSTRAP -->
#   <link href="/assamfinance/resources/bootstrap/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <!-- CALENDAR  -->
#   <link href="/assamfinance/resources/js/calendar/calendar.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/bootstrap/css/bootstrap-datetimepicker.min.css" media="screen" rel="stylesheet"/>
#   <script src="/assamfinance/resources/js/jquery-1.9.1.js">
#   </script>
#   <script src="/assamfinance/resources/js/jquery-ui.js">
#   </script>
#   <script src="/assamfinance/resources/bootstrap/js/bootstrap.min.js">
#   </script>
#   <!-- TINY-BOX  -->
#   <script src="/assamfinance/resources/js/tinybox/tinybox.js" type="text/javascript">
#   </script>
#   <script src="/assamfinance/resources/js/calendar/calendar.js">
#   </script>
#   <script charset="UTF-8" src="/assamfinance/resources/bootstrap/js/bootstrap-datetimepicker.js" type="text/javascript">
#   </script>
#   <!-- TOOL-TIP  -->
#   <link href="/assamfinance/resources/js/menu/css/dropdown/dropdown.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/menu/css/dropdown/dropdown.vertical.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/menu/css/dropdown/themes/default/default.ultimate.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/tooltipster-master/css/tooltipster.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/tooltipster-master/css/themes/tooltipster-noir.css" rel="stylesheet" type="text/css"/>
#   <script src="/assamfinance/resources/js/tooltipster-master/js/jquery.tooltipster.min.js" type="text/javascript">
#   </script>
#   <script src="/assamfinance/resources/js/jquery.slimscroll.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="../resources/js/ckeditor/ckeditor.js?version=2" type="text/javascript">
#   </script>
#   <style>
#    .cke{visibility:hidden;}
#   </style>
#   <script charset="utf-8" src="../resources/js/ckeditor5-build-classic/ckeditor.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .ck-hidden{display:none!important}.ck.ck-reset,.ck.ck-reset_all,.ck.ck-reset_all *{box-sizing:border-box;height:auto;position:static;width:auto}:root{--ck-color-base-action:#61b045;--ck-color-base-active:#198cf0;--ck-color-base-active-focus:#0e7fe1;--ck-color-base-background:#fff;--ck-color-base-border:#c4c4c4;--ck-color-base-focus:#6cb5f9;--ck-color-base-foreground:#fafafa;--ck-color-base-text:#333;--ck-color-button-action-active-background:#53973b;--ck-color-button-action-active-shadow:#498433;--ck-color-button-action-background:var(--ck-color-base-action);--ck-color-button-action-disabled-background:#7ec365;--ck-color-button-action-hover-background:#579e3d;--ck-color-button-action-text:var(--ck-color-base-background);--ck-color-button-cancel:#db3700;--ck-color-button-default-active-background:#d9d9d9;--ck-color-button-default-active-shadow:#bfbfbf;--ck-color-button-default-background:transparent;--ck-color-button-default-disabled-background:transparent;--ck-color-button-default-hover-background:#e6e6e6;--ck-color-button-on-active-background:#bababa;--ck-color-button-on-active-shadow:#a1a1a1;--ck-color-button-on-background:#dedede;--ck-color-button-on-disabled-background:#dedede;--ck-color-button-on-hover-background:#c4c4c4;--ck-color-button-save:#008a00;--ck-color-dropdown-panel-background:var(--ck-color-base-background);--ck-color-dropdown-panel-border:var(--ck-color-base-border);--ck-color-engine-placeholder-text:#c2c2c2;--ck-color-focus-border:#47a4f5;--ck-color-focus-disabled-shadow:rgba(119,186,248,0.3);--ck-color-focus-shadow:rgba(119,186,248,0.5);--ck-color-input-background:var(--ck-color-base-background);--ck-color-input-border:#c7c7c7;--ck-color-input-disabled-background:#f2f2f2;--ck-color-input-disabled-border:#c7c7c7;--ck-color-input-disabled-text:#5c5c5c;--ck-color-input-text:var(--ck-color-base-text);--ck-color-link-default:#0000f0;--ck-color-link-selected-background:#ebf8ff;--ck-color-list-background:var(--ck-color-base-background);--ck-color-list-button-hover-background:var(--ck-color-base-foreground);--ck-color-list-button-on-background:var(--ck-color-base-active);--ck-color-list-button-on-background-focus:var(--ck-color-base-active-focus);--ck-color-list-button-on-text:var(--ck-color-base-background);--ck-color-panel-background:var(--ck-color-base-background);--ck-color-panel-border:var(--ck-color-base-border);--ck-color-shadow-drop:rgba(0,0,0,0.15);--ck-color-shadow-inner:rgba(0,0,0,0.1);--ck-color-switch-button-inner-background:var(--ck-color-base-background);--ck-color-switch-button-off-background:#b0b0b0;--ck-color-switch-button-on-background:var(--ck-color-button-action-background);--ck-color-text:var(--ck-color-base-text);--ck-color-toolbar-background:var(--ck-color-base-foreground);--ck-color-toolbar-border:var(--ck-color-base-border);--ck-color-tooltip-background:var(--ck-color-base-text);--ck-color-tooltip-text:var(--ck-color-base-background);--ck-color-upload-bar-background:#6cb5f9;--ck-color-upload-infinite-background:rgba(0,0,0,0.1);--ck-disabled-opacity:.5;--ck-focus-disabled-outer-shadow:var(--ck-focus-outer-shadow-geometry) var(--ck-color-focus-disabled-shadow);--ck-focus-outer-shadow:var(--ck-focus-outer-shadow-geometry) var(--ck-color-focus-shadow);--ck-focus-outer-shadow-geometry:0 0 0 3px;--ck-focus-ring:1px solid var(--ck-color-focus-border);--ck-font-face:Helvetica,Arial,Tahoma,Verdana,Sans-Serif;--ck-font-size-base:13px;--ck-font-size-big:1.4em;--ck-font-size-large:1.8em;--ck-font-size-normal:1em;--ck-font-size-small:0.75em;--ck-font-size-tiny:0.7em;--ck-line-height-base:1.84615;--ck-ui-component-min-height:2.3em;--ck-z-default:1;--ck-z-modal:calc(var(--ck-z-default) + 999)}.ck.ck-reset,.ck.ck-reset_all,.ck.ck-reset_all *{background:transparent;border:0;margin:0;padding:0;text-decoration:none;transition:none;vertical-align:middle;word-wrap:break-word}.ck.ck-reset_all,.ck.ck-reset_all *{border-collapse:collapse;color:var(--ck-color-text);cursor:auto;float:none;font:normal normal norm ...
#   </style>
#   <script type="text/javascript">
#    window.history.forward();
# 	function noBack() {
# 		window.history.forward();
# 	}
#
# 	$(function() {
# 		tab = 'administrativeApprovalDept';
# 		surveyId = '';
# 		seat = '18914';
#
# 		if (typeof surveyId !== 'undefined' && surveyId > 0
# 				&& tab == "dashboard") {
# 			$.ajax({
# 				url : "https://fin.assam.gov.in/survey/getMySurveyBanner",
# 				data : {
# 					surveyId : surveyId,
# 					seat : seat
# 				}
# 			}).then(function(data) {
# 				$('#surveyModal .modal-body').html(data);
# 			});
#
# 			$('#surveyModal').modal('show');
# 		}
#
# 		if (tab != "") {
# 			$("#" + tab).addClass("active");
# 		}
#
# 		if (tab != "") {
# 			subtab = 'aaOngoing';
# 			if (subtab != "") {
# 				$("#" + subtab).attr("class", "active");
# 				if (subtab == "man" || subtab == "obl" || subtab == "suo"
# 						|| subtab == "oth") {
# 					stab = '';
#
# 					$("#" + stab).attr("class", "current_page_item");
# 					var $el, leftPos, newWidth, $mainNav = $("#example-one");
#
# 					$mainNav.append("<li id='magic-line'></li>");
# 					var $magicLine = $("#magic-line");
#
# 					$magicLine.width($(".current_page_item").width()).css(
# 							"left", $(".current_page_item a").position().left)
# 							.data("origLeft", $magicLine.position().left).data(
# 									"origWidth", $magicLine.width());
#
# 					$("#example-one li a").hover(function() {
# 						$el = $(this);
# 						leftPos = $el.position().left;
# 						newWidth = $el.parent().width();
# 						$magicLine.stop().animate({
# 							left : leftPos,
# 							width : newWidth
# 						});
# 					}, function() {
# 						$magicLine.stop().animate({
# 							left : $magicLine.data("origLeft"),
# 							width : $magicLine.data("origWidth")
# 						});
# 					});
# 				}
#
# 				subsubtab = '';
# 				if (subsubtab != "") {
# 					$("#" + subsubtab).attr("class", "selected");
# 				}
# 				if (tab != "" && tab == "la" && subsubtab != "") {
# 					$("#" + subsubtab).attr("class", "active");
# 				}
# 			}
# 		}
#
# 		if (tab != "" && tab == "home") {
# 			$('#d3').height($(window).height() - 280);
# 			$('#d2').height($(window).height() - 236);
# 		}
#
# 		if (tab != "" && tab == "reports") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
# 			$('#pr').height($(window).height() - 180);
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 			}
# 		}
#
# 		if (tab != "" && subtab == "otherAllowanceSetup") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
# 			$('#pr').height($(window).height() - 180);
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 			}
# 		}
#
# 		if (tab != "" && tab == "specialDeductionSetup") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
# 			$('#pr').height($(window).height() - 180);
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 			}
# 		}
#
# 		if (tab != "" && subtab == "debtSetup") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
#
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 				/* 	$("#" + stab).css("background-color", "white"); */
# 			}
# 		}
#
# 		$('#3').height($(window).height() - 280);
# 		$('#4').height($(window).height() - 350);
# 	});
#
# 	function viewGraph(year) {
# 		if ('aaOngoing' == "sfp") {
# 			view(document.getElementById("scid").value, year);
# 		}
# 	}
#
# 	function reportCeil() {
# 		var s = "Y";
# 		TINY.box.show({
# 			iframe : 'ceilingDetails?template=Y',
# 			width : 750,
# 			height : 320,
# 			fixed : false,
# 			maskid : 'bluemask',
# 			maskopacity : 60,
# 			openjs : function() {
# 				openJS()
# 			}
# 		});
# 	}
#
# 	function loadAjaxContent(elemId, action, param) {
# 		$.ajax({
# 			type : 'GET',
# 			url : action,
# 			data : param,
# 			success : function(msg) {
# 				$('#' + elemId).html(msg);
# 			}
# 		});
# 	}
#
# 	function goToFinVault(param1, param2, param3) {
# 		window.open("https://fin.assam.gov.in/finvault/goToFinVault?q=" + q);
# 	}
#
# 	$(document)
# 			.ready(
# 					function() {
# 						if ('D' == "O"
# 								&& '' != null) {
# 							var justificationSurrender = '';
# 							if (justificationSurrender == "true") {
#
# 								TINY.box.show({
# 									iframe : 'surrenderInitiationStatus',
# 									closejs : function() {
# 										window.parent.document.location
# 												.reload();
# 									},
# 									width : window.innerWidth - 900,
# 									height : window.innerHeight - 350,
# 									boxid : 'frameless'
# 								});
#
# 							}
# 						}
#
# // 						const tokenInput = document.querySelector('input[name="token"]');
#
# // 						// Get the value of the hidden input field
# // 						const sessionId = tokenInput ? tokenInput.value : null;
# // 						    localStorage.setItem("whatsapp-session", JSON.stringify({ loggedIn: true, sessionId }));
#
#
# // 								debugger
# // 							    const checkSessionInterval = setInterval(function () {
# // 							        const tokenInput = document.querySelector('input[name="token"]');
# // 							        const sessionId = tokenInput ? tokenInput.value : null;
#
# // 							        if (sessionId) {
# // 							            const currentSession = JSON.parse(localStorage.getItem("whatsapp-session"));
#
# // 							            if (!currentSession || currentSession.sessionId !== sessionId) {
# // 							                // Update the localStorage if sessionId changes
# // 							                alert("Another session is being started on a different tab.")
# // 							            }
# // 							        }
# // 							    }, 1000); // Check every 1 second
#
# // 							    });
#
# 					});
#   </script>
#   <title>
#    Administrative Approval, Technical and Financial Sanctions
#   </title>
#   <style type="text/css">
#    .header-part .nav-tabs {
# 	border-bottom: none;
# }
#
# ul.header-part {
# 	margin: 0px;
# 	padding: 0px;
# 	margin-top: 10px;
# 	margin-bottom: 5px;
# }
#
# ul.header-part li {
# 	display: inline;
# }
#
# ul.header-part li .mainLink {
# 	background-color: #F8C301;
# 	color: #000000;
# 	margin: -1px;
# 	padding: 3px 6px 4px 6px;
# 	text-decoration: none;
# 	font-size: 11px;
# 	font-family: Verdana, Arial, Helvetica, sans-serif;
# 	border-left: 3px solid #F9CC32;
# 	border-right: 3px solid #F9CC32;
# 	border-top: 3px solid #F9CC32;
# }
#
# ul.header-part li .mainLink:hover {
# 	background-color: #2666AB;
# 	border: 3px solid #1A60AB;
# 	border-bottom: none;
# 	color: #FFFFFF;
# }
#
# ul.header-part li .mainLink.active {
# 	background-color: #01458E;
# 	color: #FFFFFF;
# 	margin: 0px;
# 	padding: 3px 8px 4px 8px;
# 	outline: none;
# 	font-size: 11px;
# 	font-family: Verdana, Arial, Helvetica, sans-serif;
# 	border-left: 3px solid #01458E;
# 	border-right: 3px solid #01458E;
# 	border-top: 3px solid #01458E;
# }
#
# .header-part .dropdown-menu {
# 	transition: all 0.5s;
# 	overflow: hidden;
# 	transform-origin: top center;
# 	transform: scale(1, 0);
# 	display: block;
# 	opacity: 0.97;
# }
#
# .header-part .dropdown-menu a .row {
# 	padding: 3px 8px 4px 14px;
# }
#
# .header-part .dropdown:hover>.dropdown-menu {
# 	transform: scale(1);
# }
#
# .header-part .dropdown:hover>.dropdown-menu a:hover .row {
# 	color: #28a745;
# 	background-color: #f5f5f5;
# }
#
# .header-part .dropdown-menu a {
# 	color: #000;
# 	font-size: 12px;
# 	line-height: 1.8;
# }
#
# .header-part .dropdown-menu .dropdown-item {
# 	background-color: none;
# }
#
# .header-part .dropdown-menu .dropdown-item-disable {
# 	display: none;
# }
#   </style>
#   <link href="https://finanalytics.assam.gov.in/botpress/assets/modules/channel-web/inject.css" rel="stylesheet"/>
#  </head>
#  <body onload="noBack();" onpageshow="if(event.persisted) noBack();">
#   <table class="layoutStyle">
#    <tbody>
#     <tr>
#      <td colspan="3">
#       <link href="../resources/js/anylinkmenu.css" rel="stylesheet" type="text/css"/>
#       <script src="../resources/js/anylinkmenu.js" type="text/javascript">
#       </script>
#       <script src="../resources/js/jQuery-idle/jquery-idle.min.js" type="text/javascript">
#       </script>
#       <script src="https://finanalytics.assam.gov.in/botpress/assets/modules/channel-web/inject.js">
#       </script>
#       <script type="text/javascript">
#        anylinkmenu.init("menuanchorclass")
# 	var anylinkmenu4 = {
# 		divclass : 'anylinkmenu',
# 		inlinestyle : 'width:150px; background:#ffffff',
# 		linktarget : '_self'
# 	}
#
# 	anylinkmenu4.items = [
# 			[
# 				"Profile",
# 				"javascript: editProfile()" ],
# 			[
# 					"Change Password",
# 					"javascript:TINY.box.show({iframe:'/assamfinance/changePasswd',width:650,height:500,boxid : 'frameless' })" ],
# 			[ "Password History", "javascript: passwordHistory()" ],
# 			[
# 				"Deactivate Account",
# 				"javascript:TINY.box.show({iframe:'deleteProfile',width:600,height:450,boxid : 'frameless' })" ]]
#
# 	function passwordHistory() {
# 		window.location.href = "passwordHistory";
# 	}
#
# 	function editProfile() {
# 		window.location.href = "editProfile";
# 	}
#
# 	$(function() {
# 		if ('Y' == "N") {
# 			TINY.box
# 					.show({
# 						iframe : '/assamfinance/changePasswd',
# 						closejs : function() {
# 							window.parent.document.location.reload();
# 						},
# 						width : 650,
# 						height : 300,
# 						boxid : 'frameless'
# 					});
# 		}
# 	});
#
# 	$(document).on('click', '.forceLogout', function(event) {
# 		forceLogout();
# 	});
#
# 	$(document).on('click', '.keepAlive', function(event) {
# 		keepAlive();
# 	});
#
# 	$(document).idle({
# 		onIdle : function() {
# 			$("#notifyLogout").modal('show');
# 			countdown();
# 		},
# 		idle : 1000000
# 	})
#
# 	var timeoutHandle;
# 	function countdown() {
# 		var seconds = 60;
# 		function tick() {
# 			var counter = document.getElementById("countdowntimer");
# 			seconds--;
# 			counter.innerHTML = "(" + (seconds < 10 ? "0" : "")
# 					+ String(seconds) + ")";
# 			if (seconds > 0) {
# 				timeoutHandle = setTimeout(tick, 1000);
# 			} else {
# 				forceLogout();
# 			}
# 		}
# 		tick();
# 	}
#
# 	function forceLogout() {
# 		window.location.href = '/cas/logout';
# 	}
#
# 	function keepAlive() {
# 		$.ajax({
# 			url : 'keepSessionAlive',
# 			complete : function() {
# 				$("#notifyLogout").modal('hide');
# 			}
# 		});
# 	}
#
# 	function viewSupportNumbers() {
# 		$.ajax({
# 			type : "GET",
# 			url : "viewSupportNumbers",
# 			beforeSend : function() {
# 				$('#supportModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#supportModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#supportModal').modal('show');
# 	}
#       </script>
#       <table>
#        <tbody>
#         <tr>
#          <td class="headerband" height="60px" style="background-image: url('../resources/images/Assam_Logo_Header.png'); background-repeat: no-repeat; border: none; vertical-align: middle; margin: 10px 10px 10px 10px" width="300px">
#          </td>
#          <td class="headerband" height="56" style="vertical-align: middle;">
#           <img align="right" src="../resources/images/AssamFinance_Logo_Header.png"/>
#          </td>
#         </tr>
#         <tr class="band">
#          <td style="width: 60%; padding-top: 5px; padding-left: 5px;">
#           <div align="left">
#            <span style="color: white; font-size: 12px;">
#             Mr. Assistant rdm, Assistant Department, Revenue and Disaster Management Department
#            </span>
#            <a class="menuanchorclass" href="#" rel="anylinkmenu4">
#             <img border="0" height="10px" src="../resources/images/arr.png" width="10px"/>
#            </a>
#            <span style="color: #FFF;">
#             Last Log In : Friday, 21 March 2025, 11:46 AM
#            </span>
#            <a href="loginHistory" style="color: #F8C301;">
#             Show More
#            </a>
#           </div>
#          </td>
#          <td height="22px;" style="padding-top: 5px; padding-left: 5px">
#           <div align="right">
#            <span color="#FFFFFF;" style="font-weight: lighter;">
#             <a href="gotoMyInbox" style="text-decoration: none;" title="Home Page">
#              <span style="color: white; font-weight: normal; font-size: 12px;">
#               <i class="fa fa-home">
#               </i>
#               Home |
#              </span>
#             </a>
#             <a href="javascript:void(0);" id="userManualLink" onclick="gotoUserManuals();" style="text-decoration: none;" title="User Manuals">
#              <span style="color: white; font-size: 12px; font-weight: lighter;">
#               <i class="fa fa-book">
#               </i>
#               Manuals &amp; Tutorials |
#              </span>
#             </a>
#             <a href="changeAccountDetails" style="text-decoration: none;" title="Home Page">
#              <span style="color: white; font-weight: normal; font-size: 12px;">
#               <i class="fa fa-user-circle-o">
#               </i>
#               Change Account |
#              </span>
#             </a>
#             <a href="/cas/logout" style="text-decoration: none;" title="logout">
#              <span style="color: white; font-size: 12px; font-weight: lighter; padding-right: 10px;">
#               <i class="fa fa-sign-out">
#               </i>
#               Logout
#              </span>
#             </a>
#            </span>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <!-- GENERAL-USER-IDLE-STATUS -->
#       <div aria-hidden="true" aria-labelledby="notifyLogoutLabel" class="modal fade in" id="notifyLogout" role="dialog" tabindex="-1">
#        <div class="modal-dialog">
#         <div class="modal-content">
#          <div class="modal-header">
#           <button class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#            <span class="sr-only">
#             Close
#            </span>
#           </button>
#           <h4 class="modal-title" id="notifyLogoutLabel" style="color: #444;">
#            Session
# 					Timeout
#           </h4>
#          </div>
#          <div class="modal-body" style="font-size: 14px; line-height: 20px;">
#           You're
# 				being timed out due to inactivity. Please choose to stay signed in
# 				or to logout. Otherwise, you will be logged out automatically.
#          </div>
#          <div class="modal-footer">
#           <button class="btn btn-sm btn-danger forceLogout" type="button">
#            Logout
#           </button>
#           <button class="btn btn-sm btn-primary keepAlive" data-dismiss="modal" type="button">
#            Stay Logged In
#            <span id="countdowntimer">
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal" data-backdrop="static" data-keyboard="false" id="supportModal" role="dialog">
#        <div class="modal-dialog modal-lg">
#         <div class="modal-content">
#          <div class="modal-body" style="background-color: #f5f5f5;">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal fade" data-backdrop="static" data-keyboard="false" id="updatePasswordModal" role="dialog">
#        <div class="modal-dialog modal-md">
#         <div class="modal-content">
#          <div class="modal-header" style="display: flex;">
#           <h4 class="modal-title" style="color: #fff; width: 95%; text-align: left;">
#            Update
# 					Password
#           </h4>
#           <button class="close" data-dismiss="modal" style="width: 5%" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#            <span class="sr-only">
#             Close
#            </span>
#           </button>
#          </div>
#          <div class="modal-body" id="updatePasswordModalBody" style="height: 375px;">
#          </div>
#         </div>
#        </div>
#       </div>
#       <script>
#        let webchatOpen = false
# 	window.botpressWebChat.init({
# 		host : 'https://finanalytics.assam.gov.in/botpress',
# 		botId : 'helpdesk',
# 		userId : "18914",
# 		botName : 'Helpdesk',
# 		enableTranscriptDownload : false,
# 		showConversationsButton : false,
# 		hideWidget : true,
# 		useSessionStorage: true
# 	})
#
# 	window.addEventListener('message', function(event) {
# 		if (event.data.name === 'webchatReady') {
# 			window.botpressWebChat.sendEvent({
# 				type : 'proactive-trigger',
# 				text : 'Hi',
# 				channel : "web",
# 				payload : {
# 					token : "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJzdWIiOiJhZC5yZG0iLCJuYmYiOjE3NDI1Mzc5MjEsImlkIjoiMTg5MTQiLCJleHAiOjE3NDI2MjQzMjEsInVzZXJuYW1lIjoiYWQucmRtIn0.VsQ89FCpwS7QNSLIObONIpil-rplSP5Zrc7OKYsBmSg_-eAUf68Nab19H6uWCs6nyNp-913s2UvLH0ktVLBzNO8mQu3P59gr0CVnNiB0Ou7WJJiJKS7ULah-xzT9ne5WT1_4pk5AtM6c0DwoEW6e73HlKLLfSbW3Ab5tKYgtzUOfi8hVhHc16BQh9DNyzdXIFJs9lBSwiZQf4k2449QuKYymAw4d7x5P0eiaCWTCBbmXLrEMWkqSO0X4N0dH72XI7xVSr-U02dctH-MKEMzoQnQmVQciScM5z14mrUFQ2t-MOG_r6M7a2asGWaba2WHTn1Hso6qH3dCP3u9sTDjGuQ",
# 				},
# 			})
# 		}
# 		if (event.data.name === 'webchatOpened') {
# 			webchatOpen = true
# 		}
#
# 		if (event.data.name === 'webchatClosed') {
# 			webchatOpen = false
# 		}
# 	})
#       </script>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#FFFFFF" colspan="3" style="padding: 0px 4px 0px 4px">
#       <div align="left">
#        <ul class="header-part">
#         <li class="nav-item" title="Inbox">
#          <a class="nav-link mainLink" href="gotoDebtInbox" id="inbox">
#           Inbox
#          </a>
#         </li>
#         <!-- ====================== -->
#         <!-- === FOR BUDGET === -->
#         <!-- === FOR BUDGET END === -->
#         <!-- === FOR CEILING === -->
#         <!-- === FOR CEILING END === -->
#         <!-- === FOR AATSFS === -->
#         <!-- === FOR AATSFS END === -->
#         <!-- === FOR BILLS === -->
#         <!-- === FOR BILLS END === -->
#         <!-- === FOR DEBT === -->
#         <!-- === FOR DEBT END === -->
#         <!-- === FOR RIDF === -->
#         <!-- === FOR RIDF END === -->
#         <!-- === FOR EIS === -->
#         <!-- === FOR EIS END === -->
#         <!-- === FOR WORKS ACCOUNT === -->
#         <!-- === FOR WORKS ACCOUNT END === -->
#         <!-- === FOR AUDIT === -->
#         <!-- === FOR AUDIT END === -->
#         <!-- === FOR DASHBOARD === -->
#         <!-- === FOR CASH-PLANNING  === -->
#         <!-- === FOR CASH-PLANNING END === -->
#         <!-- === FOR TEMPORARY  === -->
#         <!-- Master Data -->
#        </ul>
#       </div>
#      </td>
#     </tr>
#     <tr>
#      <td width="4px">
#      </td>
#      <td id="bodypart">
#       <table>
#        <tbody>
#         <tr>
#          <td>
#           <ul class="dropdown dropdown-horizontal">
#            <li title="Received Administrative Approvals (Held By You)">
#             <a href="administrativeApprovalDeptReceived" id="aaReceivedDept">
#              Received
#             </a>
#            </li>
#            <li title="Create a new Administrative Approval">
#             <a href="administrativeApprovalDept" id="aaRequestDept">
#              Pending
#             </a>
#            </li>
#            <li title="Inter And Intra Department Forwarded">
#             <a href="aaInterAndIntraDeptForwarded" id="aaInterAndIntraForwarded">
#              Forwarded (Dept)
#             </a>
#            </li>
#            <li title="Forwarded To Finance">
#             <a href="administrativeApprovalDeptForwarded" id="aaDeptForwarded">
#              Forwarded
# 											(Finance)
#             </a>
#            </li>
#            <li title="Forwarded To Finance">
#             <a href="getAaFinanceReturnedInDept" id="aaFinReturnedDept">
#              Finance Returned
#             </a>
#            </li>
#            <li title="Queried">
#             <a href="administrativeApprovalDeptQueried" id="aaDeptQueried">
#              Queried
#             </a>
#            </li>
#            <li title="Issued (Manual+System Generated) Administrative Approvals">
#             <a href="aaIssuedDept" id="aaIssuedDept">
#              Issued
#             </a>
#            </li>
#            <li title="Ongoing + Proposals need to be revalidated">
#             <a class="active" href="aaOngoing" id="aaOngoing">
#              Manually Approved
#             </a>
#            </li>
#            <li>
#             <a href="aaRejectedDept" id="aaRejectedDEpt">
#              Rejected
#             </a>
#            </li>
#            <li>
#             <a href="aaCanceledDept" id="aaCanceledDept">
#              Cancelled
#             </a>
#            </li>
#            <li>
#             <a href="getAdministrativeApprovalListForVerification" id="verifyAa">
#              Verify
# 											AA
#             </a>
#            </li>
#            <li title="Administrative Approval Summary">
#             <a href="administrativeApprovalSummaryDept" id="aaSummaryDept">
#              Search
#             </a>
#            </li>
#            <li style="background-color: #338ad7;">
#             <a href="getAaGIS" id="getAaGIS" title="District Wise Administrative Approval">
#              AA-GIS
#             </a>
#            </li>
#            <li style="background-color: #338ad7;">
#             <a href="getAaReport" id="getAaReport" title="Administrative Approval Report">
#              Money
# 											Flow-Report
#             </a>
#            </li>
#            <li>
#             <a href="getAaGeneralReportsDept" id="getAaGeneralReportsDept" title="Administrative Approval General Reports">
#              Reports
#             </a>
#            </li>
#            <li>
#             <a href="getAaWildCardReportsDept" id="getAaWildCardReportsDept" title="Financial Sanction Wild Card Reports">
#              Wild Card Reports
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#         <!-- SUBTAB FOR BILLS -->
#         <!-- Sub tab for GeM -->
#         <!-- SUBTAB FOR TREASURY -->
#         <tr>
#          <td>
#           <script src="/assamfinance/resources/js/CommonAAFS.js">
#           </script>
#           <script charset="utf-8" src="../resources/js/ckeditor/ckeditor.js?version=2" type="text/javascript">
#           </script>
#           <script type="text/javascript">
#            var manualProposalAttachment = '1166-2017(1).pdf';
# 	var clicked = false;
# 	var iniId;
# 	var autocomp_opt = {
# 		delay : 100,
# 		source : function(request, response) {
# 			var ddoValue =  $('#ddoValue').val();
# 			$.ajax({
# 				url : 'headAutocompleteForAA',
# 				dataType : 'JSON',
# 				data : {
# 					searchQuery : request.term,
# 					initiationId : iniId,
# 					salaryOnly : false,
# 					mappedDdoId : ddoValue
# 				},
# 				success : function(data) {
# 					response($.map(data, function(i) {
# 						return {
# 							label : i.head,
# 							value : i.headId,
# 							allottedAmount : i.allottedAmount,
# 							shareStatus : i.shareStatus,
# 							color : i.color,
# 							levelOfImpact : i.levelOfImpact
# 						};
# 					}));
# 				}
# 			});
# 		},
# 		select : function(event, ui) {
# 			$(this).val(ui.item.label);
# 			$(this).parent('td').find(".headId").val(ui.item.value);
# 			$(this).closest('tr').find(".allottedAmount").val(
# 					ui.item.allottedAmount);
# 			$(this).closest('tr').find(".levelOfImpact").val(ui.item.levelOfImpact);
# 			$(this).closest('tr').find(".color").css("backgroundColor", ui.item.color);
#
# 			var sum = 0;
# 			$('.allottedAmount').each(function() {
# 				sum += Number($(this).val());
# 			});
# 			$('#totBudgetctFY').val(sum);
#
# 			if (ui.item.shareStatus == 'C') {
# 				$("#centralDiv").show();
# 				$('.centrallySponsored').show();
# 				$("#centralOrnot").val("Y");
# 			} else if ((ui.item.shareStatus != 'C') && (CentralShare != 'C')) {
# 				$('.centrallySponsored').hide();
# 				$("#centralDiv").hide();
# 				$("#centralOrnot").val("N");
# 			}
#
# 			return false;
# 		},
# 		minLength : 11
# 	};
#
# 	var autocomp_ddochoosen = {
# 		delay : 100,
# 		source : function(request, response) {
# 			$.ajax({
# 				url : 'ddoAutocomplete',
# 				dataType : 'JSON',
# 				data : {
# 					ddoSearchName : request.term
# 				},
# 				success : function(data) {
# 					response($.map(data, function(i) {
# 						return {
# 							label : i.hierarchyCode,
# 							value : i.hierarchyId
# 						};
# 					}));
# 				}
# 			});
# 		},
# 		select : function(event, ui) {
# 			$(this).val(ui.item.label);
# 			$(this).closest('td').find(".hierarchyId").val(ui.item.value);
# 			return false;
# 		},
# 		minLength : 1
# 	};
#
# 	$(document).ready(
# 			function() {
#
# 				$('.datetimepicker').datetimepicker({
# 					minView : 3,
# 					pickerPosition : 'bottom-right',
# 					format : 'dd-mm-yyyy',
# 					pickTime : false,
# 					autoclose : true,
# 					todayBtn : true,
# 					endDate : new Date()
# 				});
# 				$('.datetimepicker1').datetimepicker({
# 					minView : 3,
# 					pickerPosition : 'bottom-right',
# 					format : 'dd-mm-yyyy',
# 					pickTime : false,
# 					autoclose : true,
# 					todayBtn : true
#
# 				});
#
# 				iniId = $('#iniId').val();
# 				CentralShare = $('#CentralShare').val();
# 				if (CentralShare == 'C') {
# 					$("#centralDiv").show();
# 					$('.centrallySponsored').show();
# 					$("#centralOrnot").val("Y");
# 				} else {
# 					$("#centralDiv").hide();
# 					$('.centrallySponsored').hide();
# 					$("#centralOrnot").val("N");
#
# 				}
# 				$('.depname').val("");
# 				$('.head').on(
# 						"keyup",
# 						function(event) {
# 							var val = $(this).val();
# 							if (event.keyCode != 8) {
# 								if (val.length == 4 || val.length == 7
# 										|| val.length == 11 || val.length == 16
# 										|| val.length == 20) {
# 									val = val + "-";
# 									$(this).val(val);
# 								}
# 							}
# 						}).autocomplete(autocomp_opt);
# 				bindDeptAutoComplete();
#
# 				$('.ddochoosen').on("keyup", function(event) {
# 					var val = $(this).val();
#
# 					$(this).val(val);
# 				}).autocomplete(autocomp_ddochoosen);
#
# 				var sum = 0;
# 				$('.allottedAmount').each(function() {
# 					sum += Number($(this).val());
# 				});
# 				$('#totBudgetctFY').val(sum);
# 			});
#
# 	function bindDeptAutoComplete() {
# 		$('.depname').on("keyup", function(event) {
# 		}).autocomplete({
# 			delay : 100,
# 			source : function(request, response) {
# 				$.ajax({
# 					url : 'getDepartmentAutocomplete',
# 					data : {
# 						temp : request.term
# 					},
# 					beforeSend : function() {
#
# 					},
# 					success : function(data) {
# 						response($.map(data, function(i) {
# 							return {
# 								label : i.hierarchyName,
# 								value : i.hierarchyId
# 							};
#
# 						}));
# 					}
# 				});
# 			},
# 			select : function(event, ui) {
# 				$(this).val(ui.item.label);
# 				$(".deptId").val(ui.item.value);
# 				return false;
# 			},
# 			minLength : 1
# 		});
# 	}
# 	function showReplyBox(queryId) {
# 		$('#parentId').val(queryId);
# 		$('#myModal2').modal('show');
# 		return false;
# 	}
# 	function sendQuery(elem, queryId) {
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "sendAdministrativeApprovalQuery",
# 					data : {
# 						'id' : queryId
# 					},
# 					beforeSend : function() {
# 						$(elem).prop('class',
# 								'glyphicon glyphicon-option-horizontal');
# 					},
# 					success : function(msg) {
# 						if (msg) {
# 							$(elem)
# 									.closest('td')
# 									.html(
# 											'<i title="Sent" class="fa fa-share" aria-hidden="true" style="font-size: 16px; color: green;"></i>');
# 							location.reload();
# 						}
# 					}
# 				});
# 	}
# 	function deleteQuery(elem, queryId) {
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "deleteAdministrativeApprovalQuery",
# 					data : {
# 						'id' : queryId
# 					},
# 					beforeSend : function() {
# 						$(elem).prop('class',
# 								'glyphicon glyphicon-option-horizontal');
# 					},
# 					success : function(msg) {
# 						if (msg) {
# 							location.reload();
# 							$(elem).closest('tr').remove();
# 							if ($('#queryTable tr').length == 1) {
# 								$('#queryTable')
# 										.append(
# 												'<tr><td colspan="3" style="text-align:center">--No Queries Found--</td></tr>');
# 							}
# 							var i = 1;
# 							$('#queryTable').find(".slno").each(function() {
# 								$(this).html(i);
# 								i++;
# 							});
# 						}
# 					}
# 				});
# 	}
# 	function validateNum(elem) {
# 		if (isNaN(elem.value)) {
# 			alert('Invalid numeric value');
# 			elem.value = "";
# 			elem.focus();
# 		}
# 	}
# 	function validateNumAndTotCost(elem) {
# 		if (isNaN(elem.value)) {
# 			alert('Invalid numeric value');
# 			elem.value = "";
# 			elem.focus();
# 		} else {
# 			var sum = 0;
# 			$('.amt').each(function() {
# 				sum += Number($(this).val());
# 			});
# 			$('#aaTotAmount').val(sum);
# 		}
# 	}
# 	function validateCFYAmount(elem) {
# 		var txt_bAmt = $(elem).parent('td').find(".amt").val();
# 		if (isNaN(elem.value)) {
# 			alert('Invalid numeric value');
# 			elem.value = "";
# 			elem.focus();
# 		} else {
# 			var sum = 0;
# 			$('.eeCFYAmount').each(function() {
# 				sum += Number($(this).val());
# 			});
# 			$('#totEstimatedctFY').val(sum);
# 		}
# 	}
# 	function addNewRow(elem) {
# 		var rowLen = $('#proposalTable2').find('tr').length;
# 		rowLen = rowLen - 3;
# 		var rowData = $('#dynamicRow').html();
# 		rowData = rowData.replace(/counter/g, rowLen - 1);
# 		$(elem).before($('<tr></tr>').append(rowData));
# 	}
# 	function addNewCondition(elem) {
# 		var rowLen = $('#conditionTable').find('tr').length;
# 		rowLen = rowLen - 3;
# 		var rowData = $('#dynamicRow').html();
# 		rowData = rowData.replace(/counterIndex/g, rowLen);
# 		rowData = rowData.replace(/counter/g, rowLen - 1);
# 		$(elem).before($('<tr></tr>').append(rowData));
# 	}
# 	function addNewHOArow(elem) {
# 		var rowLen = $('#hoaTable').find('tr').length;
# 		rowLen = rowLen - 2;
# 		var rowData = $('#dynamicHOArow').html();
# 		rowData = rowData.replace(/counterIndex/g, rowLen);
# 		rowData = rowData.replace(/counter/g, rowLen - 1);
# 		$(elem).before($('<tr></tr>').append(rowData));
# 		$('.head').on(
# 				"keyup",
# 				function(event) {
# 					var val = $(this).val();
# 					if (event.keyCode != 8) {
# 						if (val.length == 4 || val.length == 7
# 								|| val.length == 11 || val.length == 16
# 								|| val.length == 20) {
# 							val = val + "-";
# 							$(this).val(val);
# 						}
# 					}
# 				}).autocomplete(autocomp_opt);
# 	}
# 	function validateDate(inputText) {
# 		var dateformat = /^(0?[1-9]|[12][0-9]|3[01])[\/\-](0?[1-9]|1[012])[\/\-]\d{4}$/;
# 		// Match the date format through regular expression
# 		if (inputText.value.match(dateformat)) {
# 			//Test which seperator is used '/' or '-'
# 			var opera1 = inputText.value.split('/');
# 			var opera2 = inputText.value.split('-');
# 			lopera1 = opera1.length;
# 			lopera2 = opera2.length;
# 			// Extract the string into month, date and year
# 			if (lopera1 > 1) {
# 				var pdate = inputText.value.split('/');
# 			} else if (lopera2 > 1) {
# 				var pdate = inputText.value.split('-');
# 			}
# 			var dd = parseInt(pdate[0]);
# 			var mm = parseInt(pdate[1]);
# 			var yy = parseInt(pdate[2]);
# 			// Create list of days of a month [assume there is no leap year by default]
# 			var ListofDays = [ 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31 ];
# 			if (mm == 1 || mm > 2) {
# 				if (dd > ListofDays[mm - 1]) {
# 					alert('Invalid date format!');
# 					inputText.value = "";
# 					return false;
# 				}
# 			}
# 			if (mm == 2) {
# 				var lyear = false;
# 				if ((!(yy % 4) && yy % 100) || !(yy % 400)) {
# 					lyear = true;
# 				}
# 				if ((lyear == false) && (dd >= 29)) {
# 					alert('Invalid date format!');
# 					inputText.value = "";
# 					return false;
# 				}
# 				if ((lyear == true) && (dd > 29)) {
# 					alert('Invalid date format!');
# 					inputText.value = "";
# 					return false;
# 				}
# 			}
# 		} else {
# 			alert("Invalid date format!");
# 			inputText.value = "";
# 			return false;
# 		}
# 	}
# 	function proposalReport(approvalId) {
# 		window.open('downloadAAChecklist?q=' + approvalId);
# 		return false;
# 	}
#
# 	function displayCentrallySponsored(elem) {
# 		if ($(elem).val() == "Y") {
# 			$('.centrallySponsored').show();
# 		} else {
# 			$('.centrallySponsored').hide();
# 		}
# 	}
# 	function validateSave() {
# 		var officeCat = 'D';
# 		var aaTotalAmount = $('#aaTotAmount').val();
# 		if ($(".projectname").val() == '') {
# 			alert('Invalid Name of the Scheme/Project proposed');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.amount']").val() == ''
# 				|| $("input[name='administrativeApproval.amount']").val() == 0) {
# 			alert('Invalid Project Amount');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.manualProposalNo']").val() == ''
# 				|| $("input[name='administrativeApproval.manualProposalNo']")
# 						.val() == 0) {
# 			alert('Invalid Manual Proposal No');
# 			return false;
# 		}
# 		checkManualProposalNoStatus();
# 		if ($("input[name='administrativeApproval.issuedOnStr']").val() == ''
# 				|| $("input[name='administrativeApproval.issuedOnStr']").val() == 0) {
# 			alert('Invalid issued Date');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.validUptoStr']").val() == ''
# 				|| $("input[name='administrativeApproval.validUptoStr']").val() == 0) {
# 			alert('Invalid Date');
# 			return false;
# 		}
# 		var finyear = $(".chosefinyear").val();
# 		if (finyear == '' || finyear == 0) {
# 			alert('Invalid Year');
# 			return false;
# 		}
# 		if (officeCat != "O") {
# 			var ddoId = $(".hierarchyId").val();
# 			if (ddoId == '' || ddoId == 0) {
# 				alert('Select DDO Details');
# 				return false;
# 			}
# 		}
# 		if (officeCat === 'O') {
# 			if (Number(aaTotalAmount) > Number(99999)) {
# 				alert('Maximum "Total Project Cost" is limited to 99999.000L!');
# 				return false;
# 			}
# 		}
# 		var validUptoStr = $("#validUptoStr").val().split("-");
# 		var issuedOnStr = $("#issuedOnStr").val().split("-");
#
# 		var validDate = new Date(validUptoStr[2], validUptoStr[1],
# 				validUptoStr[0]);
# 		var issuedDate = new Date(issuedOnStr[2], issuedOnStr[1],
# 				issuedOnStr[0]);
#
# 		if (validDate.getFullYear() < issuedDate.getFullYear()) {
# 			alert("Validity date shoud be higher than Issued date");
# 			return false;
# 		}
# 		if (validDate.getFullYear() == issuedDate.getFullYear()) {
# 			if (validDate.getMonth() < issuedDate.getMonth()) {
# 				alert("Validity date shoud be higher than Issued date");
# 				return false;
# 			}
# 		}
# 		if (validDate.getFullYear() == issuedDate.getFullYear()
# 				&& validDate.getMonth() == issuedDate.getMonth()) {
# 			if (validDate.getDate() < issuedDate.getDate()
# 					|| validDate.getDate() == issuedDate.getDate()) {
# 				alert("Validity date shoud be higher than Issued date");
# 				return false;
# 			}
# 		}
# 		if (!clicked) {
# 			clicked = true;
# 			return true;
# 		}
# 		return false;
# 	}
#
# 	function validateVerify() {
# 		var officeCat = 'D';
# 		var aaTotalAmount = $('#aaTotAmount').val();
# 		if ($(".projectname").val() == '') {
# 			alert('Invalid Name of the Scheme/Project proposed');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.amount']").val() == ''
# 				|| $("input[name='administrativeApproval.amount']").val() == 0) {
# 			alert('Invalid Project Amount');
# 			return false;
# 		}
#
# 		if ($("input[name='administrativeApproval.validUptoStr']").val() == ''
# 				|| $("input[name='administrativeApproval.validUptoStr']").val() == 0) {
# 			alert('Invalid Date');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.manualProposalFile']").val() == ''
# 				|| $("input[name='administrativeApproval.manualProposalFile']")
# 						.val() == 0) {
# 			alert('Invalid Attachment');
# 			return false;
# 		}
# 		if (manualProposalAttachment == '' || manualProposalAttachment == null) {
# 			alert('Please upload the Manual AA Attachment and Click the SAVE button !');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.issuedOnStr']").val() == ''
# 				|| $("input[name='administrativeApproval.issuedOnStr']").val() == 0) {
# 			alert('Invalid issued Date');
# 			return false;
# 		}
# 		if ($("input[name='administrativeApproval.manualProposalNo']").val() == ''
# 				|| $("input[name='administrativeApproval.manualProposalNo']")
# 						.val() == 0) {
# 			alert('Invalid Manual Proposal No');
# 			return false;
# 		}
# 		var finyear = $(".chosefinyear").val();
# 		if (finyear == '' || finyear == 0) {
# 			alert('Invalid Year');
# 			return false;
# 		}
# 		if (officeCat != "O") {
# 			var ddoId = $(".hierarchyId").val();
# 			if (ddoId == '' || ddoId == 0) {
# 				alert('Select DDO Details');
# 				return false;
# 			}
# 		}
# 		if (officeCat === 'O') {
# 			if (Number(aaTotalAmount) > Number(99999)) {
# 				alert('Maximum "Total Project Cost" is limited to 99999.000L!');
# 				return false;
# 			}
# 		}
# 		var validUptoStr = $("#validUptoStr").val().split("-");
# 		var issuedOnStr = $("#issuedOnStr").val().split("-");
#
# 		var validDate = new Date(validUptoStr[2], validUptoStr[1],
# 				validUptoStr[0]);
# 		var issuedDate = new Date(issuedOnStr[2], issuedOnStr[1],
# 				issuedOnStr[0]);
#
# 		getSimilarProposalList();
# 	}
# 	function getSimilarProposalList() {
# 		$.ajax({
# 			type : "POST",
# 			url : "getSimilarProposalList",
# 			data : $('#ongoingSchemeDetails').serialize(),
# 			beforeSend : function() {
# 				$('#administrativeNoteModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#administrativeNoteModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#administrativeNoteModal').modal('show');
# 		return false;
# 	}
#
# 	function addAANotes(approvalId) {
# 		$('#administrativeNoteModal #modalTitle').html(
# 				"Administrative Approval Notes");
# 		$.ajax({
# 			type : "GET",
# 			url : "addAANotes",
# 			data : {
# 				'administrativeApproval.approvalId' : approvalId
# 			},
# 			beforeSend : function() {
# 				$('#administrativeNoteModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#administrativeNoteModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#administrativeNoteModal').modal('show');
# 		return false;
# 	}
# 	function back() {
# 		window.location.href = "aaOngoing";
# 		return true;
# 	}
# 	function addConcurencePoints(approvalId) {
# 		$('#predefinedAAConcurenceModal #modalTitle').html(
# 				"Administrative Predefined Concurence");
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "getpredefinedAAConcurence",
# 					data : {
# 						'administrativeApproval.approvalId' : approvalId
# 					},
# 					beforeSend : function() {
# 						$('#predefinedAAConcurenceModal .modal-body').html(
# 								'Loading..');
# 					},
# 					success : function(msg) {
# 						$('#predefinedAAConcurenceModal .modal-body').html(msg);
# 					}
# 				});
# 		$('#predefinedAAConcurenceModal').modal('show');
# 		return false;
# 	}
# 	function deleteManualProposalAttachment(approvalId) {
# 		if (confirm('Are you sure to remove ?')) {
# 			$.ajax({
# 				url : 'deleteAAManualProposalAttachment',
# 				data : {
# 					'administrativeApproval.approvalId' : approvalId
# 				},
# 				success : function(msg) {
# 					location.reload();
# 				}
# 			});
# 		}
# 	}
# 	function deleteDfcAttachment(approvalId) {
# 		if (confirm('Are you sure to remove ?')) {
# 			$.ajax({
# 				url : 'deleteDfcAttachment',
# 				data : {
# 					'administrativeApproval.approvalId' : approvalId
# 				},
# 				success : function(msg) {
# 					location.reload();
# 				}
# 			});
# 		}
# 	}
# 	function deleteUtilizationAttachment(approvalId) {
# 		if (confirm('Are you sure to remove ?')) {
# 			$.ajax({
# 				url : 'deleteUtilizationAttachment',
# 				data : {
# 					'administrativeApproval.approvalId' : approvalId
# 				},
# 				success : function(msg) {
# 					location.reload();
# 				}
# 			});
# 		}
# 	}
# 	function updateYearAndInitId1(element) {
# 		var finYear = $("#selectedYear").val();
# 		$.ajax({
# 			type : "GET",
# 			url : "updateInitId",
# 			data : {
# 				'administrativeApproval.finYear' : finYear
# 			},
# 			beforeSend : function() {
# 			},
# 			success : function(msg) {
# 				if (msg == 0) {
#
# 					$('#hoaTable').prop("disabled", true);
# 					$("#hoaTable").hide();
# 					$("#hoaOldTable").show();
#
# 				} else {
# 					$('#hoaOldTable').prop("disabled", true);
# 					$("#hoaTable").show();
# 					$("#hoaOldTable").hide();
# 				}
# 				iniId = msg;
# 				$("#iniId").val(msg);
# 			}
# 		});
# 	}
# 	function shoaOldHoa() {
# 		var fullOldHoa = $("#MajorHead").val() + "-" + $("#SubMajorHead").val()
# 				+ "-" + $("#MinorHead").val() + "-" + $("#SubHead").val() + "-"
# 				+ $("#SubSubHead").val() + "-" + $("#DetailHead").val() + "-"
# 				+ $("#SubDetailHead").val() + "-" + $("#descriptionHead").val();
#
# 		$("#fulloldHoa").val(fullOldHoa);
#
# 	}
# 	function checkManualProposalNoStatus() {
# 		var manualProposalNo = $("#manualProposalNo").val();
# 		var approvalId = $("#approvalId").val();
# 		if (approvalId == null || approvalId == "undefined") {
# 			approvalId = 0;
# 		}
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "checkManualProposalNoStatus",
# 					async : false,
# 					data : {
# 						'administrativeApproval.manualProposalNo' : manualProposalNo,
# 						'administrativeApproval.approvalId' : approvalId
# 					},
# 					beforeSend : function() {
#
# 					},
# 					success : function(processingFlag) {
# 						if (processingFlag == true) {
# 							$("#manualProposalNo").val("");
# 							alert("This Proposal is already in the system!"
# 									+ "\nThe purpose of ongoing administrative approvals only for"
# 									+ "the proposals that are issued outside the FinAssam portal!"
# 									+ "\n\nPlease goto Issued Tab and Process the available Actions like Revalidation, Revision, etc.. If it is necessary")
#
# 							return false;
# 						}
#
# 					}
# 				});
# 	}
#           </script>
#           <script type="text/javascript">
#            jQuery(function($) {
#
# 		//filter the rows when searching
# 		$('.search-input').on(
# 				'keyup',
# 				function(event) {
# 					//get the search criteria
# 					var val = jQuery(this).val();
# 					if (event.keyCode != 8) {
# 						if (val.length == 4 || val.length == 7
# 								|| val.length == 11 || val.length == 16
# 								|| val.length == 20 || val.length == 23) {
# 							val = val + "-";
# 							jQuery(this).val(val);
# 						}
# 					}
# 				});
# 	});
#
# 	function addNewOldHOArow(elem) {
# 		var rowLen = $('#hoaOldTable').find('tr').length;
# 		rowLen = rowLen - 2;
# 		var rowData = $('#dynamicOldHOArow').html();
# 		rowData = rowData.replace(/counterIndex/g, rowLen);
# 		rowData = rowData.replace(/counter/g, rowLen - 1);
# 		$(elem).before($('<tr></tr>').append(rowData));
#
# 		$('.search-input').on(
# 				'keyup',
# 				function(event) {
# 					//get the search criteria
# 					var val = jQuery(this).val();
# 					if (event.keyCode != 8) {
# 						if (val.length == 4 || val.length == 7
# 								|| val.length == 11 || val.length == 16
# 								|| val.length == 20 || val.length == 23) {
# 							val = val + "-";
# 							jQuery(this).val(val);
# 						}
# 					}
# 				});
# 	}
# ...
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="modal fade" id="issueAdministrativeApprovalModal" role="dialog">
#            <div class="modal-dialog modal-lg">
#             <div class="modal-content">
#              <div class="modal-header">
#               <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#                <span aria-hidden="true">
#                 ×
#                </span>
#               </button>
#               <h4 class="modal-title">
#                <span class="label label-primary" id="modalTitle">
#                </span>
#               </h4>
#              </div>
#              <div class="modal-body">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="modal fade" id="predefinedAAConcurenceModal" role="dialog">
#            <div class="modal-dialog modal-lg">
#             <div class="modal-content">
#              <div class="modal-header">
#               <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#                <span aria-hidden="true">
#                 ×
#                </span>
#               </button>
#               <h4 class="modal-title">
#                <span class="label label-primary" id="modalTitle">
#                </span>
#               </h4>
#              </div>
#              <div class="modal-body">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="modal fade" id="myModalAaValidation" role="dialog">
#            <div class="modal-dialog modal-xl">
#             <div class="modal-content">
#              <div class="modal-header">
#               <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#                <span aria-hidden="true">
#                 ×
#                </span>
#               </button>
#               <h4 class="modal-title">
#                <span class="label label-primary" id="modalTitle">
#                </span>
#               </h4>
#              </div>
#              <div class="modal-body">
#              </div>
#             </div>
#            </div>
#           </div>
#           <script type="text/javascript">
#            $(document).ready(function() {
# 	$.ajax({
# 		type : "GET",
# 		url : "getMultipleOtherDocs",
# 		data : "id="
# 				+ '2856&type=OTH&issueType=AA',
# 		success : function(msg) {
# 			$('#aOdView').html(msg);
# 		}
# 	});
# });
#
# function addNewOtherDocRow(elem) {
# 	var rowLen = $('#otherDocTable').find('tr').length;
# 	rowLen = rowLen - 1;
# 	var rowData = $('#dynamicOtherDocRow').html();
# 	rowData = rowData.replace(/counterIndex/g, rowLen);
# 	rowData = rowData.replace(/counter/g, rowLen - 1);
# 	$(elem).before($('<tr></tr>').append(rowData));
# 	bindDeptAutoComplete();
# }
# function showHistoryAmount(approvalId) {
# 	$('#myModal4 #modalTitle').html("Amount Edit History");
# 	$.ajax({
# 		type : "GET",
# 		url : "showHistoryAmount",
# 		data : {
# 			'administrativeApproval.approvalId' : approvalId
# 		},
# 		beforeSend : function() {
# 			$('#myModal4 .modal-body').html('Loading..');
# 		},
# 		success : function(msg) {
# 			$('#myModal4 .modal-body').html(msg);
# 		}
# 	});
# 	$('#myModal4').modal('show');
# }
#           </script>
#           <div class="modal fade" id="myModal4" role="dialog">
#            <div class="modal-dialog modal-md">
#             <div class="modal-content">
#              <div class="modal-header">
#               <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#                <span aria-hidden="true">
#                 ×
#                </span>
#               </button>
#               <h4 class="modal-title">
#                <span class="label label-primary" id="modalTitle">
#                </span>
#               </h4>
#              </div>
#              <div class="modal-body">
#              </div>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </td>
#      <td width="4px">
#      </td>
#     </tr>
#     <tr>
#      <td colspan="3" style="height: 15px;">
#      </td>
#     </tr>
#     <tr>
#      <td colspan="3" style="background-color: #01458E;">
#       <table>
#        <tbody>
#         <tr>
#          <td background="../resources/images/th.jpg" bgcolor="#CCCCCC" height="22" valign="baseline" width="80%">
#           <div align="left" style="padding: 10px 5px 5px 5px; color: #FFFFFF;">
#            Version 17.7.43
#           </div>
#          </td>
#          <td background="../resources/images/th.jpg" bgcolor="#CCCCCC" height="20%" valign="baseline" width="20%">
#           <div align="right">
#            <button class="btn btn-helpdesk btn-sm" id="toggle-bp" title="Chatbot" type="button">
#             <i aria-hidden="true" class="fa fa-comments-o fa-lg">
#             </i>
#            </button>
#            <button class="btn btn-success btn-sm" onclick="gotoUMDownload()" title="User Manual" type="button">
#             <i class="fa fa-book">
#             </i>
#             UM
#            </button>
#            <button class="btn btn-helpdesk btn-sm" onclick="gotoHelpDisk('ad.rdm')" title="Technical Support" type="button">
#             <span class="glyphicon glyphicon-question-sign">
#             </span>
#             TSG
#            </button>
#            <a href="http://kran.co.in" rel="noopener noreferrer" target="_blank">
#             <img align="middle" alt="KRAN" src="../resources/images/kranitlogo.png"/>
#            </a>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <!-- By Sujith -- For Help Desk -->
#       <div class="custom-modal fade" data-backdrop="static" data-keyboard="false" id="myModalTSG" role="dialog">
#        <div class="custom-modal-dialog" style="width: 90%;">
#         <!-- Modal content -->
#         <div class="custom-modal-content">
#          <div class="custom-modal-header" style="background-color: #13498d;">
#           <button class="close" data-dismiss="modal" type="button">
#            ×
#           </button>
#           <img src="../resources/images/header.png"/>
#           <img src="../resources/images/assured_logo.png" style="width: 12%; float: right;"/>
#          </div>
#          <div class="custom-modal-body" style="overflow: auto; height: 650px;">
#           <iframe frameborder="0" height="100%" id="modalframe" src="about:blank" style="height: 535px;" width="100%">
#           </iframe>
#          </div>
#          <div class="custom-modal-footer" style="background-color: #13498d;">
#           <img align="middle" alt="KRAN" src="../resources/images/kranitlogo.png"/>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal fade" data-keyboard="false" id="userManualModal" role="dialog" style="display: none;">
#        <div class="modal-dialog modal-lg">
#         <div class="modal-content">
#          <div class="modal-header" style="background-color: #1469A0; color: #FFF;">
#           <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#           </button>
#           <h4 class="modal-title">
#            Manuals &amp; Tutorials
#           </h4>
#          </div>
#          <div class="modal-body">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal" id="userManualModalBS4" role="dialog" tabindex="-1">
#        <div class="modal-dialog modal-lg" role="document">
#         <div class="modal-content">
#          <div class="modal-header">
#           <h4 class="modal-title">
#            Manuals &amp; Tutorials
#           </h4>
#           <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#           </button>
#          </div>
#          <div class="modal-body">
#          </div>
#         </div>
#        </div>
#       </div>
#       <script type="text/javascript">
#        document.getElementById("toggle-bp").addEventListener("click", function() {
# 		window.botpressWebChat.sendEvent({
# 			type : webchatOpen ? "hide" : "show"
# 		})
# 	})
#
# 	var bootstrap_enabled = (typeof $().emulateTransitionEnd == 'function');
# 	if (!bootstrap_enabled) {
# 		$("#userManualLink").hide();
# 		$.getScript('../resources/bootstrap/js/bootstrap.min.js');
# 	}
#
# 	$(document).ready(function() {
# 		$('#myModalTSG #modalframe').height($(window).height() - 200);
# 	});
#
# 	function gotoHelpDisk(hierarchyCode) {
# 		var pageTitle = document.title;
# 		var titleName = "Mr.";
# 		var empName = "Assistant";
# 		var lastName = "rdm";
# 		if (lastName != null) {
# 			var userName = titleName + ' ' + empName + ' ' + lastName;
# 		} else {
# 			var userName = titleName + ' ' + empName;
# 		}
# 		var seatName = "Assistant Department";
# 		var controllingOffice = "Revenue and Disaster Management Department";
# 		var seatUserAllotId = "18914";
# 		var mobile = "9707133011";
# 		var email = "";
#
# 		var myJSON = {
# 			"userName" : userName,
# 			"seatName" : seatName,
# 			"controllingOffice" : controllingOffice,
# 			"seatUserAllotId" : seatUserAllotId,
# 			"hierarchyCode" : hierarchyCode,
# 			"pageTitle" : pageTitle,
# 			"mobile" : mobile,
# 			"email" : email,
# 			"finassam" :'finassam'
# 		};
# 		var strJSON = encodeURIComponent(JSON.stringify(myJSON));
# 		$('#modalframe').attr('src',
# 				'/helpdesk/gotoHDeskFromApp?strJSON=' + strJSON);
# 		$('#myModalTSG').modal('show');
# 	}
#
# 	function gotoUserManuals() {
# 		var subtab = 'aaOngoing';
# 		if (subtab == 'dashboardDDO') {
# 			$.ajax({
# 				type : "GET",
# 				url : "getUserManualList",
# 				beforeSend : function() {
# 					$('#userManualModalBS4 .modal-body').html('Loading..');
# 				},
# 				success : function(msg) {
# 					$('#userManualModalBS4 .modal-body').html(msg);
# 				}
# 			});
# 			$('#userManualModalBS4').modal('show');
# 		} else {
# 			$.ajax({
# 				type : "GET",
# 				url : "getUserManualList",
# 				beforeSend : function() {
# 					$('#userManualModal .modal-body').html('Loading..');
# 				},
# 				success : function(msg) {
# 					$('#userManualModal .modal-body').html(msg);
# 				}
# 			});
# 			$('#userManualModal').modal('show');
# 		}
# 		return false;
# 	}
#
# 	function gotoUMDownload() {
# 			$.ajax({
# 				type : "GET",
# 				url : "gotoUMDownload",
# 				beforeSend : function() {
#
#
# 					$('#userManualModal .modal-body').html('Loading..');
# 				},
# 				success : function(msg) {
# 					$('#userManualModal .modal-body').html(msg);
# 				}
# 			});
# 			$('#userManualModal').modal('show');
# 	}
#
# 	function gotoFeedbackForm() {
# 		window.open("https://forms.gle/V2rio69ugYZS3zR68","_blank");
# 	}
#       </script>
#       <script type="text/javascript">
#        function gotoHelpDisk(hierarchyCode) {
# 		var pageTitle = document.title;
# 		var titleName = "Mr.";
# 		var empName = "Assistant";
# 		var lastName = "rdm";
# 		if (lastName != null) {
# 			var userName = titleName + ' ' + empName + ' ' + lastName;
# 		} else {
# 			var userName = titleName + ' ' + empName;
# 		}
# 		var seatName = "Assistant Department";
# 		var controllingOffice = "Revenue and Disaster Management Department";
# 		var seatUserAllotId = "18914";
# 		var mobile = "9707133011";
# 		var email = "";
#
# 		var myJSON = {
# 			"userName" : userName,
# 			"seatName" : seatName,
# 			"controllingOffice" : controllingOffice,
# 			"seatUserAllotId" : seatUserAllotId,
# 			"hierarchyCode" : hierarchyCode,
# 			"pageTitle" : pageTitle,
# 			"mobile" : mobile,
# 			"email" : email,
# 			"finassam" :'finassam'
# 		};
# 		var strJSON = encodeURIComponent(JSON.stringify(myJSON));
# 		$('#modalframe').attr('src',
# 				'/helpdesk/gotoHDeskFromApp?strJSON=' + strJSON);
# 		$('#myModalTSG').modal('show');
# 	}
#       </script>
#       <style>
#        .btnhelpdesk-sm, .btnhelpdesk-group-sm>.btnhelpdesk {
# 	padding: 5px 10px;
# 	font-size: 12px;
# 	line-height: 1.5;
# 	border-radius: 3px;
# }
#
# .btnhelpdesk {
# 	display: inline-block;
# 	margin-bottom: 0;
# 	font-weight: normal;
# 	text-align: center;
# 	vertical-align: middle;
# 	-ms-touch-action: manipulation;
# 	touch-action: manipulation;
# 	cursor: pointer;
# 	background-image: none;
# 	border: 1px solid transparent;
# 	border-top-color: transparent;
# 	border-right-color: transparent;
# 	border-bottom-color: transparent;
# 	border-left-color: transparent;
# 	white-space: nowrap;
# 	padding: 6px 12px;
# 	font-size: 14px;
# 	line-height: 1.42857143;
# 	border-radius: 4px;
# 	-webkit-user-select: none;
# 	-moz-user-select: none;
# 	-ms-user-select: none;
# 	user-select: none;
# }
#
# .custom-modal-body {
# 	position: relative;
# 	padding: 15px;
# }
#
# .custom-modal-content {
# 	-webkit-box-shadow: 0 5px 15px rgba(0, 0, 0, 0.5);
# 	box-shadow: 0 5px 15px rgba(0, 0, 0, 0.5);
# }
#
# .custom-modal-content {
# 	position: relative;
# 	background-color: #fff;
# 	border: 1px solid #999;
# 	border: 1px solid rgba(0, 0, 0, 0.2);
# 	border-radius: 6px;
# 	-webkit-box-shadow: 0 3px 9px rgba(0, 0, 0, 0.5);
# 	box-shadow: 0 3px 9px rgba(0, 0, 0, 0.5);
# 	-webkit-background-clip: padding-box;
# 	background-clip: padding-box;
# 	outline: 0;
# }
#
# .custom-modal-open .modal {
# 	overflow-x: hidden;
# 	overflow-y: auto;
# }
#
# .custom-modal {
# 	display: none;
# 	overflow: hidden;
# 	position: fixed;
# 	top: 0;
# 	right: 0;
# 	bottom: 0;
# 	left: 0;
# 	z-index: 1050;
# 	-webkit-overflow-scrolling: touch;
# 	outline: 0;
# }
#
# .custom-modal-header {
# 	padding: 15px;
# 	border-bottom: 1px solid #e5e5e5;
# }
#
# .custom-modal-header .close {
# 	margin-top: -2px;
# }
#
# .custom-modal-footer {
# 	padding: 15px;
# 	text-align: right;
# 	border-top: 1px solid #e5e5e5;
# }
#
# .close:hover, .close:focus {
# 	color: #000;
# 	text-decoration: none;
# 	cursor: pointer;
# 	opacity: .5;
# 	filter: alpha(opacity = 50);
# }
#
# button.close {
# 	padding: 0;
# 	cursor: pointer;
# 	background: transparent;
# 	border: 0;
# 	-webkit-appearance: none;
# }
#
# .close {
# 	float: right;
# 	font-size: 21px;
# 	font-weight: bold;
# 	line-height: 1;
# 	color: #000;
# 	text-shadow: 0 1px 0 #fff;
# 	opacity: 1;
# 	filter: alpha(opacity = 20);
# }
#
# .custom-modal-dialog {
# 	margin: 30px auto;
# }
#
# .custom-modal-dialog {
# 	position: relative;
# 	width: auto;
# 	margin: 5%;
# }
#
# .custom-modal-backdrop.fade {
# 	opacity: 0;
# 	filter: alpha(opacity = 0);
# }
#
# .custom-modal-backdrop.in {
# 	opacity: .5;
# 	filter: alpha(opacity = 50);
# }
#
# .custom-modal-backdrop {
# 	position: fixed;
# 	top: 0;
# 	right: 0;
# 	bottom: 0;
# 	left: 0;
# 	z-index: 1040;
# 	background-color: #000;
# }
#       </style>
#       <!-- By Sujith -- For Help Desk -->
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <div id="bp-web-widget">
#    <iframe class="bp-widget-web bp-widget-widget bp-widget-hidden" frameborder="0" id="bp-widget" src="https://finanalytics.assam.gov.in/botpress/lite/helpdesk/?m=channel-web&amp;v=Embedded&amp;options=%7B%22config%22%3A%7B%22host%22%3A%22https%3A%2F%2Ffinanalytics.assam.gov.in%2Fbotpress%22%2C%22botId%22%3A%22helpdesk%22%2C%22userId%22%3A%2218914%22%2C%22botName%22%3A%22Helpdesk%22%2C%22enableTranscriptDownload%22%3Afalse%2C%22showConversationsButton%22%3Afalse%2C%22hideWidget%22%3Atrue%2C%22useSessionStorage%22%3Atrue%7D%7D" title="Helpdesk">
#    </iframe>
#   </div>
#   <div class="modal fade centered-modal" id="surveyModal" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-body">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="anylinkmenu" style="width: 150px; background: rgb(255, 255, 255);">
#    <ul>
#     <li>
#      <a href="javascript: editProfile()" target="_self">
#       Profile
#      </a>
#     </li>
#     <li>
#      <a href="javascript:TINY.box.show({iframe:'/assamfinance/changePasswd',width:650,height:500,boxid : 'frameless' })" target="_self">
#       Change Password
#      </a>
#     </li>
#     <li>
#      <a href="javascript: passwordHistory()" target="_self">
#       Password History
#      </a>
#     </li>
#     <li>
#      <a href="javascript:TINY.box.show({iframe:'deleteProfile',width:600,height:450,boxid : 'frameless' })" target="_self">
#       Deactivate Account
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="anylinkshadow" style="width: 150px; height: 92px; opacity: 0.3;">
#   </div>
#  </body>
# </html>
#
# ['Name of the Scheme/Project proposed*', 'Existing AA No.*', 'Financial Year*', '', 'Proposal No.*', 'Issued Date*', 'Validity*', 'Ddo Details*', 'Ongoing Remarks', 'Existing AA Document*', 'DFC (Minutes of the Departmental Finance Committee)', 'Utilization Certificate', 'Other Documents( if required )']

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Your extraction dictionary mapping column names to CSS fingerprint strings
extraction_dict = {
    'Name of the Scheme/Project proposed': 'div class="col-sm-18"', 
    'Whether scheme/project is new/ongoing': 'div class="col-sm-6"', 
    'Whether the scheme is funded by NABARD': 'div class="col-sm-6"', 
    'Proposal Number': 'div class="form-group"', 
    'Proposal Date': 'div class="col-sm-6"', 
    'Issued Number': 'div class="form-group"', 
    'Valid Upto(Auto generated after Issue)': 'div class="col-sm-6"', 
    'Admin Department File Number': 'div class="col-sm-6"', 
    'Brief nature of the scheme/project and the time period required for implementation/execution': 'div class="col-sm-6"', 
    'Aim, objectives and benefit expected from the scheme/project': 'div class="col-sm-6"', 
    'Whether included in the priority list approved by the Departmental Minister': 'div class="col-sm-6"', 
    'Ddo Details': 'div class="col-sm-6"', 
    'Common Proposal(If the documents in the Proposal Needs a Referance in other Proposals)': 'div class="col-sm-6"', 
    'Project Profile Id:': 'div class="col-sm-6"', 
    'Project Classification :': 'span class="text-success h6"', 
    'Type of the project:': '<div class="col-lg-12">', 
    'Opening and Closing dates:': 'div class="col-sm-6"', 
    'Project Beneficiary :': 'div class="col-sm-6" style="margin-top: 10px;"', 
    'Procurement Activity Type:': 'div class="col-sm-8" style="margin-top: 10px;"', 
    'Beneficiary Share Amount': 'div class="col-sm-12"', 
    'Whether the scheme is centrally sponsored scheme': 'div class="col-sm-12"', 
    'Total Administrative Approval Amount': 'div class="col-sm-12"', 
    'DDO Code': 'div class="col-sm-6"', 
    'Treasury Name(Auto generated)': 'div class="col-sm-6"', 
    'DDO Office Name(Auto generated)': 'div class="col-sm-18"', 
    'Permission from local bodies for construction/establishment wherever necessary': 'div class="col-sm-18"', 
    'Non-Objection certificate': 'div class="col-sm-18"', 
    'Non-Duplicity certificate': 'div class="col-sm-18"', 
    'Views of Department': 'div class="col-sm-18"', 
    "Details information in case of observation made by T&D in last year's endorsement": 'div class="form-group"', 
    'Sanction letter copy of GOI in case of Central Sector Schemes': 'div class="col-sm-6"', 
    'Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR': 'div class="col-sm-18"', 
    'Funding pattern of the scheme': 'div class="col-sm-6"', 
    'The year from which the scheme is being implemented': 'div class="col-sm-6"', 
    'The quantum of central share allocated/released for the year along with the supporting document': 'div class="col-sm-6"', 
    'The criteria of proposing the amount of state share': 'div class="col-sm-6"'
}

def pattern_to_selector(pattern):
    """
    Converts a string like 'div class="col-sm-18"' or '<div class="col-lg-12">' 
    into a CSS selector, e.g. 'div.col-sm-18' or 'div.col-lg-12'.
    """
    pattern = pattern.strip()
    if pattern.startswith("<") and pattern.endswith(">"):
        pattern = pattern[1:-1].strip()
    tag_match = re.match(r'^(\w+)', pattern)
    tag = tag_match.group(1) if tag_match else ""
    class_match = re.search(r'class="([^"]+)"', pattern)
    if class_match:
        classes = class_match.group(1).split()
        selector = tag + ''.join(['.' + cls for cls in classes])
    else:
        selector = tag
    return selector

def extract_value_for_key(soup, key, pattern):
    """
    Finds the text node containing the label (key) and returns the text from the first
    subsequent element that matches the CSS fingerprint derived from pattern.
    """
    label_element = soup.find(text=re.compile(re.escape(key)))
    if label_element:
        selector = pattern_to_selector(pattern)
        def matches(tag):
            if not tag.name:
                return False
            sel_parts = selector.split('.')
            sel_tag = sel_parts[0]
            sel_classes = sel_parts[1:] if len(sel_parts) > 1 else []
            if tag.name != sel_tag:
                return False
            tag_classes = tag.get("class", [])
            return all(cls in tag_classes for cls in sel_classes)
        candidate = label_element.find_next(matches)
        if candidate:
            # Clean the extracted text by replacing multiple whitespace/newlines with a single space
            return re.sub(r'\s+', ' ', candidate.get_text(strip=True))
    return None

def main():
    # Path to your test HTML file
    test_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2023-24\AA-05-2023-24-6741.html"
    if not os.path.exists(test_file):
        print(f"File not found: {test_file}")
        return

    with open(test_file, 'r', encoding='utf-8') as file:
        file_contents = file.read()

    soup = BeautifulSoup(file_contents, 'html.parser')
    
    # Pre-clean every text node in the soup to remove newlines and extra spaces
    for text_node in soup.find_all(text=True):
        cleaned = re.sub(r'\s+', ' ', text_node)
        text_node.replace_with(cleaned)
    
    # Extract data using the extraction dictionary
    extracted_data = {}
    for key, pattern in extraction_dict.items():
        value = extract_value_for_key(soup, key, pattern)
        extracted_data[key] = value

    # Create a one-row DataFrame from the extracted data
    df = pd.DataFrame([extracted_data])
    print("Extracted DataFrame:")
    print(df)
    
    # Optionally, save the DataFrame to a CSV file
    df.to_csv("extracted_data.csv", index=False)
    print("Data saved to extracted_data.csv")

if __name__ == "__main__":
    main()
# Out:
# Extracted DataFrame:
#                  Name of the Scheme/Project proposed  \
# 0  Repairing & Renovation Jalah No-1 PWSS damaged...
#
#   Whether scheme/project is new/ongoing  \
# 0                           New project
#
#   Whether the scheme is funded by NABARD     Proposal Number Proposal Date  \
# 0                                     No  AA-05-2023-24-6741    26-06-2023
#
#            Issued Number Valid Upto(Auto generated after Issue)  \
# 0  AA/05_2023-24(I)_5242                                   None
#
#   Admin Department File Number  \
# 0                       289051
#
#   Brief nature of the scheme/project and the time period required for implementation/execution  \
# 0                                         FDR SCHEME
#
#   Aim, objectives and benefit expected from the scheme/project  ...  \
# 0             Repairing & Renovation Jalah No-1 PWSS            ...
#
#   Non-Objection certificate       Non-Duplicity certificate  \
# 0                            Attached DocumentsPHED, KAMRUP
#
#   Views of Department  \
# 0
#
#   Details information in case of observation made by T&D in last year's endorsement  \
# 0                                                ---
#
#   Sanction letter copy of GOI in case of Central Sector Schemes  \
# 0                                                 No
#
#   Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR  \
# 0
#
#   Funding pattern of the scheme  \
# 0
#
#   The year from which the scheme is being implemented  \
# 0
#
#   The quantum of central share allocated/released for the year along with the supporting document  \
# 0
#
#   The criteria of proposing the amount of state share
# 0
#
# [1 rows x 36 columns]
# Data saved to extracted_data.csv
# C:\Users\saura\AppData\Local\Temp\ipykernel_34312\2219525505.py:101: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for text_node in soup.find_all(text=True):
# C:\Users\saura\AppData\Local\Temp\ipykernel_34312\2219525505.py:69: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   label_element = soup.find(text=re.compile(re.escape(key)))

# %%
# V1 of all page extractor

import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Extraction dictionary mapping column names to a string fingerprint for the element.
extraction_dict = { 'Name of the Scheme/Project proposed': 'div class="col-sm-18"', 
    'Whether scheme/project is new/ongoing': 'div class="col-sm-6"', 
    'Whether the scheme is funded by NABARD': 'div class="col-sm-6"', 
    'Proposal Number': 'div class="form-group"', 
    'Proposal Date': 'div class="col-sm-6"', 
    'Issued Number': 'div class="form-group"', 
    'Valid Upto': 'div class="col-sm-6"', 
    'Admin Department File Number': 'div class="col-sm-6"', 
    'Brief nature of the scheme/project and the time period required for implementation/execution': 'div class="col-sm-6"', 
    'Aim, objectives and benefit expected from the scheme/project': 'div class="col-sm-6"', 
    'Whether included in the priority list approved by the Departmental Minister': 'div class="col-sm-6"', 
    'Ddo Details': 'div class="col-sm-6"', 
    'Common Proposal': 'div class="col-sm-6"', 
    'Project Profile Id:': 'div class="col-sm-6"', 
    'Project Classification': 'span class="text-success h6"', 
    'Type of the project:': '<div class="col-lg-12">', 
    'Opening and Closing dates:': 'div class="col-sm-6"', 
    'Project Beneficiary :': 'div class="col-sm-6" style="margin-top: 10px;"', 
    'Procurement Activity Type:': 'div class="col-sm-8" style="margin-top: 10px;"', 
    'Beneficiary Share Amount(In Lakhs)': 'div class="col-sm-12"', 
    'Whether the scheme is centrally sponsored scheme': 'div class="col-sm-12"', 
    'Total Administrative Approval Amount (Project Cost)(In Lakhs)': 'div class="col-sm-12"', 
    'DDO Code': 'div class="col-sm-6"', 
    'Treasury Name': 'div class="col-sm-6"', 
    'DDO Office Name': 'div class="col-sm-18"', 
    'Permission from local bodies for construction/establishment wherever necessary': 'div class="col-sm-18"', 
    'Non-Objection certificate': 'div class="col-sm-18"', 
    'Non-Duplicity certificate': 'div class="col-sm-18"', 
    'Views of Department': 'div class="col-sm-18"', 
    'Details information in case of observation made by T&D in last year\'s endorsement': 'div class="form-group"', 
    'Sanction letter copy of GOI in case of Central Sector Schemes': 'div class="col-sm-6"', 
    'Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR': 'div class="col-sm-18"', 
    'Funding pattern of the scheme': 'div class="col-sm-6"', 
    'The year from which the scheme is being implemented': 'div class="col-sm-6"', 
    'The quantum of central share allocated/released for the year along with the supporting document': 'div class="col-sm-6"', 
    'The criteria of proposing the amount of state share': 'div class="col-sm-6"'
}

def pattern_to_selector(pattern):
    """
    Converts a string like 'div class="col-sm-18"' or '<div class="col-lg-12">' 
    into a CSS selector (e.g. 'div.col-sm-18' or 'div.col-lg-12').
    """
    pattern = pattern.strip()
    if pattern.startswith("<") and pattern.endswith(">"):
        pattern = pattern[1:-1].strip()
    tag_match = re.match(r'^(\w+)', pattern)
    tag = tag_match.group(1) if tag_match else ""
    class_match = re.search(r'class="([^"]+)"', pattern)
    if class_match:
        classes = class_match.group(1).split()
        selector = tag + ''.join(['.' + cls for cls in classes])
    else:
        selector = tag
    return selector

def extract_value_for_key(soup, key, pattern):
    """
    Finds the text node that matches the label (key) and then returns the text from the first subsequent element
    that matches the CSS fingerprint derived from pattern.
    """
    label_element = soup.find(text=re.compile(re.escape(key)))
    if label_element:
        selector = pattern_to_selector(pattern)
        def matches(tag):
            if not tag.name:
                return False
            sel_parts = selector.split('.')
            sel_tag = sel_parts[0]
            sel_classes = sel_parts[1:] if len(sel_parts) > 1 else []
            if tag.name != sel_tag:
                return False
            tag_classes = tag.get("class", [])
            return all(cls in tag_classes for cls in sel_classes)
        candidate = label_element.find_next(matches)
        if candidate:
            # Clean the extracted text by reducing whitespace/newlines to single spaces.
            return re.sub(r'\s+', ' ', candidate.get_text(strip=True))
    return None

def process_file(file_path):
    """
    Processes one HTML file: cleans the text nodes, extracts data based on extraction_dict,
    and returns a dictionary with the extracted values.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        file_contents = file.read()

    soup = BeautifulSoup(file_contents, 'html.parser')
    
    # Pre-clean every text node to remove extra whitespace/newlines.
    for text_node in soup.find_all(text=True):
        cleaned = re.sub(r'\s+', ' ', text_node)
        text_node.replace_with(cleaned)
    
    extracted_data = {}
    for key, pattern in extraction_dict.items():
        value = extract_value_for_key(soup, key, pattern)
        extracted_data[key] = value
    return extracted_data

def main():
    # Set the root folder that contains subfolders named as financial years ("YYYY-YY")
    root_folder = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages"
    all_data = []
    
    # Loop over each subfolder in the root folder.
    for subfolder in os.listdir(root_folder):
        subfolder_path = os.path.join(root_folder, subfolder)
        # Check if it's a directory and matches the financial year pattern
        if os.path.isdir(subfolder_path) and re.match(r'\d{4}-\d{2}', subfolder):
            financial_year = subfolder  # e.g. "2021-22"
            # Process both .html and .htm files in this subfolder
            for file in os.listdir(subfolder_path):
                if file.lower().endswith((".html", ".htm")):
                    file_path = os.path.join(subfolder_path, file)
                    data = process_file(file_path)
                    # Add the financial year and optionally the source file path
                    data["Financial Year"] = financial_year
                    data["Source File"] = file_path
                    all_data.append(data)
    
    # Create a single DataFrame from all extracted records.
    df = pd.DataFrame(all_data)
    print("Extracted DataFrame (first few rows):")
    print(df.head())
    
    # Save the DataFrame to a CSV file.
    output_csv = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\data\all_extracted_data.csv"
    df.to_csv(output_csv, index=False)
    print(f"Data saved to {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_25628\3426271400.py:100: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for text_node in soup.find_all(text=True):
# C:\Users\saura\AppData\Local\Temp\ipykernel_25628\3426271400.py:70: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   label_element = soup.find(text=re.compile(re.escape(key)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 142
#     139     print(f"Data saved to {output_csv}")
#     141 if __name__ == "__main__":
# --> 142     main()
#
# Cell In[5], line 125, in main()
#     123 if file.lower().endswith((".html", ".htm")):
#     124     file_path = os.path.join(subfolder_path, file)
# --> 125     data = process_file(file_path)
#     126     # Add the financial year and optionally the source file path
#     127     data["Financial Year"] = financial_year
#
# Cell In[5], line 94, in process_file(file_path)
#      89 def process_file(file_path):
#      90     """
#      91     Processes one HTML file: cleans the text nodes, extracts data based on extraction_dict,
#      92     and returns a dictionary with the extracted values.
#      93     """
# ---> 94     with open(file_path, 'r', encoding='utf-8') as file:
#      95         file_contents = file.read()
#      97     soup = BeautifulSoup(file_contents, 'html.parser')
#
# File c:\Users\saura\anaconda3\envs\cdl-env\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test single - page script

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Extraction dictionary: keys are the labels (parentheses will be removed in matching)
extraction_dict = {
    'Name of the Scheme/Project proposed': 'div class="col-sm-18"', 
    'Whether scheme/project is new/ongoing': 'div class="col-sm-6"', 
    'Whether the scheme is funded by NABARD': 'div class="col-sm-6"', 
    'Proposal Number': 'div class="form-group"', 
    'Proposal Date': 'div class="col-sm-6"', 
    'Issued Number': 'div class="form-group"', 
    'Valid Upto': 'div class="col-sm-6"', 
    'Admin Department File Number': 'div class="col-sm-6"', 
    'Brief nature of the scheme/project and the time period required for implementation/execution': 'div class="col-sm-6"', 
    'Aim, objectives and benefit expected from the scheme/project': 'div class="col-sm-6"', 
    'Whether included in the priority list approved by the Departmental Minister': 'div class="col-sm-6"', 
    'Ddo Details': 'div class="col-sm-6"', 
    'Common Proposal': 'div class="col-sm-6"', 
    'Project Profile Id:': 'div class="col-sm-6"', 
    'Project Classification': 'span class="text-success h6"', 
    'Type of the project:': '<div class="col-lg-12">', 
    'Opening and Closing dates:': 'div class="col-sm-6"', 
    'Project Beneficiary :': 'div class="col-sm-6" style="margin-top: 10px;"', 
    'Procurement Activity Type:': 'div class="col-sm-8" style="margin-top: 10px;"', 
    'Beneficiary Share Amount(In Lakhs)': 'div class="col-sm-12"', 
    'Whether the scheme is centrally sponsored scheme': 'div class="col-sm-12"', 
    'Total Administrative Approval Amount (Project Cost)(In Lakhs)': 'div class="col-sm-12"', 
    'DDO Code': 'div class="col-sm-6"', 
    'Treasury Name': 'div class="col-sm-6"', 
    'DDO Office Name': 'div class="col-sm-18"', 
    'Permission from local bodies for construction/establishment wherever necessary': 'div class="col-sm-18"', 
    'Non-Objection certificate': 'div class="col-sm-18"', 
    'Non-Duplicity certificate': 'div class="col-sm-18"', 
    'Views of Department': 'div class="col-sm-18"', 
    "Details information in case of observation made by T&D in last year's endorsement": 'div class="form-group"', 
    'Sanction letter copy of GOI in case of Central Sector Schemes': 'div class="col-sm-6"', 
    'Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR': 'div class="col-sm-18"', 
    'Funding pattern of the scheme': 'div class="col-sm-6"', 
    'The year from which the scheme is being implemented': 'div class="col-sm-6"', 
    'The quantum of central share allocated/released for the year along with the supporting document': 'div class="col-sm-6"', 
    'The criteria of proposing the amount of state share': 'div class="col-sm-6"'
}

def pattern_to_selector(pattern):
    """
    Converts a string like 'div class="col-sm-18"' or '<div class="col-lg-12">' 
    into a CSS selector such as 'div.col-sm-18' or 'div.col-lg-12'.
    """
    pattern = pattern.strip()
    if pattern.startswith("<") and pattern.endswith(">"):
        pattern = pattern[1:-1].strip()
    tag_match = re.match(r'^(\w+)', pattern)
    tag = tag_match.group(1) if tag_match else ""
    class_match = re.search(r'class="([^"]+)"', pattern)
    if class_match:
        classes = class_match.group(1).split()
        selector = tag + ''.join(['.' + cls for cls in classes])
    else:
        selector = tag
    return selector

def extract_value_for_key(soup, key, pattern):
    """
    Matches a text node containing the cleaned key (parentheses removed) in a case-insensitive way,
    then returns the text from the first subsequent element that matches the CSS selector derived from pattern.
    """
    # Remove any parentheses and contained text from the key
    cleaned_key = re.sub(r'\s*\([^)]*\)', '', key).strip()
    label_element = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))
    if label_element:
        selector = pattern_to_selector(pattern)
        def matches(tag):
            if not tag.name:
                return False
            sel_parts = selector.split('.')
            sel_tag = sel_parts[0]
            sel_classes = sel_parts[1:] if len(sel_parts) > 1 else []
            if tag.name != sel_tag:
                return False
            tag_classes = tag.get("class", [])
            return all(cls in tag_classes for cls in sel_classes)
        candidate = label_element.find_next(matches)
        if candidate:
            return re.sub(r'\s+', ' ', candidate.get_text(strip=True))
    return None

def process_file(file_path):
    """
    Processes one HTML file: cleans text nodes, extracts data using extraction_dict,
    and returns a dictionary of the extracted values.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        file_contents = file.read()

    soup = BeautifulSoup(file_contents, 'html.parser')
    
    # Pre-clean every text node to remove extra whitespace/newlines
    for text_node in soup.find_all(text=True):
        cleaned = re.sub(r'\s+', ' ', text_node)
        text_node.replace_with(cleaned)
    
    extracted_data = {}
    for key, pattern in extraction_dict.items():
        value = extract_value_for_key(soup, key, pattern)
        extracted_data[key] = value
    return extracted_data

def main():
    # Specify the test HTML file path.
    test_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2023-24\AA-05-2023-24-6741.html"
    # Manually set a financial year for testing (or extract it from the folder name)
    financial_year = "2021-22"
    
    if not os.path.exists(test_file):
        print(f"File not found: {test_file}")
        return
    
    data = process_file(test_file)
    data["Financial Year"] = financial_year
    data["Source File"] = test_file
    
    # Create a DataFrame with one row using the extracted data.
    df = pd.DataFrame([data])
    print("Extracted DataFrame:")
    print(df)
    
    # Optionally, save the DataFrame to a CSV file.
    output_csv = "single_file_extracted_data.csv"
    df.to_csv(output_csv, index=False)
    print(f"Data saved to {output_csv}")

if __name__ == "__main__":
    main()
# Out:
# Extracted DataFrame:
#                  Name of the Scheme/Project proposed  \
# 0  Repairing & Renovation Jalah No-1 PWSS damaged...
#
#   Whether scheme/project is new/ongoing  \
# 0                           New project
#
#   Whether the scheme is funded by NABARD     Proposal Number Proposal Date  \
# 0                                     No  AA-05-2023-24-6741    26-06-2023
#
#            Issued Number  Valid Upto Admin Department File Number  \
# 0  AA/05_2023-24(I)_5242  26-06-2026                       289051
#
#   Brief nature of the scheme/project and the time period required for implementation/execution  \
# 0                                         FDR SCHEME
#
#   Aim, objectives and benefit expected from the scheme/project  ...  \
# 0             Repairing & Renovation Jalah No-1 PWSS            ...
#
#   Views of Department  \
# 0
#
#   Details information in case of observation made by T&D in last year's endorsement  \
# 0                                                ---
#
#   Sanction letter copy of GOI in case of Central Sector Schemes  \
# 0                                                 No
#
#   Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR  \
# 0
#
#   Funding pattern of the scheme  \
# 0
#
#   The year from which the scheme is being implemented  \
# 0
#
#   The quantum of central share allocated/released for the year along with the supporting document  \
# 0
#
#   The criteria of proposing the amount of state share Financial Year  \
# 0                                                            2021-22
#
#                                          Source File
# 0  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
#
# [1 rows x 38 columns]
# Data saved to single_file_extracted_data.csv
# C:\Users\saura\AppData\Local\Temp\ipykernel_34312\351325366.py:100: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for text_node in soup.find_all(text=True):
# C:\Users\saura\AppData\Local\Temp\ipykernel_34312\351325366.py:71: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   label_element = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))

# %% [markdown]
# Extract basic html info

# %%
import pandas as pd
from bs4 import BeautifulSoup

html_doc = open(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2023-24\AA-05-2023-24-6742.html')
# html_doc = open(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2017-18\AA-05-2017-18-0001.html')
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Public Finance Management System - Government of Assam" name="description"/>
#   <link href="/assamfinance/resources/icons/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/assamfinance/resources/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/assamfinance/resources/style/kranstyle.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/style/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <!-- BOOTSTRAP -->
#   <link href="/assamfinance/resources/bootstrap/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <!-- CALENDAR  -->
#   <link href="/assamfinance/resources/js/calendar/calendar.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/bootstrap/css/bootstrap-datetimepicker.min.css" media="screen" rel="stylesheet"/>
#   <script src="/assamfinance/resources/js/jquery-1.9.1.js">
#   </script>
#   <script src="/assamfinance/resources/js/jquery-ui.js">
#   </script>
#   <script src="/assamfinance/resources/bootstrap/js/bootstrap.min.js">
#   </script>
#   <!-- TINY-BOX  -->
#   <script src="/assamfinance/resources/js/tinybox/tinybox.js" type="text/javascript">
#   </script>
#   <script src="/assamfinance/resources/js/calendar/calendar.js">
#   </script>
#   <script charset="UTF-8" src="/assamfinance/resources/bootstrap/js/bootstrap-datetimepicker.js" type="text/javascript">
#   </script>
#   <!-- TOOL-TIP  -->
#   <link href="/assamfinance/resources/js/menu/css/dropdown/dropdown.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/menu/css/dropdown/dropdown.vertical.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/menu/css/dropdown/themes/default/default.ultimate.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/tooltipster-master/css/tooltipster.css" rel="stylesheet" type="text/css"/>
#   <link href="/assamfinance/resources/js/tooltipster-master/css/themes/tooltipster-noir.css" rel="stylesheet" type="text/css"/>
#   <script src="/assamfinance/resources/js/tooltipster-master/js/jquery.tooltipster.min.js" type="text/javascript">
#   </script>
#   <script src="/assamfinance/resources/js/jquery.slimscroll.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="../resources/js/ckeditor/ckeditor.js?version=2" type="text/javascript">
#   </script>
#   <style>
#    .cke{visibility:hidden;}
#   </style>
#   <script charset="utf-8" src="../resources/js/ckeditor5-build-classic/ckeditor.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .ck-hidden{display:none!important}.ck.ck-reset,.ck.ck-reset_all,.ck.ck-reset_all *{box-sizing:border-box;height:auto;position:static;width:auto}:root{--ck-color-base-action:#61b045;--ck-color-base-active:#198cf0;--ck-color-base-active-focus:#0e7fe1;--ck-color-base-background:#fff;--ck-color-base-border:#c4c4c4;--ck-color-base-focus:#6cb5f9;--ck-color-base-foreground:#fafafa;--ck-color-base-text:#333;--ck-color-button-action-active-background:#53973b;--ck-color-button-action-active-shadow:#498433;--ck-color-button-action-background:var(--ck-color-base-action);--ck-color-button-action-disabled-background:#7ec365;--ck-color-button-action-hover-background:#579e3d;--ck-color-button-action-text:var(--ck-color-base-background);--ck-color-button-cancel:#db3700;--ck-color-button-default-active-background:#d9d9d9;--ck-color-button-default-active-shadow:#bfbfbf;--ck-color-button-default-background:transparent;--ck-color-button-default-disabled-background:transparent;--ck-color-button-default-hover-background:#e6e6e6;--ck-color-button-on-active-background:#bababa;--ck-color-button-on-active-shadow:#a1a1a1;--ck-color-button-on-background:#dedede;--ck-color-button-on-disabled-background:#dedede;--ck-color-button-on-hover-background:#c4c4c4;--ck-color-button-save:#008a00;--ck-color-dropdown-panel-background:var(--ck-color-base-background);--ck-color-dropdown-panel-border:var(--ck-color-base-border);--ck-color-engine-placeholder-text:#c2c2c2;--ck-color-focus-border:#47a4f5;--ck-color-focus-disabled-shadow:rgba(119,186,248,0.3);--ck-color-focus-shadow:rgba(119,186,248,0.5);--ck-color-input-background:var(--ck-color-base-background);--ck-color-input-border:#c7c7c7;--ck-color-input-disabled-background:#f2f2f2;--ck-color-input-disabled-border:#c7c7c7;--ck-color-input-disabled-text:#5c5c5c;--ck-color-input-text:var(--ck-color-base-text);--ck-color-link-default:#0000f0;--ck-color-link-selected-background:#ebf8ff;--ck-color-list-background:var(--ck-color-base-background);--ck-color-list-button-hover-background:var(--ck-color-base-foreground);--ck-color-list-button-on-background:var(--ck-color-base-active);--ck-color-list-button-on-background-focus:var(--ck-color-base-active-focus);--ck-color-list-button-on-text:var(--ck-color-base-background);--ck-color-panel-background:var(--ck-color-base-background);--ck-color-panel-border:var(--ck-color-base-border);--ck-color-shadow-drop:rgba(0,0,0,0.15);--ck-color-shadow-inner:rgba(0,0,0,0.1);--ck-color-switch-button-inner-background:var(--ck-color-base-background);--ck-color-switch-button-off-background:#b0b0b0;--ck-color-switch-button-on-background:var(--ck-color-button-action-background);--ck-color-text:var(--ck-color-base-text);--ck-color-toolbar-background:var(--ck-color-base-foreground);--ck-color-toolbar-border:var(--ck-color-base-border);--ck-color-tooltip-background:var(--ck-color-base-text);--ck-color-tooltip-text:var(--ck-color-base-background);--ck-color-upload-bar-background:#6cb5f9;--ck-color-upload-infinite-background:rgba(0,0,0,0.1);--ck-disabled-opacity:.5;--ck-focus-disabled-outer-shadow:var(--ck-focus-outer-shadow-geometry) var(--ck-color-focus-disabled-shadow);--ck-focus-outer-shadow:var(--ck-focus-outer-shadow-geometry) var(--ck-color-focus-shadow);--ck-focus-outer-shadow-geometry:0 0 0 3px;--ck-focus-ring:1px solid var(--ck-color-focus-border);--ck-font-face:Helvetica,Arial,Tahoma,Verdana,Sans-Serif;--ck-font-size-base:13px;--ck-font-size-big:1.4em;--ck-font-size-large:1.8em;--ck-font-size-normal:1em;--ck-font-size-small:0.75em;--ck-font-size-tiny:0.7em;--ck-line-height-base:1.84615;--ck-ui-component-min-height:2.3em;--ck-z-default:1;--ck-z-modal:calc(var(--ck-z-default) + 999)}.ck.ck-reset,.ck.ck-reset_all,.ck.ck-reset_all *{background:transparent;border:0;margin:0;padding:0;text-decoration:none;transition:none;vertical-align:middle;word-wrap:break-word}.ck.ck-reset_all,.ck.ck-reset_all *{border-collapse:collapse;color:var(--ck-color-text);cursor:auto;float:none;font:normal normal norm ...
#   </style>
#   <script type="text/javascript">
#    window.history.forward();
# 	function noBack() {
# 		window.history.forward();
# 	}
#
# 	$(function() {
# 		tab = 'administrativeApprovalDept';
# 		surveyId = '';
# 		seat = '18914';
#
# 		if (typeof surveyId !== 'undefined' && surveyId > 0
# 				&& tab == "dashboard") {
# 			$.ajax({
# 				url : "https://fin.assam.gov.in/survey/getMySurveyBanner",
# 				data : {
# 					surveyId : surveyId,
# 					seat : seat
# 				}
# 			}).then(function(data) {
# 				$('#surveyModal .modal-body').html(data);
# 			});
#
# 			$('#surveyModal').modal('show');
# 		}
#
# 		if (tab != "") {
# 			$("#" + tab).addClass("active");
# 		}
#
# 		if (tab != "") {
# 			subtab = 'aaIssuedDept';
# 			if (subtab != "") {
# 				$("#" + subtab).attr("class", "active");
# 				if (subtab == "man" || subtab == "obl" || subtab == "suo"
# 						|| subtab == "oth") {
# 					stab = '';
#
# 					$("#" + stab).attr("class", "current_page_item");
# 					var $el, leftPos, newWidth, $mainNav = $("#example-one");
#
# 					$mainNav.append("<li id='magic-line'></li>");
# 					var $magicLine = $("#magic-line");
#
# 					$magicLine.width($(".current_page_item").width()).css(
# 							"left", $(".current_page_item a").position().left)
# 							.data("origLeft", $magicLine.position().left).data(
# 									"origWidth", $magicLine.width());
#
# 					$("#example-one li a").hover(function() {
# 						$el = $(this);
# 						leftPos = $el.position().left;
# 						newWidth = $el.parent().width();
# 						$magicLine.stop().animate({
# 							left : leftPos,
# 							width : newWidth
# 						});
# 					}, function() {
# 						$magicLine.stop().animate({
# 							left : $magicLine.data("origLeft"),
# 							width : $magicLine.data("origWidth")
# 						});
# 					});
# 				}
#
# 				subsubtab = '';
# 				if (subsubtab != "") {
# 					$("#" + subsubtab).attr("class", "selected");
# 				}
# 				if (tab != "" && tab == "la" && subsubtab != "") {
# 					$("#" + subsubtab).attr("class", "active");
# 				}
# 			}
# 		}
#
# 		if (tab != "" && tab == "home") {
# 			$('#d3').height($(window).height() - 280);
# 			$('#d2').height($(window).height() - 236);
# 		}
#
# 		if (tab != "" && tab == "reports") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
# 			$('#pr').height($(window).height() - 180);
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 			}
# 		}
#
# 		if (tab != "" && subtab == "otherAllowanceSetup") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
# 			$('#pr').height($(window).height() - 180);
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 			}
# 		}
#
# 		if (tab != "" && tab == "specialDeductionSetup") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
# 			$('#pr').height($(window).height() - 180);
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 			}
# 		}
#
# 		if (tab != "" && subtab == "debtSetup") {
# 			$('#p1').height($(window).height() - 100);
# 			$('#p2').height($(window).height() - 100);
#
# 			stab = '';
# 			if (stab != "") {
# 				$("#" + stab).attr("class", "selected");
# 				/* 	$("#" + stab).css("background-color", "white"); */
# 			}
# 		}
#
# 		$('#3').height($(window).height() - 280);
# 		$('#4').height($(window).height() - 350);
# 	});
#
# 	function viewGraph(year) {
# 		if ('aaIssuedDept' == "sfp") {
# 			view(document.getElementById("scid").value, year);
# 		}
# 	}
#
# 	function reportCeil() {
# 		var s = "Y";
# 		TINY.box.show({
# 			iframe : 'ceilingDetails?template=Y',
# 			width : 750,
# 			height : 320,
# 			fixed : false,
# 			maskid : 'bluemask',
# 			maskopacity : 60,
# 			openjs : function() {
# 				openJS()
# 			}
# 		});
# 	}
#
# 	function loadAjaxContent(elemId, action, param) {
# 		$.ajax({
# 			type : 'GET',
# 			url : action,
# 			data : param,
# 			success : function(msg) {
# 				$('#' + elemId).html(msg);
# 			}
# 		});
# 	}
#
# 	function goToFinVault(param1, param2, param3) {
# 		window.open("https://fin.assam.gov.in/finvault/goToFinVault?q=" + q);
# 	}
#
# 	$(document)
# 			.ready(
# 					function() {
# 						if ('D' == "O"
# 								&& '' != null) {
# 							var justificationSurrender = '';
# 							if (justificationSurrender == "true") {
#
# 								TINY.box.show({
# 									iframe : 'surrenderInitiationStatus',
# 									closejs : function() {
# 										window.parent.document.location
# 												.reload();
# 									},
# 									width : window.innerWidth - 900,
# 									height : window.innerHeight - 350,
# 									boxid : 'frameless'
# 								});
#
# 							}
# 						}
#
# // 						const tokenInput = document.querySelector('input[name="token"]');
#
# // 						// Get the value of the hidden input field
# // 						const sessionId = tokenInput ? tokenInput.value : null;
# // 						    localStorage.setItem("whatsapp-session", JSON.stringify({ loggedIn: true, sessionId }));
#
#
# // 								debugger
# // 							    const checkSessionInterval = setInterval(function () {
# // 							        const tokenInput = document.querySelector('input[name="token"]');
# // 							        const sessionId = tokenInput ? tokenInput.value : null;
#
# // 							        if (sessionId) {
# // 							            const currentSession = JSON.parse(localStorage.getItem("whatsapp-session"));
#
# // 							            if (!currentSession || currentSession.sessionId !== sessionId) {
# // 							                // Update the localStorage if sessionId changes
# // 							                alert("Another session is being started on a different tab.")
# // 							            }
# // 							        }
# // 							    }, 1000); // Check every 1 second
#
# // 							    });
#
# 					});
#   </script>
#   <title>
#    Administrative Approval, Technical and Financial Sanctions
#   </title>
#   <style type="text/css">
#    .header-part .nav-tabs {
# 	border-bottom: none;
# }
#
# ul.header-part {
# 	margin: 0px;
# 	padding: 0px;
# 	margin-top: 10px;
# 	margin-bottom: 5px;
# }
#
# ul.header-part li {
# 	display: inline;
# }
#
# ul.header-part li .mainLink {
# 	background-color: #F8C301;
# 	color: #000000;
# 	margin: -1px;
# 	padding: 3px 6px 4px 6px;
# 	text-decoration: none;
# 	font-size: 11px;
# 	font-family: Verdana, Arial, Helvetica, sans-serif;
# 	border-left: 3px solid #F9CC32;
# 	border-right: 3px solid #F9CC32;
# 	border-top: 3px solid #F9CC32;
# }
#
# ul.header-part li .mainLink:hover {
# 	background-color: #2666AB;
# 	border: 3px solid #1A60AB;
# 	border-bottom: none;
# 	color: #FFFFFF;
# }
#
# ul.header-part li .mainLink.active {
# 	background-color: #01458E;
# 	color: #FFFFFF;
# 	margin: 0px;
# 	padding: 3px 8px 4px 8px;
# 	outline: none;
# 	font-size: 11px;
# 	font-family: Verdana, Arial, Helvetica, sans-serif;
# 	border-left: 3px solid #01458E;
# 	border-right: 3px solid #01458E;
# 	border-top: 3px solid #01458E;
# }
#
# .header-part .dropdown-menu {
# 	transition: all 0.5s;
# 	overflow: hidden;
# 	transform-origin: top center;
# 	transform: scale(1, 0);
# 	display: block;
# 	opacity: 0.97;
# }
#
# .header-part .dropdown-menu a .row {
# 	padding: 3px 8px 4px 14px;
# }
#
# .header-part .dropdown:hover>.dropdown-menu {
# 	transform: scale(1);
# }
#
# .header-part .dropdown:hover>.dropdown-menu a:hover .row {
# 	color: #28a745;
# 	background-color: #f5f5f5;
# }
#
# .header-part .dropdown-menu a {
# 	color: #000;
# 	font-size: 12px;
# 	line-height: 1.8;
# }
#
# .header-part .dropdown-menu .dropdown-item {
# 	background-color: none;
# }
#
# .header-part .dropdown-menu .dropdown-item-disable {
# 	display: none;
# }
#   </style>
#   <link href="https://finanalytics.assam.gov.in/botpress/assets/modules/channel-web/inject.css" rel="stylesheet"/>
#   <link href="https://fin.assam.gov.in/assamfinance/webjars/tinymce/5.0.9/skins/ui/oxide/skin.min.css" id="u0" rel="stylesheet" type="text/css"/>
#  </head>
#  <body onload="noBack();" onpageshow="if(event.persisted) noBack();">
#   <table class="layoutStyle">
#    <tbody>
#     <tr>
#      <td colspan="3">
#       <link href="../resources/js/anylinkmenu.css" rel="stylesheet" type="text/css"/>
#       <script src="../resources/js/anylinkmenu.js" type="text/javascript">
#       </script>
#       <script src="../resources/js/jQuery-idle/jquery-idle.min.js" type="text/javascript">
#       </script>
#       <script src="https://finanalytics.assam.gov.in/botpress/assets/modules/channel-web/inject.js">
#       </script>
#       <script type="text/javascript">
#        anylinkmenu.init("menuanchorclass")
# 	var anylinkmenu4 = {
# 		divclass : 'anylinkmenu',
# 		inlinestyle : 'width:150px; background:#ffffff',
# 		linktarget : '_self'
# 	}
#
# 	anylinkmenu4.items = [
# 			[
# 				"Profile",
# 				"javascript: editProfile()" ],
# 			[
# 					"Change Password",
# 					"javascript:TINY.box.show({iframe:'/assamfinance/changePasswd',width:650,height:500,boxid : 'frameless' })" ],
# 			[ "Password History", "javascript: passwordHistory()" ],
# 			[
# 				"Deactivate Account",
# 				"javascript:TINY.box.show({iframe:'deleteProfile',width:600,height:450,boxid : 'frameless' })" ]]
#
# 	function passwordHistory() {
# 		window.location.href = "passwordHistory";
# 	}
#
# 	function editProfile() {
# 		window.location.href = "editProfile";
# 	}
#
# 	$(function() {
# 		if ('Y' == "N") {
# 			TINY.box
# 					.show({
# 						iframe : '/assamfinance/changePasswd',
# 						closejs : function() {
# 							window.parent.document.location.reload();
# 						},
# 						width : 650,
# 						height : 300,
# 						boxid : 'frameless'
# 					});
# 		}
# 	});
#
# 	$(document).on('click', '.forceLogout', function(event) {
# 		forceLogout();
# 	});
#
# 	$(document).on('click', '.keepAlive', function(event) {
# 		keepAlive();
# 	});
#
# 	$(document).idle({
# 		onIdle : function() {
# 			$("#notifyLogout").modal('show');
# 			countdown();
# 		},
# 		idle : 1000000
# 	})
#
# 	var timeoutHandle;
# 	function countdown() {
# 		var seconds = 60;
# 		function tick() {
# 			var counter = document.getElementById("countdowntimer");
# 			seconds--;
# 			counter.innerHTML = "(" + (seconds < 10 ? "0" : "")
# 					+ String(seconds) + ")";
# 			if (seconds > 0) {
# 				timeoutHandle = setTimeout(tick, 1000);
# 			} else {
# 				forceLogout();
# 			}
# 		}
# 		tick();
# 	}
#
# 	function forceLogout() {
# 		window.location.href = '/cas/logout';
# 	}
#
# 	function keepAlive() {
# 		$.ajax({
# 			url : 'keepSessionAlive',
# 			complete : function() {
# 				$("#notifyLogout").modal('hide');
# 			}
# 		});
# 	}
#
# 	function viewSupportNumbers() {
# 		$.ajax({
# 			type : "GET",
# 			url : "viewSupportNumbers",
# 			beforeSend : function() {
# 				$('#supportModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#supportModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#supportModal').modal('show');
# 	}
#       </script>
#       <table>
#        <tbody>
#         <tr>
#          <td class="headerband" height="60px" style="background-image: url('../resources/images/Assam_Logo_Header.png'); background-repeat: no-repeat; border: none; vertical-align: middle; margin: 10px 10px 10px 10px" width="300px">
#          </td>
#          <td class="headerband" height="56" style="vertical-align: middle;">
#           <img align="right" src="../resources/images/AssamFinance_Logo_Header.png"/>
#          </td>
#         </tr>
#         <tr class="band">
#          <td style="width: 60%; padding-top: 5px; padding-left: 5px;">
#           <div align="left">
#            <span style="color: white; font-size: 12px;">
#             Mr. Assistant rdm, Assistant Department, Revenue and Disaster Management Department
#            </span>
#            <a class="menuanchorclass" href="#" rel="anylinkmenu4">
#             <img border="0" height="10px" src="../resources/images/arr.png" width="10px"/>
#            </a>
#            <span style="color: #FFF;">
#             Last Log In : Thursday, 20 March 2025, 02:01 AM
#            </span>
#            <a href="loginHistory" style="color: #F8C301;">
#             Show More
#            </a>
#           </div>
#          </td>
#          <td height="22px;" style="padding-top: 5px; padding-left: 5px">
#           <div align="right">
#            <span color="#FFFFFF;" style="font-weight: lighter;">
#             <a href="gotoMyInbox" style="text-decoration: none;" title="Home Page">
#              <span style="color: white; font-weight: normal; font-size: 12px;">
#               <i class="fa fa-home">
#               </i>
#               Home |
#              </span>
#             </a>
#             <a href="javascript:void(0);" id="userManualLink" onclick="gotoUserManuals();" style="text-decoration: none;" title="User Manuals">
#              <span style="color: white; font-size: 12px; font-weight: lighter;">
#               <i class="fa fa-book">
#               </i>
#               Manuals &amp; Tutorials |
#              </span>
#             </a>
#             <a href="changeAccountDetails" style="text-decoration: none;" title="Home Page">
#              <span style="color: white; font-weight: normal; font-size: 12px;">
#               <i class="fa fa-user-circle-o">
#               </i>
#               Change Account |
#              </span>
#             </a>
#             <a href="/cas/logout" style="text-decoration: none;" title="logout">
#              <span style="color: white; font-size: 12px; font-weight: lighter; padding-right: 10px;">
#               <i class="fa fa-sign-out">
#               </i>
#               Logout
#              </span>
#             </a>
#            </span>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <!-- GENERAL-USER-IDLE-STATUS -->
#       <div aria-hidden="true" aria-labelledby="notifyLogoutLabel" class="modal fade in" id="notifyLogout" role="dialog" tabindex="-1">
#        <div class="modal-dialog">
#         <div class="modal-content">
#          <div class="modal-header">
#           <button class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#            <span class="sr-only">
#             Close
#            </span>
#           </button>
#           <h4 class="modal-title" id="notifyLogoutLabel" style="color: #444;">
#            Session
# 					Timeout
#           </h4>
#          </div>
#          <div class="modal-body" style="font-size: 14px; line-height: 20px;">
#           You're
# 				being timed out due to inactivity. Please choose to stay signed in
# 				or to logout. Otherwise, you will be logged out automatically.
#          </div>
#          <div class="modal-footer">
#           <button class="btn btn-sm btn-danger forceLogout" type="button">
#            Logout
#           </button>
#           <button class="btn btn-sm btn-primary keepAlive" data-dismiss="modal" type="button">
#            Stay Logged In
#            <span id="countdowntimer">
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal" data-backdrop="static" data-keyboard="false" id="supportModal" role="dialog">
#        <div class="modal-dialog modal-lg">
#         <div class="modal-content">
#          <div class="modal-body" style="background-color: #f5f5f5;">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal fade" data-backdrop="static" data-keyboard="false" id="updatePasswordModal" role="dialog">
#        <div class="modal-dialog modal-md">
#         <div class="modal-content">
#          <div class="modal-header" style="display: flex;">
#           <h4 class="modal-title" style="color: #fff; width: 95%; text-align: left;">
#            Update
# 					Password
#           </h4>
#           <button class="close" data-dismiss="modal" style="width: 5%" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#            <span class="sr-only">
#             Close
#            </span>
#           </button>
#          </div>
#          <div class="modal-body" id="updatePasswordModalBody" style="height: 375px;">
#          </div>
#         </div>
#        </div>
#       </div>
#       <script>
#        let webchatOpen = false
# 	window.botpressWebChat.init({
# 		host : 'https://finanalytics.assam.gov.in/botpress',
# 		botId : 'helpdesk',
# 		userId : "18914",
# 		botName : 'Helpdesk',
# 		enableTranscriptDownload : false,
# 		showConversationsButton : false,
# 		hideWidget : true,
# 		useSessionStorage: true
# 	})
#
# 	window.addEventListener('message', function(event) {
# 		if (event.data.name === 'webchatReady') {
# 			window.botpressWebChat.sendEvent({
# 				type : 'proactive-trigger',
# 				text : 'Hi',
# 				channel : "web",
# 				payload : {
# 					token : "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJzdWIiOiJhZC5yZG0iLCJuYmYiOjE3NDI0MTYzODMsImlkIjoiMTg5MTQiLCJleHAiOjE3NDI1MDI3ODMsInVzZXJuYW1lIjoiYWQucmRtIn0.Vd892vaH6GzlLb3vtL_mctiMsxo7L1g8FUB3mF6VIFnASS1Cj1GayjMMmzamXmoC6pDm6v7NLKaRhBlSzDwnVVAewFK9P7I071GOD-KMRukhq1Qz-_HLhRZKuNw_0tkOzKykPB9efsXWTpHrub94PoI1NSm8oEZO15m9QtKTcB5IdNaWl9DM5960PDXSMPgxcp-WnZOfe1AK0g0x06NaJ4HzKtYgR8J8gjMoszXowPFGGiFAijdd0K5OsypY65z6t9Dj_JuHYAEHatoo7ToQdTRmNND3ZOo7kRfQqDfyzNGZQccZh4QUSdKg6DoNj6OTQ-hgLzYgkGGXXmxhh9IizQ",
# 				},
# 			})
# 		}
# 		if (event.data.name === 'webchatOpened') {
# 			webchatOpen = true
# 		}
#
# 		if (event.data.name === 'webchatClosed') {
# 			webchatOpen = false
# 		}
# 	})
#       </script>
#      </td>
#     </tr>
#     <tr>
#      <td bgcolor="#FFFFFF" colspan="3" style="padding: 0px 4px 0px 4px">
#       <div align="left">
#        <ul class="header-part">
#         <li class="nav-item" title="Inbox">
#          <a class="nav-link mainLink" href="gotoDebtInbox" id="inbox">
#           Inbox
#          </a>
#         </li>
#         <!-- ====================== -->
#         <!-- === FOR BUDGET === -->
#         <!-- === FOR BUDGET END === -->
#         <!-- === FOR CEILING === -->
#         <!-- === FOR CEILING END === -->
#         <!-- === FOR AATSFS === -->
#         <!-- === FOR AATSFS END === -->
#         <!-- === FOR BILLS === -->
#         <!-- === FOR BILLS END === -->
#         <!-- === FOR DEBT === -->
#         <!-- === FOR DEBT END === -->
#         <!-- === FOR RIDF === -->
#         <!-- === FOR RIDF END === -->
#         <!-- === FOR EIS === -->
#         <!-- === FOR EIS END === -->
#         <!-- === FOR WORKS ACCOUNT === -->
#         <!-- === FOR WORKS ACCOUNT END === -->
#         <!-- === FOR AUDIT === -->
#         <!-- === FOR AUDIT END === -->
#         <!-- === FOR DASHBOARD === -->
#         <!-- === FOR CASH-PLANNING  === -->
#         <!-- === FOR CASH-PLANNING END === -->
#         <!-- === FOR TEMPORARY  === -->
#         <!-- Master Data -->
#        </ul>
#       </div>
#      </td>
#     </tr>
#     <tr>
#      <td width="4px">
#      </td>
#      <td id="bodypart">
#       <table>
#        <tbody>
#         <tr>
#          <td>
#           <ul class="dropdown dropdown-horizontal">
#            <li title="Received Administrative Approvals (Held By You)">
#             <a href="administrativeApprovalDeptReceived" id="aaReceivedDept">
#              Received
#             </a>
#            </li>
#            <li title="Create a new Administrative Approval">
#             <a href="administrativeApprovalDept" id="aaRequestDept">
#              Pending
#             </a>
#            </li>
#            <li title="Inter And Intra Department Forwarded">
#             <a href="aaInterAndIntraDeptForwarded" id="aaInterAndIntraForwarded">
#              Forwarded (Dept)
#             </a>
#            </li>
#            <li title="Forwarded To Finance">
#             <a href="administrativeApprovalDeptForwarded" id="aaDeptForwarded">
#              Forwarded
# 											(Finance)
#             </a>
#            </li>
#            <li title="Forwarded To Finance">
#             <a href="getAaFinanceReturnedInDept" id="aaFinReturnedDept">
#              Finance Returned
#             </a>
#            </li>
#            <li title="Queried">
#             <a href="administrativeApprovalDeptQueried" id="aaDeptQueried">
#              Queried
#             </a>
#            </li>
#            <li title="Issued (Manual+System Generated) Administrative Approvals">
#             <a class="active" href="aaIssuedDept" id="aaIssuedDept">
#              Issued
#             </a>
#            </li>
#            <li title="Ongoing + Proposals need to be revalidated">
#             <a href="aaOngoing" id="aaOngoing">
#              Manually Approved
#             </a>
#            </li>
#            <li>
#             <a href="aaRejectedDept" id="aaRejectedDEpt">
#              Rejected
#             </a>
#            </li>
#            <li>
#             <a href="aaCanceledDept" id="aaCanceledDept">
#              Cancelled
#             </a>
#            </li>
#            <li>
#             <a href="getAdministrativeApprovalListForVerification" id="verifyAa">
#              Verify
# 											AA
#             </a>
#            </li>
#            <li title="Administrative Approval Summary">
#             <a href="administrativeApprovalSummaryDept" id="aaSummaryDept">
#              Search
#             </a>
#            </li>
#            <li style="background-color: #338ad7;">
#             <a href="getAaGIS" id="getAaGIS" title="District Wise Administrative Approval">
#              AA-GIS
#             </a>
#            </li>
#            <li style="background-color: #338ad7;">
#             <a href="getAaReport" id="getAaReport" title="Administrative Approval Report">
#              Money
# 											Flow-Report
#             </a>
#            </li>
#            <li>
#             <a href="getAaGeneralReportsDept" id="getAaGeneralReportsDept" title="Administrative Approval General Reports">
#              Reports
#             </a>
#            </li>
#            <li>
#             <a href="getAaWildCardReportsDept" id="getAaWildCardReportsDept" title="Financial Sanction Wild Card Reports">
#              Wild Card Reports
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#         <!-- SUBTAB FOR BILLS -->
#         <!-- Sub tab for GeM -->
#         <!-- SUBTAB FOR TREASURY -->
#         <tr>
#          <td>
#           <script charset="utf-8" src="../resources/js/ckeditor/ckeditor.js?version=2" type="text/javascript">
#           </script>
#           <script charset="utf-8" src="../webjars/tinymce/5.0.9/tinymce.min.js" type="text/javascript">
#           </script>
#           <script type="text/javascript">
#            var displayMessage = '';
# 	$(document).ready(function() {
# 		if (displayMessage != null && displayMessage != "") {
# 			$("#confirmAlertTitle").html(displayMessage);
# 			$('#confirmAlert').modal('show');
# 		}
# 		var sum = 0;
# 		$('.allottedAmount').each(function() {
# 			sum += Number($(this).val());
# 		});
# 		$('#totBudgetctFY').val(sum);
#
# 		CentralShare = $('#CentralShare').val();
# 		if (CentralShare == 'C') {
# 			$("#centralDiv").show();
# 		} else {
# 			$("#centralDiv").hide();
#
# 		}
# 	});
#
# 	function viewSignedChecklist(sanctionId) {
# 		window.open(
# 				"viewSignedChecklistAdministrativeApproval?q="
# 						+ sanctionId, "_blank");
# 		return false;
# 	}
# 	function showQueryBox() {
# 		$('#myModal2').find('.modal-title').find('.label').html("Query HoD");
# 		$('#querySaveBtn')
# 				.prop("name", "action:addAdministrativeApprovalQuery");
# 		$('#parentId').val('');
# 		$('#myModal2').modal('show');
# 		return false;
# 	}
# 	function showReplyBox(queryId) {
# 		$('#myModal2').find('.modal-title').find('.label').html(
# 				"Query Reply To Finance");
# 		$('#querySaveBtn').prop("name",
# 				"action:addAdministrativeApprovalQueryReply");
# 		$('#parentId').val(queryId);
# 		$('#myModal2').modal('show');
# 		return false;
# 	}
# 	function sendQuery(elem, queryId, approvalId, status) {
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "sendAdministrativeApprovalQuery",
# 					data : {
# 						'id' : queryId,
# 						'administrativeApproval.approvalId' : approvalId,
# 						'administrativeApproval.finQueryStatus' : status
# 					},
# 					beforeSend : function() {
# 						$(elem).prop('class',
# 								'glyphicon glyphicon-option-horizontal');
# 					},
# 					success : function(msg) {
# 						if (msg) {
# 							location.reload();
# 							$(elem)
# 									.closest('td')
# 									.html(
# 											'<i title="Sent" class="fa fa-share" aria-hidden="true" style="font-size: 16px; color: green;"></i>');
# 						}
# 					}
# 				});
# 	}
# 	function sendQueryDept(elem, queryId, approvalId, status) {
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "sendAdministrativeApprovalQueryDept",
# 					data : {
# 						'id' : queryId,
# 						'administrativeApproval.approvalId' : approvalId,
# 						'administrativeApproval.finQueryStatus' : status
# 					},
# 					beforeSend : function() {
# 						$(elem).prop('class',
# 								'glyphicon glyphicon-option-horizontal');
# 					},
# 					success : function(msg) {
# 						if (msg) {
# 							location.reload();
# 							$(elem)
# 									.closest('td')
# 									.html(
# 											'<i title="Sent" class="fa fa-share" aria-hidden="true" style="font-size: 16px; color: green;"></i>');
# 						}
# 					}
# 				});
# 	}
# 	function deleteQuery(elem, queryId) {
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "deleteAdministrativeApprovalQuery",
# 					data : {
# 						'id' : queryId
# 					},
# 					beforeSend : function() {
# 						$(elem).prop('class',
# 								'glyphicon glyphicon-option-horizontal');
# 					},
# 					success : function(msg) {
# 						if (msg) {
# 							location.reload();
# 							$(elem).closest('tr').remove();
# 							if ($('#queryTable tr').length == 1) {
# 								$('#queryTable')
# 										.append(
# 												'<tr><td colspan="3" style="text-align:center">--No Queries Found--</td></tr>');
# 							}
# 							var i = 1;
# 							$('#queryTable').find(".slno").each(function() {
# 								$(this).html(i);
# 								i++;
# 							});
# 						}
# 					}
# 				});
# 	}
# 	function proposalReport(approvalId) {
# 		window.open("downloadAAChecklist?q="
# 				+ approvalId, "_blank");
# 		return false;
# 	}
#
# 	function uploadSignedChecklist(elem, approvalId) {
# 		$('#myModal3 #modalTitle').html("Upload Signed Checklist");
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "uploadSignedChecklistAdministrativeApproval",
# 					data : {
# 						'administrativeApproval.approvalId' : approvalId
# 					},
# 					beforeSend : function() {
# 						$('#myModal3 .modal-body').html('Loading..');
# 					},
# 					success : function(msg) {
# 						$('#myModal3 .modal-body').html(msg);
# 						$('#checklist')
# 								.change(
# 										function(event) {
# 											var ext = this.value
# 													.match(/\.(.+)$/)[1];
# 											switch (ext) {
# 											case 'pdf':
# 												var tmppath = URL
# 														.createObjectURL(event.target.files[0]);
# 												$("#uploads").attr('src',
# 														tmppath);
# 												break;
# 											case 'PDF':
# 												var tmppath = URL
# 														.createObjectURL(event.target.files[0]);
# 												$("#uploads").attr('src',
# 														tmppath);
# 												break;
# 											default:
# 												alert('Please upload PDF file.');
# 												this.value = '';
# 											}
# 										});
# 					}
# 				});
# 		$('#myModal3').modal('show');
# 		return false;
# 	}
# 	function showHistoryAmount(approvalId) {
# 		$('#myModal4 #modalTitle').html("Amount Edit History");
# 		$.ajax({
# 			type : "GET",
# 			url : "showHistoryAmount",
# 			data : {
# 				'administrativeApproval.approvalId' : approvalId
# 			},
# 			beforeSend : function() {
# 				$('#myModal4 .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#myModal4 .modal-body').html(msg);
# 			}
# 		});
# 		$('#myModal4').modal('show');
# 	}
# 	//rejection note
# 	function addAANotes(approvalId) {
# 		$('#administrativeNoteModal #modalTitle').html(
# 				"Administrative Approval Notes");
# 		$.ajax({
# 			type : "GET",
# 			url : "addAANotes",
# 			data : {
# 				'administrativeApproval.approvalId' : approvalId
# 			},
# 			beforeSend : function() {
# 				$('#administrativeNoteModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#administrativeNoteModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#administrativeNoteModal').modal('show');
# 		return false;
# 	}
# 	function validateSchemeWise(approvalId){
# 		var a=getIssuedDetails(approvalId);
# 		$('#issueAdministrativeApprovalModal').modal('hide');
# 		$('#SchemeWiseValidationModal').modal('show');
# 		 return false;
# 	}
# 	function getIssuedDetails(approvalId) {
# 	    var result = vaidateHoaWiseBudgetLimit();
# 	    var budgetProvisions = result.budgetProvisions;
# 	    var aaIssuedAmount = JSON.parse($('#aaIssuedAmount').val());
# 	    var aaExpenditureAmount = JSON.parse($('#aaExpenditureAmount').val());
# 	    var eligibleAAAmounts = [];
# 	    var allEligible = true;
#
# 	    for (var i = 0; i < budgetProvisions.length; i++) {
# 	        var Budgetprovision = budgetProvisions[i];
# 	        var aaIssued = aaIssuedAmount[i];
# 	        var aaExpenditure = aaExpenditureAmount[i];
# 	        var EligibleAAAmount = Budgetprovision - (aaIssued - aaExpenditure);
# 	        eligibleAAAmounts.push(EligibleAAAmount);
#
# 	        var elementId = 'eligibleAAAmount' + i;
# 	        var element = document.getElementById(elementId);
# 	        if (element) {
# 	            element.innerText = formatAmount(EligibleAAAmount);
# 	        }
#       	 $('#eligibleAAAmountscheck'+i).text(formatAmount(EligibleAAAmount));
#
# 	    }
#
# 	    var totalEligibleAAAmount = eligibleAAAmounts.reduce((acc, amount) => acc + amount, 0);
#
# 	    var proceedButton = document.getElementById('proceedButton');
# 	    var saveButton = document.getElementById('saveButton');
# 	    var additionalInfo = document.getElementById('additionalInfo');
# 		var attachment = '';
# 	    if (totalEligibleAAAmount <= 0 && !attachment) {
# 	    	proceedButton.style.display = "none";
# 	     	additionalInfo.style.display = "block";
# 	        document.getElementById('alertId').innerText = "The AA cannot be issued, as the outstanding liabilities are more than double the budget provision for the current financial year.";
# 		 }
# 		 else if(attachment!=null && attachment !== ""){
# 			additionalInfo.style.display = "block";
# 		 		$('#SchemeWiseValidationModal').modal('hide');
# 		 		issueAdministrativeApprovalDFP(approvalId);
# 		 	   }
# 		 else {
# 	    	saveButton.style.display = "none";
# 	    	additionalInfo.style.display = "none";
# 	        document.getElementById('alertId').innerText = "";
# 	        $('#SchemeWiseValidationModal').modal('hide');
# 	        issueAdministrativeApprovalDFP(approvalId);
# 	    }
# 	}
#
# 	function formatAmount(amount) {
# 	    var formattedString = '₹ ' + amount.toFixed(2);
# 	    if (amount >= 10000000) {
# 	        formattedString += ' crore';
# 	    } else if (amount >= 100000) {
# 	        formattedString += ' lakh';
# 	    }
#
# 	    return formattedString;
# 	}
# 	function issueAdministrativeApprovalDFP(approvalId) {
# 		$('#issueAdministrativeApprovalModal #modalTitle').html(
# 		"Administrative Approval Issue (Under DFP)");
# 		var abbreviationforAA = $("#abbreviationforAA").val();
# 		var aaValidationExempted = $("#aaValidationExempted").val();
# 		if(!aaValidationExempted){
# 		if (abbreviationforAA == "undefined" || (abbreviationforAA != "SOPD-EE-SSA" && abbreviationforAA != "SOPD-FDR" && abbreviationforAA != "SOPD-G" && abbreviationforAA != "SOPD-GSP" && abbreviationforAA != "SOPD-ODS" && abbreviationforAA != "SOPD-SCSP" && abbreviationforAA != "SOPD-SCSP SS" && abbreviationforAA != "SOPD-SS" && abbreviationforAA != "SOPD-TSP")) {
# 		var isValidationSuccess = vaidateHoaWiseBudgetLimit();
# 		if (!isValidationSuccess.responseObj.statusFlag && Number(isValidationSuccess.responseObj.param) > 0) {
# 			alert('Proposal cannot be issued since the overall project cost against the HoA is exceeding the ' + isValidationSuccess.responseObj.param + 'x budget provision of HoA(s)');
# 		return false;
# 			}
# 		}
# 	}
# 		var theTotalAAAmount = $("#theTotalAAAmount").val();
# 		if (theTotalAAAmount > 0) {
# 			var totalHoaAmount = $("#totalHoaAmount").val();
# 			if (isNaN(totalHoaAmount)) {
# 				alert("Invalid Financial Details");
# 				return false;
# 			} else {
# 				if (totalHoaAmount > 0) {
# 					$('#issueAdministrativeApprovalModal #modalTitle').html(
# 							"Administrative Approval Issue (Under DFP)");
# 					$.ajax({
# 						type : "GET",
# 						url : "issueAdministrativeApprovalDFP",
# 						data : {
# 							'administrativeApproval.approvalId' : approvalId
# 						},
# 						beforeSend : function() {
# 							$('#issueAdministrativeApprovalModal .modal-body')
# 									.html('Loading..');
# 						},
# 						success : function(msg) {
# 							$('#issueAdministrativeApprovalModal .modal-body')
# 									.html(msg);
# 						}
# 					});
# 					$('#issueAdministrativeApprovalModal').modal('show');
# 					return false;
#
# 				} else {
# 					alert("Invalid Financial Details");
# 					return false;
# 				}
# 			}
# 		} else {
# 			alert("Invalid Amount");
# 			return false;
# 		}
# 	}
# 	function back() {
# 		var tab = 'aaIssuedDept';
# 		if (tab != "" && tab == "aaIssuedDept") {
# 			window.location.href = "aaIssuedDept";
# 		}
# 		if (tab != "" && tab == "aaRequestDept") {
# 			window.location.href = "administrativeApprovalDept";
# 		}
# 		if (tab != "" && tab == "aaRejectedDept") {
# 			window.location.href = "aaRejectedDept";
# 		}
# 		if (tab != "" && tab == "aaDeptForwarded") {
# 			window.location.href = "administrativeApprovalDeptForwarded";
# 		}
# 		if (tab != "" && tab == "aaInterAndIntraForwarded") {
# 			window.location.href = "aaInterAndIntraDeptForwarded";
# 		}
# 		if (tab != "" && tab == "aaReceivedDept") {
# 			window.location.href = "administrativeApprovalDeptReceived";
# 		}
# 		return false;
# 	}
# 	function addNewCondition(elem) {
# 		var rowLen = $('#conditionTable').find('tr').length;
# 		rowLen = rowLen - 5;
# 		var rowData = $('#dynamicRow').html();
# 		rowData = rowData.replace(/counterIndex/g, rowLen);
# 		rowData = rowData.replace(/counter/g, rowLen - 1);
# 		$(elem).before($('<tr></tr>').append(rowData));
# 	}
# 	function addConcurencePoints(approvalId) {
# 		$('#predefinedAAConcurenceModal #modalTitle').html(
# 				"Administrative Predefined Concurence");
# 		$
# 				.ajax({
# 					type : "GET",
# 					url : "getpredefinedAAConcurence",
# 					data : {
# 						'administrativeApproval.approvalId' : approvalId
# 					},
# 					beforeSend : function() {
# 						$('#predefinedAAConcurenceModal .modal-body').html(
# 								'Loading..');
# 					},
# 					success : function(msg) {
# 						$('#predefinedAAConcurenceModal .modal-body').html(msg);
# 					}
# 				});
# 		$('#predefinedAAConcurenceModal').modal('show');
# 		return false;
# 	}
# 	function acceptProposalDept(approvalId) {
# 		$('#selectedAaId').val(approvalId);
# 		$
# 				.ajax({
# 					type : "POST",
# 					url : "acceptProposalDept",
# 					data : $('#aaDetailsId').serialize(),
# 					success : function(msg) {
# 						alert('The Proposal is added to your Received Tab');
# 						location.reload();
# 					}
# 				});
# 	}
# 	function validateNumAndTotCost(elem) {
# 		if (isNaN(elem.value)) {
# 			alert('Invalid numeric value');
# 			elem.value = "";
# 			elem.focus();
# 		} else if (elem.value == "") {
# 			alert('This field can not be blank!');
# 			elem.value = "";
# 		} else if (elem.value == 0) {
# 			alert('Amount must be greater than zero');
# 			elem.value = "";
# 		} else {
# 			var sum = 0;
# 			var aaSum = 0;
# 			var concurredAmount = '1.41479';
# 			concurredAmount = Number(concurredAmount);
# 			$('.amt').each(function() {
# 				sum += Number($(this).val());
# 			});
# 			$('#totalHoaAmount').val(sum);
# 			if (sum != null && sum != "") {
# 				var benShareAmount = $("#benShareAmount").val();
# 				if (benShareAmount != null && benShareAmount != "") {
# 					aaSum = Number(sum) + Number(benShareAmount);
# 				} else {
# 					aaSum = sum;
# 				}
# 			}
# 			//validating the edited amount with the concurred amount
# 			if (aaSum > concurredAmount) {
# 				alert('New amount( '
# 						+ aaSum.toFixed(5)
# 						+ 'L ) should not exceed the concurred amount. Which is, '
# 						+ concurredAmount.toFixed(5) + 'L');
# 				//reloading the form to reset the amount to previous(actual) one
# 				location.reload();
# 			} else {
# 				$('#theTotalAAAmount').val(aaSum.toFixed(5));
# 			}
# 		}
# 	}
# 	function calculateAaAmount(elem) {
# 		if (isNaN(elem.value)) {
# 			alert('Invalid numeric value');
# 			elem.value = "";
# 			elem.focus();
# 		} else {
# 			var sum = 0;
# 			var aaSum = 0;
# 			$('.amt').each(function() {
# 				sum += Number($(this).val());
# 			});
# 			$('#totalHoaAmount').val(sum.toFixed(5));
# 			if (sum != null && sum != "") {
# 				var benShareAmount = $("#benShareAmount").val();
# 				if (benShareAmount != null && benShareAmount != "") {
# 					aaSum = Number(sum) + Number(benShareAmount);
# 				} else {
# 					aaSum = sum;
# 				}
# 			}
# 			$('#theTotalAAAmount').val(aaSum.toFixed(5));
# 		}
# 	}
#
# 	function validateCFYAmount(elem) {
# 		var txt_bAmt = $(elem).parent('td').find(".amt").val();
# 		if (isNaN(elem.value)) {
# 			alert('Invalid numeric value');
# 			elem.value = "";
# 			elem.focus();
# 		} else if (elem.value == "") {
# 			alert('This field can not be blank!');
# 			elem.value = "";
# 		} else if (elem.value == 0) {
# 			alert('Amount must be greater than zero');
# 			elem.value = "";
# 		} else {
# 			var sum = 0;
# 			$('.eeCFYAmount').each(function() {
# 				sum += Number($(this).val());
# 			});
# 			$('#totEstimatedctFY').val(sum);
# 		}
# 	}
# 	function validateUpdate() {
# 		if (confirm('Do you really want to update the modifications?') == true) {
# 			if ($('#costOfProject').val() == ""
# 					|| $('#costOfProject').val() == 0) {
# 				alert('Project cost value can not be blank/zero');
# 				$('#costOfProject').val("").css('border', '1px solid red');
# 				return false;
# 			}
# 			if ($('#estimatedAmount').val() == ""
# 					|| $('#estimatedAmount').val() == 0) {
# 				alert('Estimated cost value can not be blank/zero');
# 				$('#estimatedAmount').val("").css('border', '1px solid red');
# 				return false;
# 			}
# 			return true;
# 		}
# 		return false;
# 	}
# 	function validateBasicDetails() {
# 		if (confirm('Do you want to continue?') == true) {
# 			var totalHoaAmount = $("#totalHoaAmount").val();
# 			if (isNaN(totalHoaAmount)) {
# 				alert("Invalid Financial Details");
# 				return false;
# 			} else {
# 				if (totalHoaAmount > 0) {
# 					return true;
# 				} else {
# 					alert("Invalid Financial Details");
# 					return false;
# 				}
# 			}
# 			return false;
# 		}
# 		return false;
# 	}
#
# 	function addAADeptForwardNotes(approvalId) {
# 		$('#administrativeNoteModal #modalTitle').html(
# 				"Forward Administrative Approval");
# 		$.ajax({
# 			type : "GET",
# 			url : "addAADeptForwardNotes",
# 			data : {
# 				'administrativeApproval.approvalId' : approvalId
# 			},
# 			beforeSend : function() {
# 				$('#administrativeNoteModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#administrativeNoteModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#administrativeNoteModal').modal('show');
# 		return false;
# 	}
#
# 	function saveAdministrativeApprovalNotes(approvalId) {
# 		if (tinyMCE.get('kraneditorD').getContent() == "") {
# 			alert("Enter Forward Notes!");
# 			return false;
# 		} else {
# 			tinyMCE.triggerSave();
# 			$.ajax({
# 				type : "POST",
# 				url : "saveAdministrativeApprovalNotes",
# 				data : $('#approvalNotes').serialize(),
# 				success : function(result) {
# 					if (result)
# 						alert('Notes Saved');
# 				}
# 			});
# 			return false;
# 		}
# 	}
# 	function getdprDetails() {
# 		$('#administrativeNoteModal #modalTitle').html("Scheme Details");
# 		var dprId = $("#dprId").val();
# 		$.ajax({
# 			type : "GET",
# 			url : "getdprDetails",
# 			data : {
# 				id : dprId
# 			},
# 			beforeSend : function() {
# 				$('#administrativeNoteModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#administrativeNoteModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#administrativeNoteModal').modal('show');
# 		return false;
# 	}
#
# 	var clicked_val=false;
# 	function financialProgressDetails(approvalId){
# 		if(!clicked_val){
# 			clicked_val=true;
# 		$.ajax({
# 			type : "GET",
# 			url : "getFinancialProgressDetailsOfAa",
# 			data : {
# 				'administrativeApproval.approvalId' : approvalId
# 			},
# 			beforeSend : function() {
# 				$("#removedCommitmentHistory").html('Loading...Please Wait...    '+'<i class="fa fa-circle-o-notch fa-spin"></i>')
# 			},
# 			success : function(result) {
# 				$("#removedCommitmentHistory").html(result)
# 			}
# 		 });
# 		}
# 	 }
# 	$(document).on('keyup', '.amount', function() {
# 		var breakUpSum = 0;
# 		var aaTotalProjectCost = $('#theTotalAAAmount').val();
# 		aaTotalProjectCost = parseFloat(Number(aaTotalProjectCost).toFixed(5));
#
# 		$('.amount').each((index, element)=> {
# 			breakUpSum += parseFloat(element.value);
# 			breakUpSum = parseFloat(breakUpSum.toFixed(5));
# 			if (breakUpSum > aaTotalProjectCost) {
# 				alert('Break-up amount exceeds total approval amount!');
# 				element.value = "";
# 			}
# 		});
# 	});
#
# 	function pullBack(approvalId) {
# 		$('#administrativepullNoteModal #modalTitle').html(
# 				"Pull Back Notes");
# 		$.ajax({
# 			type : "GET",
# 			url : "pullBack",
# 			data : {
# 				'administrativeApproval.approvalId' : approvalId
# 			},
# 			beforeSend : function() {
# 				$('#administrativepullNoteModal .modal-body').html('Loading..');
# 			},
# 			success : function(msg) {
# 				$('#administrativepullNoteModal .modal-body').html(msg);
# 			}
# 		});
# 		$('#administrativepullNoteModal').modal('show');
# 		return false;
# 	}
# 	function validateAttachmentSize(element) {
# 		var file = element.files[0];
# 		if((file.size/1000) > 10000) {
# 			alert('File size exceeds maximum limit');
# 			element.value = "";
# 		}
# 	}
#           </script>
#           <style>
#            #proposalTable1 {
# 	font-size: 12px;
# }
#
# #proposalTable1 tr>td, #proposalTable1 tr>th {
# 	vertical-align: middle;
# }
#
# #accordion .panel-heading {
# 	padding: 0;
# }
#
# #accordion .panel-title>a {
# 	display: block;
# 	padding: 0.4em 0.6em;
# 	outline: none;
# 	font-weight: normal;
# 	text-decoration: none;
# }
#
# #accordion .panel-title {
# 	text-align: left;
# }
#
# #accordion .panel-title>a.accordion-toggle::before, #accordion a[data-toggle="collapse"]::before
# 	{
# 	content: "\e113";
# 	float: left;
# 	font-family: 'Glyphicons Halflings';
# 	margin-right: 1em;
# }
#
# #accordion .panel-title>a.accordion-toggle.collapsed::before, #accordion a.collapsed[data-toggle="collapse"]::before
# 	{
# 	content: "\e114";
# }
#
# @media ( min-width : 768px) {
# 	.modal-xl {
# 		width: 90%;
# 		max-width: 1200px;
# 	}
# }
#
# div .col-sm-3, div .col-sm-6, div .col-sm-12 {
# 	margin: 5px 0px 5px 0px;
# }
#
# .active {
# 	border: none;
# ...
# 		if (classNames.split(' ').includes('collapsed')) {
# 			approvalId = '98936';
# 			if (typeof approvalId != 'undefined' && approvalId > 0) {
# 				getBudgetDetailsByHeadOfAccount(null, approvalId);
# 			}
# 		}
# 	}
#
# 	// FOR AA CANCEL
# 	function addCancelNotes(q) {
# 		$('#myModal .modal-title').html('Update Cancel Remarks');
# 		$.ajax({
# 			type: 'GET',
# 			url: 'addAANotes',
# 			data: {
# 				'q':q
# 			},
# 			beforeSend: ()=> {
# 				$('#myModal .modal-body').html('Loading..');
# 			},
# 			success: (result)=> {
# 				$('#myModal .modal-body').html(result);
# 			}
# 		});
# 		$('#myModal').modal('show');
# 		return false;
# 	}
#
# 	// For retrieviing all details of AA by ID
# 	function getAllDetailsByApprovalId(q) {
# 		$('#myModal .modal-title').html('Cancel Administrative Approval');
# 		$('#modalDialog').removeClass('modal-lg');
# 		$('#modalDialog').addClass('modal-xl');
# 		$.ajax({
# 			type: 'GET',
# 			url: 'findAllApprovalDetailsById',
# 			data: {
# 				'q' : q
# 			},
# 			beforeSend: ()=> {
# 				$('#myModal .modal-body').html('Loading..');
# 			},
# 			success: (response)=> {
# 				$('#myModal .modal-body').html(response);
# 			}
# 		});
# 		$('#myModal').modal('show');
# 		return false;
# 	}
# 	function reloadPageForRefreshToken(){
# 		location.reload();
# 	}
#
# 	function vaidateHoaWiseBudgetLimit(){
# 		var responseObj = {};
# 	var budgetProvisions = [];
# 		$('.headId').each((index, element)=>{
# 			if(element.value != ""){
# 				$.ajax({
# 					type: "GET",
# 					url: "vaidateHoaWiseBudgetLimit",
# 					async: false,
# 					data:{
# 						"hoaId": element.value
# 					},
# 					success: (response)=>{
# 						responseObj = {statusFlag: true, param: 0};
# 						var isExempted = response[0];
# 						var currentYearBudget = response[1];
# 						currentYearBudget = parseAndFormatFloats(currentYearBudget);
# 						var amountApprovedTillDate = response[2];
# 						var validationParameter = response[3];
# 						amountApprovedTillDate = parseAndFormatFloats(amountApprovedTillDate);
# 						currentYearBudgetprovision = currentYearBudget * validationParameter;
# 						budgetProvisions.push(currentYearBudgetprovision);
# 						$('#currentBudgetProvision').val(currentYearBudgetprovision);
#
# 						if(!isExempted){
# 							var amountRequestingFromTheHead = $('#amounts').val();
# 							amountRequestingFromTheHead = parseAndFormatFloats(amountRequestingFromTheHead);
# 							amountApprovedTillDate = amountApprovedTillDate + amountRequestingFromTheHead;
# 							amountApprovedTillDate = parseAndFormatFloats(amountApprovedTillDate);
#
# 							if(validationParameter!=null){
# 								if(amountApprovedTillDate > (currentYearBudget*validationParameter)){
# 									responseObj.param = validationParameter;
# 									responseObj.statusFlag = false;
# 								}
# 							}
# 						}
# 					}
# 				});
# 			}
# 			if(!responseObj.statusFlag){
# 				return false;
# 			}
# 		});
# 		return { responseObj, budgetProvisions,validationParameter };
# 	}
#
# 	function parseAndFormatFloats(value){
# 		var floatValue = parseFloat(value);
# 		floatValue = parseFloat(floatValue.toFixed(5));
# 		return floatValue;
# 	}
#
# 	function aaSaveDetails(approvalId) {
# 		var token = '4C10DNDKZ6NZDEA2UU0OFSDB6AH36TQX';
# 		var formData = new FormData();
# 	    var attachment = document.getElementById('sopdFileAttach').files[0];
# 	    var remark = document.getElementById('sopdJustifyRemark').value;
#
# 	    if (!attachment) {
# 	        alert("Please upload the SOPD Justification document.");
# 	        return false;
# 	    }
# 	    if (!remark) {
# 	        alert("Please provide your remarks.");
# 	        return false;
# 	    }
#
# 	    formData.append('administrativeApproval.sopdFile', attachment);
# 	    formData.append('administrativeApproval.sopdJustifyRemark', remark);
# 	    formData.append('administrativeApproval.approvalId', approvalId);
# 	    formData.append("struts.token.name", "token");
# 		formData.append("token", token);
#
# 	    $.ajax({
# 			type: "POST",
# 			url: "saveSopdAttachment",
# 			contentType: false,
# 			processData: false,
# 			data: formData,
# 			success: (response)=>{
# 				alert("Details saved successfully.");
# 				location.reload();
# 			}
# 		});
# 	    return true;
# 	}
#           </script>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </td>
#      <td width="4px">
#      </td>
#     </tr>
#     <tr>
#      <td colspan="3" style="height: 15px;">
#      </td>
#     </tr>
#     <tr>
#      <td colspan="3" style="background-color: #01458E;">
#       <table>
#        <tbody>
#         <tr>
#          <td background="../resources/images/th.jpg" bgcolor="#CCCCCC" height="22" valign="baseline" width="80%">
#           <div align="left" style="padding: 10px 5px 5px 5px; color: #FFFFFF;">
#            Version 17.7.42
#           </div>
#          </td>
#          <td background="../resources/images/th.jpg" bgcolor="#CCCCCC" height="20%" valign="baseline" width="20%">
#           <div align="right">
#            <button class="btn btn-helpdesk btn-sm" id="toggle-bp" title="Chatbot" type="button">
#             <i aria-hidden="true" class="fa fa-comments-o fa-lg">
#             </i>
#            </button>
#            <button class="btn btn-success btn-sm" onclick="gotoUMDownload()" title="User Manual" type="button">
#             <i class="fa fa-book">
#             </i>
#             UM
#            </button>
#            <button class="btn btn-helpdesk btn-sm" onclick="gotoHelpDisk('ad.rdm')" title="Technical Support" type="button">
#             <span class="glyphicon glyphicon-question-sign">
#             </span>
#             TSG
#            </button>
#            <a href="http://kran.co.in" rel="noopener noreferrer" target="_blank">
#             <img align="middle" alt="KRAN" src="../resources/images/kranitlogo.png"/>
#            </a>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <!-- By Sujith -- For Help Desk -->
#       <div class="custom-modal fade" data-backdrop="static" data-keyboard="false" id="myModalTSG" role="dialog">
#        <div class="custom-modal-dialog" style="width: 90%;">
#         <!-- Modal content -->
#         <div class="custom-modal-content">
#          <div class="custom-modal-header" style="background-color: #13498d;">
#           <button class="close" data-dismiss="modal" type="button">
#            ×
#           </button>
#           <img src="../resources/images/header.png"/>
#           <img src="../resources/images/assured_logo.png" style="width: 12%; float: right;"/>
#          </div>
#          <div class="custom-modal-body" style="overflow: auto; height: 650px;">
#           <iframe frameborder="0" height="100%" id="modalframe" src="about:blank" style="height: 535px;" width="100%">
#           </iframe>
#          </div>
#          <div class="custom-modal-footer" style="background-color: #13498d;">
#           <img align="middle" alt="KRAN" src="../resources/images/kranitlogo.png"/>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal fade" data-keyboard="false" id="userManualModal" role="dialog" style="display: none;">
#        <div class="modal-dialog modal-lg">
#         <div class="modal-content">
#          <div class="modal-header" style="background-color: #1469A0; color: #FFF;">
#           <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#           </button>
#           <h4 class="modal-title">
#            Manuals &amp; Tutorials
#           </h4>
#          </div>
#          <div class="modal-body">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="modal" id="userManualModalBS4" role="dialog" tabindex="-1">
#        <div class="modal-dialog modal-lg" role="document">
#         <div class="modal-content">
#          <div class="modal-header">
#           <h4 class="modal-title">
#            Manuals &amp; Tutorials
#           </h4>
#           <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#            <span aria-hidden="true">
#             ×
#            </span>
#           </button>
#          </div>
#          <div class="modal-body">
#          </div>
#         </div>
#        </div>
#       </div>
#       <script type="text/javascript">
#        document.getElementById("toggle-bp").addEventListener("click", function() {
# 		window.botpressWebChat.sendEvent({
# 			type : webchatOpen ? "hide" : "show"
# 		})
# 	})
#
# 	var bootstrap_enabled = (typeof $().emulateTransitionEnd == 'function');
# 	if (!bootstrap_enabled) {
# 		$("#userManualLink").hide();
# 		$.getScript('../resources/bootstrap/js/bootstrap.min.js');
# 	}
#
# 	$(document).ready(function() {
# 		$('#myModalTSG #modalframe').height($(window).height() - 200);
# 	});
#
# 	function gotoHelpDisk(hierarchyCode) {
# 		var pageTitle = document.title;
# 		var titleName = "Mr.";
# 		var empName = "Assistant";
# 		var lastName = "rdm";
# 		if (lastName != null) {
# 			var userName = titleName + ' ' + empName + ' ' + lastName;
# 		} else {
# 			var userName = titleName + ' ' + empName;
# 		}
# 		var seatName = "Assistant Department";
# 		var controllingOffice = "Revenue and Disaster Management Department";
# 		var seatUserAllotId = "18914";
# 		var mobile = "9707133011";
# 		var email = "";
#
# 		var myJSON = {
# 			"userName" : userName,
# 			"seatName" : seatName,
# 			"controllingOffice" : controllingOffice,
# 			"seatUserAllotId" : seatUserAllotId,
# 			"hierarchyCode" : hierarchyCode,
# 			"pageTitle" : pageTitle,
# 			"mobile" : mobile,
# 			"email" : email,
# 			"finassam" :'finassam'
# 		};
# 		var strJSON = encodeURIComponent(JSON.stringify(myJSON));
# 		$('#modalframe').attr('src',
# 				'/helpdesk/gotoHDeskFromApp?strJSON=' + strJSON);
# 		$('#myModalTSG').modal('show');
# 	}
#
# 	function gotoUserManuals() {
# 		var subtab = 'aaIssuedDept';
# 		if (subtab == 'dashboardDDO') {
# 			$.ajax({
# 				type : "GET",
# 				url : "getUserManualList",
# 				beforeSend : function() {
# 					$('#userManualModalBS4 .modal-body').html('Loading..');
# 				},
# 				success : function(msg) {
# 					$('#userManualModalBS4 .modal-body').html(msg);
# 				}
# 			});
# 			$('#userManualModalBS4').modal('show');
# 		} else {
# 			$.ajax({
# 				type : "GET",
# 				url : "getUserManualList",
# 				beforeSend : function() {
# 					$('#userManualModal .modal-body').html('Loading..');
# 				},
# 				success : function(msg) {
# 					$('#userManualModal .modal-body').html(msg);
# 				}
# 			});
# 			$('#userManualModal').modal('show');
# 		}
# 		return false;
# 	}
#
# 	function gotoUMDownload() {
# 			$.ajax({
# 				type : "GET",
# 				url : "gotoUMDownload",
# 				beforeSend : function() {
#
#
# 					$('#userManualModal .modal-body').html('Loading..');
# 				},
# 				success : function(msg) {
# 					$('#userManualModal .modal-body').html(msg);
# 				}
# 			});
# 			$('#userManualModal').modal('show');
# 	}
#
# 	function gotoFeedbackForm() {
# 		window.open("https://forms.gle/V2rio69ugYZS3zR68","_blank");
# 	}
#       </script>
#       <script type="text/javascript">
#        function gotoHelpDisk(hierarchyCode) {
# 		var pageTitle = document.title;
# 		var titleName = "Mr.";
# 		var empName = "Assistant";
# 		var lastName = "rdm";
# 		if (lastName != null) {
# 			var userName = titleName + ' ' + empName + ' ' + lastName;
# 		} else {
# 			var userName = titleName + ' ' + empName;
# 		}
# 		var seatName = "Assistant Department";
# 		var controllingOffice = "Revenue and Disaster Management Department";
# 		var seatUserAllotId = "18914";
# 		var mobile = "9707133011";
# 		var email = "";
#
# 		var myJSON = {
# 			"userName" : userName,
# 			"seatName" : seatName,
# 			"controllingOffice" : controllingOffice,
# 			"seatUserAllotId" : seatUserAllotId,
# 			"hierarchyCode" : hierarchyCode,
# 			"pageTitle" : pageTitle,
# 			"mobile" : mobile,
# 			"email" : email,
# 			"finassam" :'finassam'
# 		};
# 		var strJSON = encodeURIComponent(JSON.stringify(myJSON));
# 		$('#modalframe').attr('src',
# 				'/helpdesk/gotoHDeskFromApp?strJSON=' + strJSON);
# 		$('#myModalTSG').modal('show');
# 	}
#       </script>
#       <style>
#        .btnhelpdesk-sm, .btnhelpdesk-group-sm>.btnhelpdesk {
# 	padding: 5px 10px;
# 	font-size: 12px;
# 	line-height: 1.5;
# 	border-radius: 3px;
# }
#
# .btnhelpdesk {
# 	display: inline-block;
# 	margin-bottom: 0;
# 	font-weight: normal;
# 	text-align: center;
# 	vertical-align: middle;
# 	-ms-touch-action: manipulation;
# 	touch-action: manipulation;
# 	cursor: pointer;
# 	background-image: none;
# 	border: 1px solid transparent;
# 	border-top-color: transparent;
# 	border-right-color: transparent;
# 	border-bottom-color: transparent;
# 	border-left-color: transparent;
# 	white-space: nowrap;
# 	padding: 6px 12px;
# 	font-size: 14px;
# 	line-height: 1.42857143;
# 	border-radius: 4px;
# 	-webkit-user-select: none;
# 	-moz-user-select: none;
# 	-ms-user-select: none;
# 	user-select: none;
# }
#
# .custom-modal-body {
# 	position: relative;
# 	padding: 15px;
# }
#
# .custom-modal-content {
# 	-webkit-box-shadow: 0 5px 15px rgba(0, 0, 0, 0.5);
# 	box-shadow: 0 5px 15px rgba(0, 0, 0, 0.5);
# }
#
# .custom-modal-content {
# 	position: relative;
# 	background-color: #fff;
# 	border: 1px solid #999;
# 	border: 1px solid rgba(0, 0, 0, 0.2);
# 	border-radius: 6px;
# 	-webkit-box-shadow: 0 3px 9px rgba(0, 0, 0, 0.5);
# 	box-shadow: 0 3px 9px rgba(0, 0, 0, 0.5);
# 	-webkit-background-clip: padding-box;
# 	background-clip: padding-box;
# 	outline: 0;
# }
#
# .custom-modal-open .modal {
# 	overflow-x: hidden;
# 	overflow-y: auto;
# }
#
# .custom-modal {
# 	display: none;
# 	overflow: hidden;
# 	position: fixed;
# 	top: 0;
# 	right: 0;
# 	bottom: 0;
# 	left: 0;
# 	z-index: 1050;
# 	-webkit-overflow-scrolling: touch;
# 	outline: 0;
# }
#
# .custom-modal-header {
# 	padding: 15px;
# 	border-bottom: 1px solid #e5e5e5;
# }
#
# .custom-modal-header .close {
# 	margin-top: -2px;
# }
#
# .custom-modal-footer {
# 	padding: 15px;
# 	text-align: right;
# 	border-top: 1px solid #e5e5e5;
# }
#
# .close:hover, .close:focus {
# 	color: #000;
# 	text-decoration: none;
# 	cursor: pointer;
# 	opacity: .5;
# 	filter: alpha(opacity = 50);
# }
#
# button.close {
# 	padding: 0;
# 	cursor: pointer;
# 	background: transparent;
# 	border: 0;
# 	-webkit-appearance: none;
# }
#
# .close {
# 	float: right;
# 	font-size: 21px;
# 	font-weight: bold;
# 	line-height: 1;
# 	color: #000;
# 	text-shadow: 0 1px 0 #fff;
# 	opacity: 1;
# 	filter: alpha(opacity = 20);
# }
#
# .custom-modal-dialog {
# 	margin: 30px auto;
# }
#
# .custom-modal-dialog {
# 	position: relative;
# 	width: auto;
# 	margin: 5%;
# }
#
# .custom-modal-backdrop.fade {
# 	opacity: 0;
# 	filter: alpha(opacity = 0);
# }
#
# .custom-modal-backdrop.in {
# 	opacity: .5;
# 	filter: alpha(opacity = 50);
# }
#
# .custom-modal-backdrop {
# 	position: fixed;
# 	top: 0;
# 	right: 0;
# 	bottom: 0;
# 	left: 0;
# 	z-index: 1040;
# 	background-color: #000;
# }
#       </style>
#       <!-- By Sujith -- For Help Desk -->
#      </td>
#     </tr>
#    </tbody>
#   </table>
#   <div id="bp-web-widget">
#    <iframe class="bp-widget-web bp-widget-widget bp-widget-hidden" frameborder="0" id="bp-widget" src="https://finanalytics.assam.gov.in/botpress/lite/helpdesk/?m=channel-web&amp;v=Embedded&amp;options=%7B%22config%22%3A%7B%22host%22%3A%22https%3A%2F%2Ffinanalytics.assam.gov.in%2Fbotpress%22%2C%22botId%22%3A%22helpdesk%22%2C%22userId%22%3A%2218914%22%2C%22botName%22%3A%22Helpdesk%22%2C%22enableTranscriptDownload%22%3Afalse%2C%22showConversationsButton%22%3Afalse%2C%22hideWidget%22%3Atrue%2C%22useSessionStorage%22%3Atrue%7D%7D" title="Helpdesk">
#    </iframe>
#   </div>
#   <div class="modal fade centered-modal" id="surveyModal" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-body">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="anylinkmenu" style="width: 150px; background: rgb(255, 255, 255);">
#    <ul>
#     <li>
#      <a href="javascript: editProfile()" target="_self">
#       Profile
#      </a>
#     </li>
#     <li>
#      <a href="javascript:TINY.box.show({iframe:'/assamfinance/changePasswd',width:650,height:500,boxid : 'frameless' })" target="_self">
#       Change Password
#      </a>
#     </li>
#     <li>
#      <a href="javascript: passwordHistory()" target="_self">
#       Password History
#      </a>
#     </li>
#     <li>
#      <a href="javascript:TINY.box.show({iframe:'deleteProfile',width:600,height:450,boxid : 'frameless' })" target="_self">
#       Deactivate Account
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="anylinkshadow" style="width: 150px; height: 92px; opacity: 0.3;">
#   </div>
#   <div class="tox tox-silver-sink tox-tinymce-aux" style="position: relative;">
#   </div>
#  </body>
# </html>

# %%
import os
import re
import difflib
import pandas as pd
from bs4 import BeautifulSoup

# Your dictionary mapping original titles to the CSS fingerprint for the next element
extraction_dict = {
    'Name of the Scheme/Project proposed': 'div class="col-sm-18"', 
    'Whether scheme/project is new/ongoing': 'div class="col-sm-6"', 
    'Whether the scheme is funded by NABARD': 'div class="col-sm-6"', 
    'Proposal Number': 'div class="form-group"', 
    'Proposal Date': 'div class="col-sm-6"', 
    'Issued Number': 'div class="form-group"', 
    'Valid Upto': 'div class="col-sm-6"', 
    'Admin Department File Number': 'div class="col-sm-6"', 
    'Brief nature of the scheme/project and the time period required for implementation/execution': 'div class="col-sm-6"', 
    'Aim, objectives and benefit expected from the scheme/project': 'div class="col-sm-6"', 
    'Whether included in the priority list approved by the Departmental Minister': 'div class="col-sm-6"', 
    'Ddo Details': 'div class="col-sm-6"', 
    'Common Proposal': 'div class="col-sm-6"', 
    'Project Profile Id:': 'div class="col-sm-6"', 
    'Project Classification': 'span class="text-success h6"', 
    'Type of the project:': '<div class="col-lg-12">', 
    'Opening and Closing dates:': 'div class="col-sm-6"',  # This field will later be split into starting and closing dates
    'Project Beneficiary :': 'div class="col-sm-6" style="margin-top: 10px;"', 
    'Procurement Activity Type:': 'div class="col-sm-8" style="margin-top: 10px;"', 
    'Beneficiary Share Amount(In Lakhs)': 'div class="col-sm-12"', 
    'Whether the scheme is centrally sponsored scheme': 'div class="col-sm-12"', 
    'Total Administrative Approval Amount (Project Cost)(In Lakhs)': 'div class="col-sm-12"', 
    'DDO Code': 'div class="col-sm-6"', 
    'Treasury Name': 'div class="col-sm-6"', 
    'DDO Office Name': 'div class="col-sm-18"', 
    'Permission from local bodies for construction/establishment wherever necessary': 'div class="col-sm-18"', 
    'Non-Objection certificate': 'div class="col-sm-18"', 
    'Non-Duplicity certificate': 'div class="col-sm-18"', 
    'Views of Department': 'div class="col-sm-18"', 
    "Details information in case of observation made by T&D in last year's endorsement": 'div class="form-group"', 
    'Sanction letter copy of GOI in case of Central Sector Schemes': 'div class="col-sm-6"', 
    'Views of Sr.F.A/F.A for non-admissibility of the instant project under DFPR': 'div class="col-sm-18"', 
    'Funding pattern of the scheme': 'div class="col-sm-6"', 
    'The year from which the scheme is being implemented': 'div class="col-sm-6"', 
    'The quantum of central share allocated/released for the year along with the supporting document': 'div class="col-sm-6"', 
    'The criteria of proposing the amount of state share': 'div class="col-sm-6"'
}

def pattern_to_selector(pattern):
    """
    Converts a string like 'div class="col-sm-18"' or '<div class="col-lg-12">' 
    into a CSS selector (e.g. 'div.col-sm-18' or 'div.col-lg-12').
    """
    pattern = pattern.strip()
    if pattern.startswith("<") and pattern.endswith(">"):
        pattern = pattern[1:-1].strip()
    tag_match = re.match(r'^(\w+)', pattern)
    tag = tag_match.group(1) if tag_match else ""
    class_match = re.search(r'class="([^"]+)"', pattern)
    if class_match:
        classes = class_match.group(1).split()
        selector = tag + ''.join(['.' + cls for cls in classes])
    else:
        selector = tag
    return selector

def extract_value_for_key(soup, key, pattern):
    """
    Searches for a text node containing the cleaned key (parentheses removed) in a case-insensitive way,
    then returns the text from the first subsequent element that matches the CSS selector derived from pattern.
    """
    # Remove any parentheses and contained text from the key
    cleaned_key = re.sub(r'\s*\([^)]*\)', '', key).strip()
    label_element = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))
    if label_element:
        selector = pattern_to_selector(pattern)
        def matches(tag):
            if not tag.name:
                return False
            sel_parts = selector.split('.')
            sel_tag = sel_parts[0]
            sel_classes = sel_parts[1:] if len(sel_parts) > 1 else []
            if tag.name != sel_tag:
                return False
            tag_classes = tag.get("class", [])
            return all(cls in tag_classes for cls in sel_classes)
        candidate = label_element.find_next(matches)
        if candidate:
            return re.sub(r'\s+', ' ', candidate.get_text(strip=True))
    return None

def get_candidate_titles(soup):
    """
    Extracts candidate title elements from the new HTML file.
    For this example, we use all non-empty <div> elements (you can adjust this selector as needed).
    Returns a list of tuples: (text, element)
    """
    candidates = []
    for div in soup.find_all("div"):
        text = div.get_text(strip=True)
        if text and len(text) > 3:  # filter very short strings
            candidates.append((text, div))
    return candidates

def extract_new_value_from_element(elem):
    """
    Given an element (assumed to be the matched title in the new file),
    find the next element that likely contains the corresponding value and clean its text.
    """
    if elem:
        next_elem = elem.find_next()
        if next_elem:
            return re.sub(r'\s+', ' ', next_elem.get_text(strip=True))
    return None

def main():
    # Paths to your original and new HTML files (update these paths as needed)
    original_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2024-25\AA-05-2024-25-7194.html"
    new_file = r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\scripts\scraping_experiments\downloaded_pages\2017-18\AA-05-2017-18-7101.html"
    
    if not os.path.exists(original_file):
        print(f"Original file not found: {original_file}")
        return
    if not os.path.exists(new_file):
        print(f"New file not found: {new_file}")
        return

    # Load both files into BeautifulSoup and pre-clean all text nodes
    with open(original_file, 'r', encoding='utf-8') as f:
        original_soup = BeautifulSoup(f.read(), 'html.parser')
    with open(new_file, 'r', encoding='utf-8') as f:
        new_soup = BeautifulSoup(f.read(), 'html.parser')
    
    # Pre-clean all text nodes in both soups
    for soup in [original_soup, new_soup]:
        for text_node in soup.find_all(text=True):
            cleaned = re.sub(r'\s+', ' ', text_node)
            text_node.replace_with(cleaned)
    
    # Extract values from the original file using the provided dictionary
    original_extracted = {}
    for key, pattern in extraction_dict.items():
        original_extracted[key] = extract_value_for_key(original_soup, key, pattern)
    
    # In the new file, extract candidate title elements (this is a simple example using all divs)
    candidate_titles = get_candidate_titles(new_soup)
    candidate_texts = [text for text, elem in candidate_titles]
    
    # Prepare a list to collect DataFrame rows
    rows = []
    
    # For each original title (key), perform fuzzy matching to find the closest candidate title in new file
    for key in extraction_dict.keys():
        cleaned_key = re.sub(r'\s*\([^)]*\)', '', key).strip()
        best_matches = difflib.get_close_matches(cleaned_key, candidate_texts, n=1, cutoff=0.4)
        if best_matches:
            new_title = best_matches[0]
            # Get the candidate element corresponding to the matched title
            candidate_elem = next((elem for text, elem in candidate_titles if text == new_title), None)
            new_value = extract_new_value_from_element(candidate_elem)
        else:
            new_title = None
            new_value = None
        
        # Get the original value from the original file
        original_value = original_extracted.get(key)
        
        # Append the row (each row corresponds to one original title/key)
        rows.append({
            "Original Column": key,
            "New HTML Column": new_title,
            "Element in Original File": original_value,
            "Element in New File": new_value
        })
    
    # Create the DataFrame
    df = pd.DataFrame(rows)
    print("Extracted DataFrame:")
    #print(df)
    
    # Optionally, save the DataFrame to a CSV file
    output_csv = "comparison_extracted_data.csv"
    df.to_csv(output_csv, index=False)
    print(f"Data saved to {output_csv}")
    return df

if __name__ == "__main__":
    main()
# Out:
# Extracted DataFrame:
# Data saved to comparison_extracted_data.csv
# C:\Users\saura\AppData\Local\Temp\ipykernel_25628\1576963899.py:134: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for text_node in soup.find_all(text=True):
# C:\Users\saura\AppData\Local\Temp\ipykernel_25628\1576963899.py:72: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   label_element = soup.find(text=re.compile(re.escape(cleaned_key), re.IGNORECASE))

# %% [markdown]
# # EDA

# %%
all_data = pd.read_csv(r"D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\SDRF\data\all_extracted_data.csv")
all_data
# Out:
#                                      Name of the Scheme  \
# 0     Immediate measures for closing of breach and r...
# 1     Immediate measures for restoration of damaged ...
# 2     Restoration of flood damaged road from 6th KM ...
# 3     Immediate measures for restoration of damages ...
# 4     "Immediate measures to Ring Bund at villagae T...
# ...                                                 ...
# 5826  CONSTRUCTION OF FRONT BUILDING (GROUND + THREE...
# 5827  CONSTRUCTION OF FRONT BUILDING (GROUND + THREE...
# 5828  Procurement of Machinery and Trolley Mounted P...
# 5829  Construction of DEOC building, Kamrup, Amingao...
# 5830  Resilient Relief Camp on Wheels in 02 flood pr...
#
#                                          Whether scheme  \
# 0                                           New project
# 1                                           New project
# 2                                           New project
# 3                                           New project
# 4                                           New project
# ...                                                 ...
# 5826  Ongoing Project(Parent Proposal No. AA-SDM-202...
# 5827  Ongoing Project(Parent Proposal No. AA-SDM-202...
# 5828                                        New project
# 5829                                        New project
# 5830                                        New project
#
#      Whether the scheme is funded by NABARD      Proposal Number  \
# 0                                        No   AA-05-2019-20-0197
# 1                                        No   AA-05-2019-20-0198
# 2                                        No   AA-05-2019-20-0200
# 3                                        No   AA-05-2019-20-0205
# 4                                        No   AA-05-2019-20-0206
# ...                                     ...                  ...
# 5826                                    NaN                  NaN
# 5827                                    NaN                  NaN
# 5828                                     No  AA-SDM-2024-25-0007
# 5829                                     No  AA-SDM-2024-25-0008
# 5830                                     No  AA-SDM-2024-25-0009
#
#      Proposal Date         Issued Number  Valid Upto  \
# 0       06-06-2019   AA/05_2019-20(I)_11  20-07-2022
# 1       06-06-2019   AA/05_2019-20(I)_10  19-07-2022
# 2       14-06-2019   AA/05_2019-20(I)_01  14-06-2022
# 3       26-06-2019   AA/05_2019-20(I)_28  06-12-2022
# 4       26-06-2019   AA/05_2019-20(I)_09  19-07-2024
# ...            ...                   ...         ...
# 5826    06-12-2024                   NaN         NaN
# 5827    17-12-2024                   NaN         NaN
# 5828    20-01-2025  AA/SDM_2024-25(I)_03  29-01-2030
# 5829    24-02-2025  AA/SDM_2024-25(I)_04  11-03-2028
# 5830    25-02-2025  AA/SDM_2024-25(I)_05  13-03-2028
#
#      Admin Department File Number  \
# 0                RGR(RRR)386/2019
# 1                RGr(RRR)388/2019
# 2                RGR(RRR)951/2018
# 3                RGR(RRR)548/2019
# 4                RGR(RRR)819/2018
# ...                           ...
# 5826                        -N/A-
# 5827                        -N/A-
# 5828                       499824
# 5829                          NaN
# 5830                       231771
#
#                              Brief nature of the scheme  \
# 0     Immediateestoration of flood damages of river ...
# 1     Immediate measures for repairing and restoration.
# 2                     Restoration of flood damaged work
# 3     The proposed scheme has been framed to prevent...
# 4                                                   NaN
# ...                                                 ...
# 5826                                              -N/A-
# 5827                                              -N/A-
# 5828  Procurement of Machinery and Trolley Mounted P...
# 5829  Construction of DEOC building, Kamrup, Amingao...
# 5830  Resilient Relief Camp on Wheels in 02 flood pr...
#
#      Aim, objectives and benefit expected from the scheme/project  ...  \
# 0     To protect the people of the greater Dhakuakha...            ...
# 1     To protect the people of Greater Dhakuakhana area            ...
# 2     It is the only road for movement to schools, c...            ...
# 3     The proposed scheme has been framed to prevent...            ...
# 4     To protect the life and property of the people...            ...
# ...                                                 ...            ...
# 5826                                              -N/A-            ...
# 5827                                              -N/A-            ...
# 5828  1. The pumps will aid in mitigation of urban f...            ...
# 5829  Construction of DEOC building, Kamrup, Amingao...            ...
# 5830  OUTCOMES OF THE PROJECT: Mitigate chances of e...            ...
#
#      Sanction letter copy of GOI in case of Central Sector Schemes  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 5826                                                NaN
# 5827                                                NaN
# 5828                                                 No
# 5829                                                 No
# 5830                                                Yes
#
#      Views of Sr                      Funding pattern of the scheme  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# ...          ...                                                ...
# 5826         NaN                                                NaN
# 5827         NaN                                                NaN
# 5828         NaN  FROM SDRF-PREPAREDNESS & CAPACITY BUILDING WINDOW
# 5829         NaN  FROM SDRF-PREPAREDNESS & CAPACITY BUILDING WINDOW
# 5830         NaN  FROM SDRF-PREPAREDNESS & CAPACITY BUILDING WINDOW
#
#       The year from which the scheme is being implemented  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5826                                                NaN
# 5827                                                NaN
# 5828                                            2024-25
# 5829                                            2023-24
# 5830                                            2024-25
#
#      The quantum of central share allocated  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 5826                                    NaN
# 5827                                    NaN
# 5828                             9940 LAKHS
# 5829                             9940 LAKHS
# 5830                             9940 LAKHS
#
#      The criteria of proposing the amount of state share  Starting Date  \
# 0                                                   NaN            ----
# 1                                                   NaN            ----
# 2                                                   NaN            ----
# 3                                                   NaN            ----
# 4                                                   NaN            ----
# ...                                                 ...             ...
# 5826                                                NaN             NaN
# 5827                                                NaN             NaN
# 5828                                                NaN      29-01-2025
# 5829                                                NaN      11-03-2025
# 5830                                                NaN      13-03-2025
#
#      Closing Date Financial Year  \
# 0             NaN        2019-20
# 1             NaN        2019-20
# 2             NaN        2019-20
# 3             NaN        2019-20
# 4             NaN        2019-20
# ...           ...            ...
# 5826          NaN        2024-25
# 5827          NaN        2024-25
# 5828   29-01-2030        2024-25
# 5829   11-03-2028        2024-25
# 5830   13-03-2028        2024-25
#
#                                             Source File
# 0     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 1     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 2     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 3     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 4     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# ...                                                 ...
# 5826  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5827  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5828  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5829  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5830  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
#
# [5831 rows x 40 columns]

# %%
all_data['Issued Number'].nunique()
# Out:
# 5658

# %%
# Create a regex pattern to match "PWD", "public works department", or "pwd" (case-insensitive)
pattern = r"(?i)\b(?:pwd|public works department)\b"

# Apply the pattern across all columns and get a boolean mask for rows that contain the pattern
mask = all_data.apply(lambda col: col.astype(str).str.contains(pattern, regex=True, na=False)).any(axis=1)

# Filter the DataFrame based on the mask
pwd_rows = all_data[mask]

print(pwd_rows)
# Out:
#                                      Name of the Scheme  \
# 2     Restoration of flood damaged road from 6th KM ...
# 6     Immediate restoration of flood damaged road fr...
# 8     Immediate restoration of Udmari Salkocha road ...
# 9     Immediate restoration of the flood damaged roa...
# 10    Immediate restoration of flood damaged road fr...
# ...                                                 ...
# 5614  Immediate Restoration of 7 No line tiniali roa...
# 5618  Immediate Restoration of Dillibari PWD Road to...
# 5665  Temporary Restoration of Velakoba Durahati PWD...
# 5693  Road from Gunahati PWD at Kalakata to SIRD Com...
# 5715  Restoration of road from Kanaibazar- Anipur PW...
#
#                                          Whether scheme  \
# 2                                           New project
# 6                                           New project
# 8                                           New project
# 9                                           New project
# 10                                          New project
# ...                                                 ...
# 5614                                        New project
# 5618                                        New project
# 5665                                        New project
# 5693                                        New project
# 5715  Ongoing Project(Parent Proposal No. AA-05-2014...
#
#      Whether the scheme is funded by NABARD     Proposal Number Proposal Date  \
# 2                                        No  AA-05-2019-20-0200    14-06-2019
# 6                                        No  AA-05-2019-20-0209    05-07-2019
# 8                                        No  AA-05-2019-20-0211    22-07-2019
# 9                                        No  AA-05-2019-20-0212    05-07-2019
# 10                                       No  AA-05-2019-20-0213    05-07-2019
# ...                                     ...                 ...           ...
# 5614                                     No  AA-05-2024-25-7246    06-07-2024
# 5618                                     No  AA-05-2024-25-7250    06-07-2024
# 5665                                     No  AA-05-2024-25-7299    01-07-2024
# 5693                                     No  AA-05-2024-25-7330    08-10-2024
# 5715                                    NaN                 NaN    13-11-2024
#
#               Issued Number  Valid Upto Admin Department File Number  \
# 2       AA/05_2019-20(I)_01  14-06-2022             RGR(RRR)951/2018
# 6       AA/05_2019-20(I)_08  05-07-2022             RGR(RRR)633/2019
# 8       AA/05_2019-20(I)_15  02-08-2022             RGR(RRR)666/2019
# 9       AA/05_2019-20(I)_06  05-07-2022             RGR(RRR)669/2019
# 10      AA/05_2019-20(I)_05  05-07-2022             RGR(RRR)670/2019
# ...                     ...         ...                          ...
# 5614  AA/05_2024-25(I)_5505  17-07-2027                       283937
# 5618  AA/05_2024-25(I)_5509  17-07-2027                       283937
# 5665  AA/05_2024-25(I)_5537  24-07-2027                       294426
# 5693  AA/05_2024-25(I)_5612  02-11-2027                       496057
# 5715                    NaN         NaN                        -N/A-
#
#                        Brief nature of the scheme  \
# 2               Restoration of flood damaged work
# 6     Immediate restoration of flood damaged Road
# 8               Restoration of flood damaged work
# 9      Immediate restoration of the flood damaged
# 10         Immediate restoration of flood damaged
# ...                                           ...
# 5614                                  SDRF scheme
# 5618                                  SDRF scheme
# 5665                                  SDRF SCHEME
# 5693                            mitigation scheme
# 5715                                        -N/A-
#
#      Aim, objectives and benefit expected from the scheme/project  ...  \
# 2     It is the only road for movement to schools, c...            ...
# 6     Due to devasting flood of 13th August,2017 the...            ...
# 8     For the above circumstances this estimate is p...            ...
# 9     Devastating flood on 12th July 2017, the compl...            ...
# 10    The road and it has become un comfortable for ...            ...
# ...                                                 ...            ...
# 5614                                                NaN            ...
# 5618                                                NaN            ...
# 5665                                                NaN            ...
# 5693                                                NaN            ...
# 5715                                              -N/A-            ...
#
#      Sanction letter copy of GOI in case of Central Sector Schemes  \
# 2                                                    No
# 6                                                    No
# 8                                                    No
# 9                                                    No
# 10                                                   No
# ...                                                 ...
# 5614                                                 No
# 5618                                                 No
# 5665                                                 No
# 5693                                                 No
# 5715                                                NaN
#
#      Views of Sr Funding pattern of the scheme  \
# 2            NaN                           NaN
# 6            NaN                           NaN
# 8            NaN                           NaN
# 9            NaN                           NaN
# 10           NaN                           NaN
# ...          ...                           ...
# 5614         NaN                           NaN
# 5618         NaN                           NaN
# 5665         NaN                           NaN
# 5693         NaN                           NaN
# 5715         NaN                           NaN
#
#       The year from which the scheme is being implemented  \
# 2                                                   NaN
# 6                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# ...                                                 ...
# 5614                                                NaN
# 5618                                                NaN
# 5665                                                NaN
# 5693                                                  0
# 5715                                                NaN
#
#      The quantum of central share allocated  \
# 2                                       NaN
# 6                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# ...                                     ...
# 5614                                    NaN
# 5618                                    NaN
# 5665                                    NaN
# 5693                                    NaN
# 5715                                    NaN
#
#      The criteria of proposing the amount of state share  Starting Date  \
# 2                                                   NaN            ----
# 6                                                   NaN            ----
# 8                                                   NaN            ----
# 9                                                   NaN            ----
# 10                                                  NaN            ----
# ...                                                 ...             ...
# 5614                                                NaN      17-07-2024
# 5618                                                NaN      17-07-2024
# 5665                                                NaN      24-07-2024
# 5693                                                NaN      02-11-2024
# 5715                                                NaN             NaN
#
#      Closing Date Financial Year  \
# 2             NaN        2019-20
# 6             NaN        2019-20
# 8             NaN        2019-20
# 9             NaN        2019-20
# 10            NaN        2019-20
# ...           ...            ...
# 5614   17-07-2027        2024-25
# 5618   17-07-2027        2024-25
# 5665   24-07-2027        2024-25
# 5693   02-11-2027        2024-25
# 5715          NaN        2024-25
#
#                                             Source File
# 2     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 6     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 8     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 9     D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 10    D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# ...                                                 ...
# 5614  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5618  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5665  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5693  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
# 5715  D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR...
#
# [699 rows x 40 columns]
