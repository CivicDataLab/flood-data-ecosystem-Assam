# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
urban
# Out:
#        area   id   revenue_ci               district_3  object_id  \
# 0     2.320    1    Mankachar  SOUTH SALMARA MANCACHAR        257
# 1    85.747    2    Mankachar  SOUTH SALMARA MANCACHAR        257
# 2     0.773    3    Mankachar  SOUTH SALMARA MANCACHAR        257
# 3     6.931    4  Dhubri (Pt)                   DHUBRI        112
# 4     4.618    5  Dhubri (Pt)                   DHUBRI        112
# ..      ...  ...          ...                      ...        ...
# 176   5.318  177   Doom Dooma                 TINSUKIA        155
# 177   0.760  178   Doom Dooma                 TINSUKIA        155
# 178   0.759  179   Doom Dooma                 TINSUKIA        155
# 179   0.759  180   Doom Dooma                 TINSUKIA        155
# 180   2.274  181        Jonai                  DHEMAJI        152
#
#                   district_1   revenue_cr  longitude   latitude  \
# 0    South Salmara Mancachar    Mankachar  89.863913  25.528749
# ...

# %%
urban = gpd.read_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\ANTYODAYA\data\assam_urban_shapes\assam_urban_pd_grt_2000.shp')
rc_updated = gpd.read_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Maps\as_ids-drr_shapefiles\assam_rc_2024-11.geojson')
rc_updated['object_id_old'] = rc_updated['object_id'].str[9:12].astype(int)
merged = pd.merge(urban,rc_updated[['object_id','object_id_old']],left_on="object_id",right_on="object_id_old", how="left")
merged = merged.drop(['object_id_x','object_id_old'],axis=1)
merged = merged.rename(columns={'object_id_y':'object_id'})

# %%
merged.to_file(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\IDS-DRR-Assam\Sources\ANTYODAYA\data\assam_urban_shapes\assam_urban_objectid_update.geojson')
